# %% [markdown]
# # **Cryptocurrency (CoinGecko API)**
# ## **Data Collection**

# %%
# Data collection from url
data_crypto = []

import requests
import time # avoiding limiting

for page_num in range(1,6):
  url = f"https://api.coingecko.com/api/v3/coins/markets?vs_currency=inr&per_page=250&order=market_cap_desc&page=1&sparkline=False"
  response = requests.get(url)
  if response.status_code == 200:
    data_crypto.extend(response.json()) # Extend the list with data from current page
    print(f"Collected data from page {page_num}")
  else:
    print(f"Error collecting data from page {page_num}: {response.status_code}")
    page_num += 1
  time.sleep(5) # Increased wait time to 1 second to avoid rate limiting

print ("==========================================")
print(f"Total data collected: {len(data_crypto)}")
# Out:
# Collected data from page 1
# Collected data from page 2
# Collected data from page 3
# Error collecting data from page 4: 429
# Error collecting data from page 5: 429
# ==========================================
# Total data collected: 750

# %%
data_crypto
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 5895707,
#   'market_cap': 117892080849959,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 117892263640264,
#   'total_volume': 4583479474349,
#   'high_24h': 6142059,
#   'low_24h': 5848806,
#   'price_change_24h': -216917.19891759753,
#   'price_change_percentage_24h': -3.54868,
#   'market_cap_change_24h': -4340092442865.078,
#   'market_cap_change_percentage_24h': -3.5507,
#   'circulating_supply': 19993700.0,
#   'total_supply': 19993731.0,
#   'max_supply': 21000000.0,
#   'ath': 11187013,
#   'ath_change_percentage': -47.29865,
#   'ath_date': '2025-10-06T18:57:42.558Z',
#   'atl': 3993.42,
#   'atl_change_percentage': 147535.5529,
#   'atl_date': '2013-07-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:21.461Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628',
#   'current_price': 169178,
#   'market_cap': 20440925651868,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 20440925651868,
#   'total_volume': 2001022139544,
#   'high_24h': 177705,
#   'low_24h': 167972,
#   'price_change_24h': -6835.10255134062,
#   'price_change_percentage_24h': -3.8833,
#   'market_cap_change_24h': -832379327739.9414,
#   'market_cap_change_percentage_24h': -3.91279,
#   'circulating_supply': 120692355.0689789,
#   'total_supply': 120692355.0689789,
#   'max_supply': None,
#   'ath': 431946,
#   'ath_change_percentage': -60.8336,
#   'ath_date': '2025-08-24T19:21:03.333Z',
#   'atl': 28.13,
#   'atl_change_percentage': 601286.76531,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 37.36903788407626,
#    'currency': 'btc',
#    'percentage': 3736.9037884076265},
#   'last_updated': '2026-02-23T18:28:21.307Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 90.97,
#   'market_cap': 16705159045807,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 17202511997363,
#   'total_volume': 7545121219116,
#   'high_24h': 91.0,
#   'low_24h': 90.67,
#   'price_change_24h': 0.270998,
#   'price_change_percentage_24h': 0.2988,
#   'market_cap_change_24h': 49639625334,
#   'market_cap_change_percentage_24h': 0.29804,
#   'circulating_supply': 183624238441.843,
#   'total_supply': 189091175734.4462,
#   'max_supply': None,
#   'ath': 105.52,
#   'ath_change_percentage': -13.78446,
#   'ath_date': '2025-01-25T16:51:57.989Z',
#   'atl': 36.86,
#   'atl_change_percentage': 146.81105,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.378Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 124.14,
#   'market_cap': 7577930067118,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 12417278315589,
#   'total_volume': 313077098068,
#   'high_24h': 128.81,
#   'low_24h': 121.21,
#   'price_change_24h': -1.9334480399536602,
#   'price_change_percentage_24h': -1.53361,
#   'market_cap_change_24h': -119908009809.65527,
#   'market_cap_change_percentage_24h': -1.55768,
#   'circulating_supply': 61018583977.0,
#   'total_supply': 99985712847.0,
#   'max_supply': 100000000000.0,
#   'ath': 313.99,
#   'ath_change_percentage': -60.46377,
#   'ath_date': '2025-07-21T15:02:00.541Z',
#   'atl': 0.159343,
#   'atl_change_percentage': 77806.59023,
#   'atl_date': '2013-08-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:17.907Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 54333,
#   'market_cap': 7415804403755,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 7415804355897,
#   'total_volume': 132172575655,
#   'high_24h': 55875,
#   'low_24h': 53176,
#   'price_change_24h': -1128.2570488575075,
#   'price_change_percentage_24h': -2.03431,
#   'market_cap_change_24h': -151805735667.78906,
#   'market_cap_change_percentage_24h': -2.00599,
#   'circulating_supply': 136359000.53,
#   'total_supply': 136358999.65,
#   'max_supply': 200000000.0,
#   'ath': 121422,
#   'ath_change_percentage': -55.2525,
#   'ath_date': '2025-10-13T08:41:24.131Z',
#   'atl': 2.58,
#   'atl_change_percentage': 2101982.09025,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:21.068Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/USDC.png?1769615602',
#   'current_price': 90.97,
#   'market_cap': 6798842455725,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 6799575469447,
#   'total_volume': 1174213171678,
#   'high_24h': 91.0,
#   'low_24h': 90.68,
#   'price_change_24h': 0.242333,
#   'price_change_percentage_24h': 0.2671,
#   'market_cap_change_24h': 45451812003,
#   'market_cap_change_percentage_24h': 0.67302,
#   'circulating_supply': 74743037601.80803,
#   'total_supply': 74751095984.18327,
#   'max_supply': None,
#   'ath': 1327.87,
#   'ath_change_percentage': -93.1487,
#   'ath_date': '2025-01-23T04:45:51.184Z',
#   'atl': 65.31,
#   'atl_change_percentage': 39.30402,
#   'atl_date': '2021-05-19T13:14:05.611Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.356Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 7126.6,
#   'market_cap': 4051450602339,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 4426253195174,
#   'total_volume': 443170790479,
#   'high_24h': 7579.84,
#   'low_24h': 7013.93,
#   'price_change_24h': -413.81561564257936,
#   'price_change_percentage_24h': -5.48797,
#   'market_cap_change_24h': -234814134988.67578,
#   'market_cap_change_percentage_24h': -5.47829,
#   'circulating_supply': 568474098.3567048,
#   'total_supply': 621064043.7705076,
#   'max_supply': None,
#   'ath': 25396,
#   'ath_change_percentage': -71.93845,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 38.03,
#   'atl_change_percentage': 18641.53776,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.163Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://coin-images.coingecko.com/coins/images/1094/large/tron-logo.png?1696502193',
#   'current_price': 25.65,
#   'market_cap': 2429930340801,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 2429930480653,
#   'total_volume': 57286417590,
#   'high_24h': 26.4,
#   'low_24h': 25.64,
#   'price_change_24h': -0.7344349356597206,
#   'price_change_percentage_24h': -2.78377,
#   'market_cap_change_24h': -69297458619.9458,
#   'market_cap_change_percentage_24h': -2.77275,
#   'circulating_supply': 94735543888.4447,
#   'total_supply': 94735549340.83319,
#   'max_supply': None,
#   'ath': 36.53,
#   'ath_change_percentage': -29.7797,
#   'ath_date': '2024-12-04T00:10:40.323Z',
#   'atl': 0.117589,
#   'atl_change_percentage': 21711.76168,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 147.38793060795058,
#    'currency': 'usd',
#    'percentage': 14738.793060795058},
#   'last_updated': '2026-02-23T18:28:18.111Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 8.53,
#   'market_cap': 1441016746813,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 1441283986417,
#   'total_volume': 93180325836,
#   'high_24h': 8.85,
#   'low_24h': 8.34,
#   'price_change_24h': -0.1013541053416187,
#   'price_change_percentage_24h': -1.17448,
#   'market_cap_change_24h': -13158839461.050537,
#   'market_cap_change_percentage_24h': -0.9049,
#   'circulating_supply': 168830643126.5791,
#   'total_supply': 168861953126.579,
#   'max_supply': None,
#   'ath': 53.62,
#   'ath_change_percentage': -84.09417,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 0.00552883,
#   'atl_change_percentage': 154152.11028,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.103Z'},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'image': 'https://coin-images.coingecko.com/coins/images/68480/large/figure.png?1755863954',
#   'current_price': 94.17,
#   'market_cap': 1433902804106,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 1433902804106,
#   'total_volume': 355571838,
#   'high_24h': 94.48,
#   'low_24h': 92.37,
#   'price_change_24h': 1.8,
#   'price_change_percentage_24h': 1.94996,
#   'market_cap_change_24h': 27634314295,
#   'market_cap_change_percentage_24h': 1.96508,
#   'circulating_supply': 15224003657.427,
#   'total_supply': 15224003657.427,
#   'max_supply': None,
#   'ath': 120.96,
#   'ath_change_percentage': -22.13595,
#   'ath_date': '2025-10-28T06:00:43.161Z',
#   'atl': 13.78,
#   'atl_change_percentage': 583.2639,
#   'atl_date': '2025-10-31T14:57:19.271Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:17.798Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 47932,
#   'market_cap': 958722778613,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 958722928420,
#   'total_volume': 35019957311,
#   'high_24h': 51965,
#   'low_24h': 47934,
#   'price_change_24h': -3792.8790165125756,
#   'price_change_percentage_24h': -7.33285,
#   'market_cap_change_24h': -76252975014.33667,
#   'market_cap_change_percentage_24h': -7.36761,
#   'circulating_supply': 19999131.14665078,
#   'total_supply': 19999134.27165078,
#   'max_supply': 21000000.0,
#   'ath': 242198,
#   'ath_change_percentage': -80.20974,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 5536.54,
#   'atl_change_percentage': 765.73224,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.069Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 4397.99,
#   'market_cap': 939602499188,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 1408070381420,
#   'total_volume': 6944158536,
#   'high_24h': 4574.56,
#   'low_24h': 4375.5,
#   'price_change_24h': -155.2869190369056,
#   'price_change_percentage_24h': -3.41044,
#   'market_cap_change_24h': -32987239311.31775,
#   'market_cap_change_percentage_24h': -3.39169,
#   'circulating_supply': 213606247.0,
#   'total_supply': 320106247.0,
#   'max_supply': 400000000.0,
#   'ath': 5758.63,
#   'ath_change_percentage': -23.64942,
#   'ath_date': '2025-12-10T20:16:13.582Z',
#   'atl': 245.71,
#   'atl_change_percentage': 1689.4229,
#   'atl_date': '2022-09-21T23:38:03.675Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:17.817Z'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683',
#   'current_price': 90.96,
#   'market_cap': 899649613562,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 899443372954,
#   'total_volume': 1315231677,
#   'high_24h': 91.05,
#   'low_24h': 90.6,
#   'price_change_24h': 0.238008,
#   'price_change_percentage_24h': 0.26235,
#   'market_cap_change_24h': 2070034270,
#   'market_cap_change_percentage_24h': 0.23062,
#   'circulating_supply': 9890911420.053265,
#   'total_supply': 9888643973.312433,
#   'max_supply': None,
#   'ath': 92.23,
#   'ath_change_percentage': -1.36444,
#   'ath_date': '2026-01-29T16:30:24.390Z',
#   'atl': 79.67,
#   'atl_change_percentage': 14.1848,
#   'atl_date': '2024-10-03T13:19:28.826Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:17.850Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 24.01,
#   'market_cap': 884315341107,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 1080971017844,
#   'total_volume': 41125218958,
#   'high_24h': 24.9,
#   'low_24h': 23.5,
#   'price_change_24h': -0.4665433654369906,
#   'price_change_percentage_24h': -1.90578,
#   'market_cap_change_24h': -16978088448.307617,
#   'market_cap_change_percentage_24h': -1.88375,
#   'circulating_supply': 36813373987.7429,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 225.26,
#   'ath_change_percentage': -89.33951,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 1.38,
#   'atl_change_percentage': 1645.94837,
#   'atl_date': '2017-11-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.231Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 735.3,
#   'market_cap': 677433689245,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 724443070443,
#   'total_volume': 300014683,
#   'high_24h': 756.74,
#   'low_24h': 719.94,
#   'price_change_24h': -5.6498391565579595,
#   'price_change_percentage_24h': -0.76252,
#   'market_cap_change_24h': -5208942110.312256,
#   'market_cap_change_percentage_24h': -0.76306,
#   'circulating_supply': 921306944.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 888.26,
#   'ath_change_percentage': -17.20428,
#   'ath_date': '2025-12-01T06:16:28.002Z',
#   'atl': 56.97,
#   'atl_change_percentage': 1190.84283,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:17.871Z'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'image': 'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300',
#   'current_price': 2372.0,
#   'market_cap': 565477499788,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 2282625126576,
#   'total_volume': 24114773632,
#   'high_24h': 2631.88,
#   'low_24h': 2355.57,
#   'price_change_24h': -248.16401694691922,
#   'price_change_percentage_24h': -9.47132,
#   'market_cap_change_24h': -60133986254.62561,
#   'market_cap_change_percentage_24h': -9.61203,
#   'circulating_supply': 238385315.9541414,
#   'total_supply': 962274028.9541414,
#   'max_supply': 1000000000.0,
#   'ath': 5213.52,
#   'ath_change_percentage': -54.50297,
#   'ath_date': '2025-09-18T03:30:30.650Z',
#   'atl': 321.88,
#   'atl_change_percentage': 636.9217,
#   'atl_date': '2024-11-29T09:30:30.871Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:17.684Z'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059',
#   'current_price': 90.9,
#   'market_cap': 556733473323,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 556625465165,
#   'total_volume': 13165780898,
#   'high_24h': 90.95,
#   'low_24h': 90.59,
#   'price_change_24h': 0.310237,
#   'price_change_percentage_24h': 0.34247,
#   'market_cap_change_24h': -1797826767.68396,
#   'market_cap_change_percentage_24h': -0.32188,
#   'circulating_supply': 6123353022.934256,
#   'total_supply': 6120331186.490956,
#   'max_supply': None,
#   'ath': 92.91,
#   'ath_change_percentage': -2.14308,
#   'ath_date': '2025-12-09T17:10:12.652Z',
#   'atl': 78.05,
#   'atl_change_percentage': 16.49924,
#   'atl_date': '2024-10-04T07:57:15.809Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:17.980Z'},
#  {'id': 'canton-network',
#   'symbol': 'cc',
#   'name': 'Canton',
#   'image': 'https://coin-images.coingecko.com/coins/images/70468/large/Canton-Ticker_%281%29.png?1762826299',
#   'current_price': 14.35,
#   'market_cap': 542881188586,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 542881188586,
#   'total_volume': 785177051,
#   'high_24h': 14.78,
#   'low_24h': 14.35,
#   'price_change_24h': -0.07417416511207797,
#   'price_change_percentage_24h': -0.51432,
#   'market_cap_change_24h': -2082034472.104187,
#   'market_cap_change_percentage_24h': -0.38205,
#   'circulating_supply': 37818276872.86908,
#   'total_supply': 37818276872.86908,
#   'max_supply': None,
#   'ath': 17.72,
#   'ath_change_percentage': -19.02746,
#   'ath_date': '2026-01-31T16:41:41.560Z',
#   'atl': 5.31,
#   'atl_change_percentage': 170.32102,
#   'atl_date': '2025-12-06T10:32:09.784Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.007Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://coin-images.coingecko.com/coins/images/877/large/Chainlink_Logo_500.png?1760023405',
#   'current_price': 753.69,
#   'market_cap': 533779363471,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 753819214439,
#   'total_volume': 33829055614,
#   'high_24h': 788.45,
#   'low_24h': 743.23,
#   'price_change_24h': -29.703597409708664,
#   'price_change_percentage_24h': -3.79164,
#   'market_cap_change_24h': -21038121029.264465,
#   'market_cap_change_percentage_24h': -3.7919,
#   'circulating_supply': 708099970.4525867,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 3862.15,
#   'ath_change_percentage': -80.48517,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 9.55,
#   'atl_change_percentage': 7794.82762,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.475Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 28406,
#   'market_cap': 523569358466,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 523569358466,
#   'total_volume': 7728676142,
#   'high_24h': 29780,
#   'low_24h': 27947,
#   'price_change_24h': -794.9355415626378,
#   'price_change_percentage_24h': -2.72227,
#   'market_cap_change_24h': -14286571987.929016,
#   'market_cap_change_percentage_24h': -2.65621,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'max_supply': None,
#   'ath': 72026,
#   'ath_change_percentage': -60.56101,
#   'ath_date': '2026-01-14T19:34:07.049Z',
#   'atl': 13.57,
#   'atl_change_percentage': 209217.93865,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:17.888Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350',
#   'current_price': 13.74,
#   'market_cap': 451703708562,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 687368034846,
#   'total_volume': 9089342332,
#   'high_24h': 14.27,
#   'low_24h': 13.59,
#   'price_change_24h': -0.33663227443331145,
#   'price_change_percentage_24h': -2.39091,
#   'market_cap_change_24h': -9773159472.403015,
#   'market_cap_change_percentage_24h': -2.1178,
#   'circulating_supply': 32858660026.50742,
#   'total_supply': 50001786883.65895,
#   'max_supply': None,
#   'ath': 58.01,
#   'ath_change_percentage': -76.26933,
#   'ath_date': '2021-05-16T09:48:45.220Z',
#   'atl': 0.02966141,
#   'atl_change_percentage': 46308.72475,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.468Z'},
#  {'id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'name': 'USD1',
#   'image': 'https://coin-images.coingecko.com/coins/images/54977/large/USD1_1000x1000_transparent.png?1749297002',
#   'current_price': 90.92,
#   'market_cap': 437039854624,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 437039854624,
#   'total_volume': 423620650528,
#   'high_24h': 90.93,
#   'low_24h': 90.38,
#   'price_change_24h': 0.268967,
#   'price_change_percentage_24h': 0.2967,
#   'market_cap_change_24h': -19450387420.636963,
#   'market_cap_change_percentage_24h': -4.26086,
#   'circulating_supply': 4806977895.469311,
#   'total_supply': 4806977895.469311,
#   'max_supply': None,
#   'ath': 92.17,
#   'ath_change_percentage': -1.35562,
#   'ath_date': '2026-01-28T15:56:38.616Z',
#   'atl': 83.75,
#   'atl_change_percentage': 8.55999,
#   'atl_date': '2025-05-02T03:46:49.689Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.973Z'},
#  {'id': 'rain',
#   'symbol': 'rain',
#   'name': 'Rain',
#   'image': 'https://coin-images.coingecko.com/coins/images/69134/large/Rain_logo_1_.png?1762952191',
#   'current_price': 0.851547,
#   'market_cap': 406654213443,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 978468777730,
#   'total_volume': 2655768986,
#   'high_24h': 0.903803,
#   'low_24h': 0.834915,
#   'price_change_24h': -0.0224041545021465,
#   'price_change_percentage_24h': -2.56355,
#   'market_cap_change_24h': -10783009910.38324,
#   'market_cap_change_percentage_24h': -2.58315,
#   'circulating_supply': 477913535471.4499,
#   'total_supply': 1149928999761.049,
#   'max_supply': 1150000000000.0,
#   'ath': 0.989197,
#   'ath_change_percentage': -14.01389,
#   'ath_date': '2026-02-09T17:46:22.209Z',
#   'atl': 0.196087,
#   'atl_change_percentage': 333.77227,
#   'atl_date': '2025-09-14T08:56:57.416Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.116Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 90.95,
#   'market_cap': 380069397512,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 380069397512,
#   'total_volume': 6465339190,
#   'high_24h': 91.05,
#   'low_24h': 90.67,
#   'price_change_24h': 0.232791,
#   'price_change_percentage_24h': 0.25662,
#   'market_cap_change_24h': 745606124,
#   'market_cap_change_percentage_24h': 0.19656,
#   'circulating_supply': 4177042792.17075,
#   'total_supply': 4178836061.116609,
#   'max_supply': None,
#   'ath': 92.29,
#   'ath_change_percentage': -1.47696,
#   'ath_date': '2026-01-31T18:56:20.998Z',
#   'atl': 64.85,
#   'atl_change_percentage': 40.21243,
#   'atl_date': '2019-11-25T00:04:18.137Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.108Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 8.63,
#   'market_cap': 371421703415,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 431851338639,
#   'total_volume': 9024274528,
#   'high_24h': 8.92,
#   'low_24h': 8.51,
#   'price_change_24h': -0.18662474123139283,
#   'price_change_percentage_24h': -2.11593,
#   'market_cap_change_24h': -8071986135.543335,
#   'market_cap_change_percentage_24h': -2.12704,
#   'circulating_supply': 43003421569.21756,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 41.81,
#   'ath_change_percentage': -79.33308,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.703644,
#   'atl_change_percentage': 1127.88699,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.743Z'},
#  {'id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'name': 'PayPal USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/31212/large/PYUSD_Token_Logo_2x.png?1765987788',
#   'current_price': 90.95,
#   'market_cap': 370410232363,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 370410232363,
#   'total_volume': 10554611591,
#   'high_24h': 91.02,
#   'low_24h': 90.65,
#   'price_change_24h': 0.23279,
#   'price_change_percentage_24h': 0.2566,
#   'market_cap_change_24h': 340781834,
#   'market_cap_change_percentage_24h': 0.09209,
#   'circulating_supply': 4072620294.82134,
#   'total_supply': 4072620294.82134,
#   'max_supply': None,
#   'ath': 92.2,
#   'ath_change_percentage': -1.3392,
#   'ath_date': '2026-01-28T19:05:21.799Z',
#   'atl': 80.95,
#   'atl_change_percentage': 12.36771,
#   'atl_date': '2023-08-25T16:10:42.670Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:17.976Z'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'image': 'https://coin-images.coingecko.com/coins/images/486/large/circle-zcash-color.png?1696501740',
#   'current_price': 21906,
#   'market_cap': 363316127964,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 363345424443,
#   'total_volume': 31031114800,
#   'high_24h': 22725,
#   'low_24h': 21035,
#   'price_change_24h': -139.67253656958928,
#   'price_change_percentage_24h': -0.63357,
#   'market_cap_change_24h': -2028293322.0269775,
#   'market_cap_change_percentage_24h': -0.55517,
#   'circulating_supply': 16567439.2280448,
#   'total_supply': 16568775.1655448,
#   'max_supply': 21000000.0,
#   'ath': 211171,
#   'ath_change_percentage': -89.62663,
#   'ath_date': '2016-10-29T00:00:00.000Z',
#   'atl': 1342.38,
#   'atl_change_percentage': 1531.84129,
#   'atl_date': '2024-07-05T04:22:29.321Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.681Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 4685.73,
#   'market_cap': 360313103918,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 360318229943,
#   'total_volume': 27011454825,
#   'high_24h': 4855.07,
#   'low_24h': 4631.93,
#   'price_change_24h': -150.3687648592704,
#   'price_change_percentage_24h': -3.1093,
#   'market_cap_change_24h': -11471815212.437439,
#   'market_cap_change_percentage_24h': -3.08561,
#   'circulating_supply': 76880701.98347135,
#   'total_supply': 76881795.73347135,
#   'max_supply': 84000000.0,
#   'ath': 30082,
#   'ath_change_percentage': -84.4077,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 72.12,
#   'atl_change_percentage': 6403.50318,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.251Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 768.15,
#   'market_cap': 331745121885,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 356077571382,
#   'total_volume': 26379222433,
#   'high_24h': 805.92,
#   'low_24h': 758.04,
#   'price_change_24h': -32.06231502218611,
#   'price_change_percentage_24h': -4.00672,
#   'market_cap_change_24h': -13683117326.298035,
#   'market_cap_change_percentage_24h': -3.9612,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'max_supply': 720000000.0,
#   'ath': 10772.35,
#   'ath_change_percentage': -92.87189,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 204.63,
#   'atl_change_percentage': 275.24662,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.273Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://coin-images.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 0.00055021,
#   'market_cap': 324359924842,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 324501142891,
#   'total_volume': 10260492080,
#   'high_24h': 0.00056592,
#   'low_24h': 0.00053834,
#   'price_change_24h': -9.205713984289e-06,
#   'price_change_percentage_24h': -1.64561,
#   'market_cap_change_24h': -5487468236.368286,
#   'market_cap_change_percentage_24h': -1.66364,
#   'circulating_supply': 589243858474311.2,
#   'total_supply': 589500400241439.5,
#   'max_supply': None,
#   'ath': 0.00645756,
#   'ath_change_percentage': -91.47966,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 4.169e-09,
#   'atl_change_percentage': 13197463.79555,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.119Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://coin-images.coingecko.com/coins/images/26375/large/sui-ocean-square.png?1727791290',
#   'current_price': 80.03,
#   'market_cap': 307997365642,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 800789261129,
#   'total_volume': 51772379039,
#   'high_24h': 84.01,
#   'low_24h': 78.61,
#   'price_change_24h': -3.5193730880392025,
#   'price_change_percentage_24h': -4.21245,
#   'market_cap_change_24h': -13361091948.53363,
#   'market_cap_change_percentage_24h': -4.15769,
#   'circulating_supply': 3846172527.429665,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 458.6,
#   'ath_change_percentage': -82.54945,
#   'ath_date': '2025-01-04T22:56:18.063Z',
#   'atl': 30.36,
#   'atl_change_percentage': 163.56427,
#   'atl_date': '2023-10-19T22:05:15.703Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.330Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/17980/large/photo_2024-09-10_17.09.00.jpeg?1725963446',
#   'current_price': 122.96,
#   'market_cap': 301470569700,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 633871068966,
#   'total_volume': 8691334096,
#   'high_24h': 125.41,
#   'low_24h': 118.81,
#   'price_change_24h': 2.02,
#   'price_change_percentage_24h': 1.66864,
#   'market_cap_change_24h': 5013617884,
#   'market_cap_change_percentage_24h': 1.69118,
#   'circulating_supply': 2451718045.107024,
#   'total_supply': 5154974628.543455,
#   'max_supply': None,
#   'ath': 689.6,
#   'ath_change_percentage': -82.16278,
#   'ath_date': '2024-06-15T00:36:51.509Z',
#   'atl': 38.25,
#   'atl_change_percentage': 221.54597,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.227Z'},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'image': 'https://coin-images.coingecko.com/coins/images/50767/large/wlfi.png?1756438915',
#   'current_price': 10.25,
#   'market_cap': 283596637015,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 1025269398657,
#   'total_volume': 33133726429,
#   'high_24h': 10.85,
#   'low_24h': 9.95,
#   'price_change_24h': -0.005763183688351603,
#   'price_change_percentage_24h': -0.05618,
#   'market_cap_change_24h': 3771684086,
#   'market_cap_change_percentage_24h': 1.34787,
#   'circulating_supply': 27660694583.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 29.22,
#   'ath_change_percentage': -64.91257,
#   'ath_date': '2025-09-01T12:20:09.597Z',
#   'atl': 8.91,
#   'atl_change_percentage': 15.11402,
#   'atl_date': '2026-02-08T17:02:14.734Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.837Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://coin-images.coingecko.com/coins/images/7310/large/cro_token_logo.png?1696507599',
#   'current_price': 6.73,
#   'market_cap': 276018706650,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 661719836512,
#   'total_volume': 1243441445,
#   'high_24h': 6.89,
#   'low_24h': 6.65,
#   'price_change_24h': -0.13730426999166845,
#   'price_change_percentage_24h': -1.99957,
#   'market_cap_change_24h': -5840430899.547119,
#   'market_cap_change_percentage_24h': -2.07211,
#   'circulating_supply': 41053247711.30286,
#   'total_supply': 98419953826.86824,
#   'max_supply': 100000000000.0,
#   'ath': 72.06,
#   'ath_change_percentage': -90.67567,
#   'ath_date': '2021-11-24T15:53:54.855Z',
#   'atl': 0.864137,
#   'atl_change_percentage': 677.56798,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.016Z'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/10481/large/Tether_Gold.png?1696510471',
#   'current_price': 471716,
#   'market_cap': 245816899003,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 336399103969,
#   'total_volume': 43371544915,
#   'high_24h': 472696,
#   'low_24h': 462886,
#   'price_change_24h': 7823.11,
#   'price_change_percentage_24h': 1.6864,
#   'market_cap_change_24h': 4156974867,
#   'market_cap_change_percentage_24h': 1.72018,
#   'circulating_supply': 520825.641697,
#   'total_supply': 712747.089,
#   'max_supply': None,
#   'ath': 514631,
#   'ath_change_percentage': -8.24462,
#   'ath_date': '2026-01-29T06:25:57.628Z',
#   'atl': 108167,
#   'atl_change_percentage': 336.55039,
#   'atl_date': '2020-03-17T09:39:32.572Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.090Z'},
#  {'id': 'memecore',
#   'symbol': 'm',
#   'name': 'MemeCore',
#   'image': 'https://coin-images.coingecko.com/coins/images/53247/large/square-bg-transparent.png?1752637478',
#   'current_price': 126.26,
#   'market_cap': 219573877677,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 674126277628,
#   'total_volume': 1042972764,
#   'high_24h': 129.71,
#   'low_24h': 121.44,
#   'price_change_24h': 0.897575,
#   'price_change_percentage_24h': 0.71598,
#   'market_cap_change_24h': 1614943775,
#   'market_cap_change_percentage_24h': 0.74094,
#   'circulating_supply': 1739006001.319395,
#   'total_supply': 5339021448.471307,
#   'max_supply': 10000000000.0,
#   'ath': 260.79,
#   'ath_change_percentage': -51.60609,
#   'ath_date': '2025-09-18T07:27:06.144Z',
#   'atl': 4.05,
#   'atl_change_percentage': 3014.8267,
#   'atl_date': '2025-07-04T03:56:17.448Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:17.972Z'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/9519/large/paxgold.png?1696509604',
#   'current_price': 475292,
#   'market_cap': 218479101912,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 218479101912,
#   'total_volume': 34244871723,
#   'high_24h': 476082,
#   'low_24h': 466795,
#   'price_change_24h': 8089.45,
#   'price_change_percentage_24h': 1.73146,
#   'market_cap_change_24h': 4026906321,
#   'market_cap_change_percentage_24h': 1.87776,
#   'circulating_supply': 459417.25,
#   'total_supply': 459417.25,
#   'max_supply': None,
#   'ath': 516779,
#   'ath_change_percentage': -7.94765,
#   'ath_date': '2026-01-29T06:30:56.612Z',
#   'atl': 100361,
#   'atl_change_percentage': 373.99602,
#   'atl_date': '2019-10-26T15:58:49.353Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.050Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669',
#   'current_price': 304.66,
#   'market_cap': 193114701256,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 273861461308,
#   'total_volume': 21485870804,
#   'high_24h': 321.5,
#   'low_24h': 298.59,
#   'price_change_24h': -9.231423241408493,
#   'price_change_percentage_24h': -2.94097,
#   'market_cap_change_24h': -5874655103.315918,
#   'market_cap_change_percentage_24h': -2.95225,
#   'circulating_supply': 633684762.0380214,
#   'total_supply': 898646420.0366304,
#   'max_supply': 1000000000.0,
#   'ath': 3333.06,
#   'ath_change_percentage': -90.85272,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 75.81,
#   'atl_change_percentage': 302.18046,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.805Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.jpg?1766533446',
#   'current_price': 115.73,
#   'market_cap': 193080644696,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 193080644696,
#   'total_volume': 11887667206,
#   'high_24h': 119.34,
#   'low_24h': 113.02,
#   'price_change_24h': -3.161846245359726,
#   'price_change_percentage_24h': -2.65953,
#   'market_cap_change_24h': -5103105533.286926,
#   'market_cap_change_percentage_24h': -2.57494,
#   'circulating_supply': 1668295422.743435,
#   'total_supply': 1668295422.742343,
#   'max_supply': 2100000000.0,
#   'ath': 4095.22,
#   'ath_change_percentage': -97.17279,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 103.91,
#   'atl_change_percentage': 11.42016,
#   'atl_date': '2026-02-06T00:25:45.413Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.544Z'},
#  {'id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/36291/large/blackrock.png?1711013223',
#   'current_price': 90.99,
#   'market_cap': 176588295524,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 176588295524,
#   'total_volume': None,
#   'high_24h': 91.0,
#   'low_24h': 90.69,
#   'price_change_24h': 0.258502,
#   'price_change_percentage_24h': 0.28492,
#   'market_cap_change_24h': 551690076,
#   'market_cap_change_percentage_24h': 0.3134,
#   'circulating_supply': 1940843131.800449,
#   'total_supply': 1940843131.800449,
#   'max_supply': None,
#   'ath': 92.2,
#   'ath_change_percentage': -1.31443,
#   'ath_date': '2026-01-28T16:00:11.347Z',
#   'atl': 83.81,
#   'atl_change_percentage': 8.56716,
#   'atl_date': '2025-05-02T06:30:16.890Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:20:03.501Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://coin-images.coingecko.com/coins/images/30980/large/MNT_Token_Logo.png?1765516974',
#   'current_price': 52.45,
#   'market_cap': 170697515922,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 326357265745,
#   'total_volume': 4261075354,
#   'high_24h': 54.97,
#   'low_24h': 52.36,
#   'price_change_24h': -2.1961255374169966,
#   'price_change_percentage_24h': -4.01867,
#   'market_cap_change_24h': -7054693029.28894,
#   'market_cap_change_percentage_24h': -3.96884,
#   'circulating_supply': 3252944055.63684,
#   'total_supply': 6219316794.889999,
#   'max_supply': 6219316794.89,
#   'ath': 253.43,
#   'ath_change_percentage': -79.2997,
#   'ath_date': '2025-10-09T01:04:46.659Z',
#   'atl': 25.64,
#   'atl_change_percentage': 104.62661,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.052Z'},
#  {'id': 'falcon-finance',
#   'symbol': 'usdf',
#   'name': 'Falcon USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/54558/large/ff_200_X_200.png?1740741076',
#   'current_price': 90.73,
#   'market_cap': 159386390474,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 159386390474,
#   'total_volume': 406075839,
#   'high_24h': 90.8,
#   'low_24h': 90.41,
#   'price_change_24h': 0.281608,
#   'price_change_percentage_24h': 0.31136,
#   'market_cap_change_24h': 587273709,
#   'market_cap_change_percentage_24h': 0.36982,
#   'circulating_supply': 1755749524.542127,
#   'total_supply': 1755749524.542127,
#   'max_supply': None,
#   'ath': 92.45,
#   'ath_change_percentage': -1.83954,
#   'ath_date': '2025-05-08T21:25:42.071Z',
#   'atl': 80.47,
#   'atl_change_percentage': 12.77393,
#   'atl_date': '2025-05-13T17:40:35.908Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:16.815Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://coin-images.coingecko.com/coins/images/12645/large/aave-token-round.png?1720472354',
#   'current_price': 10458.72,
#   'market_cap': 159011126292,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 167482552439,
#   'total_volume': 32212589111,
#   'high_24h': 10855.4,
#   'low_24h': 10127.67,
#   'price_change_24h': -223.94289048789688,
#   'price_change_percentage_24h': -2.09632,
#   'market_cap_change_24h': -3379803611.7205505,
#   'market_cap_change_percentage_24h': -2.08128,
#   'circulating_supply': 15190704.844337257,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 48387,
#   'ath_change_percentage': -78.37348,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 1933.39,
#   'atl_change_percentage': 441.25111,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.428Z'},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'image': 'https://coin-images.coingecko.com/coins/images/69040/large/_ASTER.png?1757326782',
#   'current_price': 63.24,
#   'market_cap': 155306450798,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 494902610466,
#   'total_volume': 14503192726,
#   'high_24h': 64.41,
#   'low_24h': 60.91,
#   'price_change_24h': 0.080009,
#   'price_change_percentage_24h': 0.12669,
#   'market_cap_change_24h': -117631441.87908936,
#   'market_cap_change_percentage_24h': -0.07568,
#   'circulating_supply': 2454947754.91,
#   'total_supply': 7822985112.446448,
#   'max_supply': 8000000000.0,
#   'ath': 213.7,
#   'ath_change_percentage': -70.40959,
#   'ath_date': '2025-09-24T11:18:14.634Z',
#   'atl': 8.76,
#   'atl_change_percentage': 621.88146,
#   'atl_date': '2025-09-17T12:05:36.771Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.089Z'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'image': 'https://coin-images.coingecko.com/coins/images/29850/large/pepe-token.jpeg?1696528776',
#   'current_price': 0.00036664,
#   'market_cap': 154292062831,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 154292062831,
#   'total_volume': 30842135246,
#   'high_24h': 0.00038068,
#   'low_24h': 0.00035198,
#   'price_change_24h': -1.683008668533e-06,
#   'price_change_percentage_24h': -0.45694,
#   'market_cap_change_24h': -503873406.0914917,
#   'market_cap_change_percentage_24h': -0.32551,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'max_supply': 420690000000000.0,
#   'ath': 0.00237833,
#   'ath_change_percentage': -84.58419,
#   'ath_date': '2024-12-09T16:30:35.828Z',
#   'atl': 4.52e-06,
#   'atl_change_percentage': 8010.84392,
#   'atl_date': '2023-04-18T02:14:41.591Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.578Z'},
#  {'id': 'global-dollar',
#   'symbol': 'usdg',
#   'name': 'Global Dollar',
#   'image': 'https://coin-images.coingecko.com/coins/images/51281/large/GDN_USDG_Token_200x200.png?1730484111',
#   'current_price': 90.96,
#   'market_cap': 147999681993,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 147999681993,
#   'total_volume': 3223368370,
#   'high_24h': 91.0,
#   'low_24h': 90.67,
#   'price_change_24h': 0.241596,
#   'price_change_percentage_24h': 0.26631,
#   'market_cap_change_24h': 375862063,
#   'market_cap_change_percentage_24h': 0.25461,
#   'circulating_supply': 1627147250.164927,
#   'total_supply': 1627147250.164927,
#   'max_supply': None,
#   'ath': 143.35,
#   'ath_change_percentage': -36.54036,
#   'ath_date': '2025-01-30T00:11:05.728Z',
#   'atl': 76.61,
#   'atl_change_percentage': 18.74266,
#   'atl_date': '2024-11-11T23:55:50.604Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.036Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'image': 'https://coin-images.coingecko.com/coins/images/28452/large/ARUsPeNQ_400x400.jpeg?1696527447',
#   'current_price': 15304.09,
#   'market_cap': 147016609346,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 321682906113,
#   'total_volume': 7713705780,
#   'high_24h': 15890.74,
#   'low_24h': 15018.34,
#   'price_change_24h': -451.1751972795919,
#   'price_change_percentage_24h': -2.86365,
#   'market_cap_change_24h': -4327566332.977875,
#   'market_cap_change_percentage_24h': -2.85942,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 62722,
#   'ath_change_percentage': -75.54001,
#   'ath_date': '2024-12-06T12:15:28.199Z',
#   'atl': 2535.93,
#   'atl_change_percentage': 504.97816,
#   'atl_date': '2023-05-14T08:57:53.732Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.212Z'},
#  {'id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'name': 'Circle USYC',
#   'image': 'https://coin-images.coingecko.com/coins/images/51054/large/Hashnote_SDYC_200x200.png?1730370965',
#   'current_price': 101.11,
#   'market_cap': 144003304098,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 157079061190,
#   'total_volume': 4044.32,
#   'high_24h': None,
#   'low_24h': None,
#   'price_change_24h': None,
#   'price_change_percentage_24h': None,
#   'market_cap_change_24h': None,
#   'market_cap_change_percentage_24h': None,
#   'circulating_supply': 1553577376.229146,
#   'total_supply': 1553577376.229146,
#   'max_supply': None,
#   'ath': 102.4,
#   'ath_change_percentage': -1.25715,
#   'ath_date': '2026-01-30T13:28:05.498Z',
#   'atl': 86.89,
#   'atl_change_percentage': 16.3626,
#   'atl_date': '2024-12-05T22:31:20.475Z',
#   'roi': None,
#   'last_updated': '2026-02-10T05:42:11.457Z'},
#  {'id': 'bitget-token',
#   'symbol': 'bgb',
#   'name': 'Bitget Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/11610/large/Bitget_logo.png?1736925727',
#   'current_price': 203.47,
#   'market_cap': 142445212509,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 186591434572,
#   'total_volume': 1866229380,
#   'high_24h': 207.59,
#   'low_24h': 201.45,
#   'price_change_24h': -3.6854963094802144,
#   'price_change_percentage_24h': -1.77912,
#   'market_cap_change_24h': -2613930255.0797424,
#   'market_cap_change_percentage_24h': -1.80198,
#   'circulating_supply': 699992035.9787906,
#   'total_supply': 916931610.9787906,
#   'max_supply': 2000000000.0,
#   'ath': 722.65,
#   'ath_change_percentage': -71.85256,
#   'ath_date': '2024-12-27T11:41:24.992Z',
#   'atl': 1.081,
#   'atl_change_percentage': 18714.53688,
#   'atl_date': '2020-06-25T04:17:05.895Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.250Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://coin-images.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 6765.83,
#   'market_cap': 142040061130,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 142040061130,
#   'total_volume': 1343312022,
#   'high_24h': 7048.39,
#   'low_24h': 6723.07,
#   'price_change_24h': -261.299046360331,
#   'price_change_percentage_24h': -3.71843,
#   'market_cap_change_24h': -5559854599.151825,
#   'market_cap_change_percentage_24h': -3.76684,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 22313,
#   'ath_change_percentage': -69.70455,
#   'ath_date': '2025-08-22T01:56:37.898Z',
#   'atl': 40.86,
#   'atl_change_percentage': 16443.12399,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.320Z'},
#  {'id': 'ripple-usd',
#   'symbol': 'rlusd',
#   'name': 'Ripple USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/39651/large/RLUSD_200x200_%281%29.png?1727376633',
#   'current_price': 90.96,
#   'market_cap': 141751060587,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 141751060587,
#   'total_volume': 7757259699,
#   'high_24h': 90.99,
#   'low_24h': 90.67,
#   'price_change_24h': 0.237946,
#   'price_change_percentage_24h': 0.26228,
#   'market_cap_change_24h': 368118597,
#   'market_cap_change_percentage_24h': 0.26037,
#   'circulating_supply': 1558420717.127497,
#   'total_supply': 1558420717.127497,
#   'max_supply': None,
#   'ath': 92.15,
#   'ath_change_percentage': -1.27512,
#   'ath_date': '2026-01-28T19:15:21.035Z',
#   'atl': 81.72,
#   'atl_change_percentage': 11.32984,
#   'atl_date': '2024-12-18T04:40:40.880Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.685Z'},
#  {'id': 'htx-dao',
#   'symbol': 'htx',
#   'name': 'HTX DAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/35491/large/Frame_1321318576.png?1708908626',
#   'current_price': 0.00015072,
#   'market_cap': 138141858466,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 138141858466,
#   'total_volume': 6867439226,
#   'high_24h': 0.00015441,
#   'low_24h': 0.00015072,
#   'price_change_24h': -3.257659828937e-06,
#   'price_change_percentage_24h': -2.11566,
#   'market_cap_change_24h': -2984620791.836914,
#   'market_cap_change_percentage_24h': -2.11486,
#   'circulating_supply': 916533066327098.8,
#   'total_supply': 916533066327098.8,
#   'max_supply': 999990000000000.0,
#   'ath': 0.00031771,
#   'ath_change_percentage': -52.55215,
#   'ath_date': '2024-12-04T00:16:20.770Z',
#   'atl': 6.739e-05,
#   'atl_change_percentage': 123.68085,
#   'atl_date': '2024-08-05T13:31:33.427Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:18.013Z'},
#  {'id': 'pi-network',
#   'symbol': 'pi',
#   'name': 'Pi Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/54342/large/pi_network.jpg?1739347576',
#   'current_price': 14.55,
#   'market_cap': 134000531329,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 206154663584,
#   'total_volume': 1409478886,
#   'high_24h': 14.88,
#   'low_24h': 14.21,
#   'price_change_24h': -0.1823256560003319,
#   'price_change_percentage_24h': -1.23791,
#   'market_cap_change_24h': -1474344152.1321564,
#   'market_cap_change_percentage_24h': -1.08828,
#   'circulating_supply': 9212524148.819681,
#   'total_supply': 14173114075.1072,
#   'max_supply': 100000000000.0,
#   'ath': 260.4,
#   'ath_change_percentage': -94.42554,
#   'ath_date': '2025-02-26T16:41:03.732Z',
#   'atl': 11.91,
#   'atl_change_percentage': 21.92832,
#   'atl_date': '2026-02-11T17:06:46.605Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:20.943Z'},
#  {'id': 'sky',
#   'symbol': 'sky',
#   'name': 'Sky',
#   'image': 'https://coin-images.coingecko.com/coins/images/39925/large/sky.jpg?1724827980',
#   'current_price': 5.72,
#   'market_cap': 131871438139,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': 134291070485,
#   'total_volume': 1073534269,
#   'high_24h': 5.86,
#   'low_24h': 5.56,
# ...
#   'name': 'Amp',
#   'image': 'https://coin-images.coingecko.com/coins/images/12409/large/amp-200x200.png?1696512231',
#   'current_price': 0.131302,
#   'market_cap': 11065747195,
#   'market_cap_rank': 233,
#   'fully_diluted_valuation': 13092646871,
#   'total_volume': 757167935,
#   'high_24h': 0.138907,
#   'low_24h': 0.13047,
#   'price_change_24h': -0.003753767999536362,
#   'price_change_percentage_24h': -2.77943,
#   'market_cap_change_24h': -319213372.61953354,
#   'market_cap_change_percentage_24h': -2.80382,
#   'circulating_supply': 84282148485.5968,
#   'total_supply': 99720008803.0992,
#   'max_supply': 100000000000.0,
#   'ath': 8.86,
#   'ath_change_percentage': -98.51506,
#   'ath_date': '2021-06-16T16:03:41.147Z',
#   'atl': 0.11691,
#   'atl_change_percentage': 12.47941,
#   'atl_date': '2026-02-06T00:25:58.854Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.513Z'},
#  {'id': 'arweave',
#   'symbol': 'ar',
#   'name': 'Arweave',
#   'image': 'https://coin-images.coingecko.com/coins/images/4343/large/oRt6SiEN_400x400.jpg?1696504946',
#   'current_price': 168.85,
#   'market_cap': 11061104140,
#   'market_cap_rank': 234,
#   'fully_diluted_valuation': 11061104140,
#   'total_volume': 1752434729,
#   'high_24h': 179.27,
#   'low_24h': 167.27,
#   'price_change_24h': -10.294593487786642,
#   'price_change_percentage_24h': -5.7466,
#   'market_cap_change_24h': -669515563.1592712,
#   'market_cap_change_percentage_24h': -5.70742,
#   'circulating_supply': 65454185.5381511,
#   'total_supply': 65454185.5381511,
#   'max_supply': 66000000.0,
#   'ath': 6640.2,
#   'ath_change_percentage': -97.45581,
#   'ath_date': '2021-11-05T04:14:42.689Z',
#   'atl': 21.36,
#   'atl_change_percentage': 690.85596,
#   'atl_date': '2020-01-31T06:47:36.543Z',
#   'roi': {'times': 1.5081671998155959,
#    'currency': 'usd',
#    'percentage': 150.8167199815596},
#   'last_updated': '2026-02-23T18:28:19.082Z'},
#  {'id': 'keeta',
#   'symbol': 'kta',
#   'name': 'Keeta',
#   'image': 'https://coin-images.coingecko.com/coins/images/54723/large/2025-03-05_22.53.06.jpg?1741234207',
#   'current_price': 22.46,
#   'market_cap': 11023778360,
#   'market_cap_rank': 235,
#   'fully_diluted_valuation': 22276598995,
#   'total_volume': 342561649,
#   'high_24h': 23.3,
#   'low_24h': 22.04,
#   'price_change_24h': -0.664766475885564,
#   'price_change_percentage_24h': -2.87444,
#   'market_cap_change_24h': -376408159.32595253,
#   'market_cap_change_percentage_24h': -3.30177,
#   'circulating_supply': 494859128.29340035,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 143.99,
#   'ath_change_percentage': -84.52677,
#   'ath_date': '2025-06-09T08:25:28.951Z',
#   'atl': 0.594085,
#   'atl_change_percentage': 3650.20136,
#   'atl_date': '2025-03-08T15:56:27.362Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.062Z'},
#  {'id': 'pleasing-usd',
#   'symbol': 'pusd',
#   'name': 'Pleasing USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/70448/large/%E7%BE%8E%E5%85%83_%281%29.png?1762079129',
#   'current_price': 91.02,
#   'market_cap': 10922742302,
#   'market_cap_rank': 236,
#   'fully_diluted_valuation': 10922742302,
#   'total_volume': 0.0,
#   'high_24h': 91.37,
#   'low_24h': 90.6,
#   'price_change_24h': 0.425939,
#   'price_change_percentage_24h': 0.47015,
#   'market_cap_change_24h': 51112737,
#   'market_cap_change_percentage_24h': 0.47015,
#   'circulating_supply': 120000000.0,
#   'total_supply': 120000000.0,
#   'max_supply': None,
#   'ath': 95.47,
#   'ath_change_percentage': -4.65366,
#   'ath_date': '2026-02-06T00:52:12.172Z',
#   'atl': 87.56,
#   'atl_change_percentage': 3.95403,
#   'atl_date': '2025-11-20T16:06:08.140Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.025Z'},
#  {'id': 'berachain-bera',
#   'symbol': 'bera',
#   'name': 'Berachain',
#   'image': 'https://coin-images.coingecko.com/coins/images/25235/large/BERA.png?1738822008',
#   'current_price': 50.74,
#   'market_cap': 10898870004,
#   'market_cap_rank': 237,
#   'fully_diluted_valuation': 27080673177,
#   'total_volume': 2483016664,
#   'high_24h': 53.21,
#   'low_24h': 49.8,
#   'price_change_24h': -1.368486353057719,
#   'price_change_percentage_24h': -2.62601,
#   'market_cap_change_24h': -290828330.8835983,
#   'market_cap_change_percentage_24h': -2.59907,
#   'circulating_supply': 214698040.9819136,
#   'total_supply': 533465164.5100173,
#   'max_supply': None,
#   'ath': 1299.39,
#   'ath_change_percentage': -96.09504,
#   'ath_date': '2025-02-06T14:16:01.862Z',
#   'atl': 31.56,
#   'atl_change_percentage': 60.77403,
#   'atl_date': '2026-02-06T00:25:15.713Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.101Z'},
#  {'id': 'cap-usd',
#   'symbol': 'cusd',
#   'name': 'Cap USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/68272/large/cUSD_ab_500%C3%97500.png?1755232868',
#   'current_price': 90.98,
#   'market_cap': 10891367318,
#   'market_cap_rank': 238,
#   'fully_diluted_valuation': 10891367318,
#   'total_volume': 1177219,
#   'high_24h': 94.71,
#   'low_24h': 88.21,
#   'price_change_24h': 2.65,
#   'price_change_percentage_24h': 3.00354,
#   'market_cap_change_24h': 232297700,
#   'market_cap_change_percentage_24h': 2.17934,
#   'circulating_supply': 118370756.016975,
#   'total_supply': 118370756.016975,
#   'max_supply': None,
#   'ath': 103.87,
#   'ath_change_percentage': -11.41719,
#   'ath_date': '2025-10-10T21:42:31.469Z',
#   'atl': 84.14,
#   'atl_change_percentage': 9.34866,
#   'atl_date': '2025-10-02T15:05:38.504Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:20.637Z'},
#  {'id': 'walrus-2',
#   'symbol': 'wal',
#   'name': 'Walrus',
#   'image': 'https://coin-images.coingecko.com/coins/images/54914/large/WAL_logo.png?1742494301',
#   'current_price': 6.71,
#   'market_cap': 10759552952,
#   'market_cap_rank': 239,
#   'fully_diluted_valuation': 33419085130,
#   'total_volume': 708232067,
#   'high_24h': 6.97,
#   'low_24h': 6.51,
#   'price_change_24h': -0.2465676116938189,
#   'price_change_percentage_24h': -3.54643,
#   'market_cap_change_24h': -435965533.76932526,
#   'market_cap_change_percentage_24h': -3.89411,
#   'circulating_supply': 1609791667.0,
#   'total_supply': 5000000000.0,
#   'max_supply': 5000000000.0,
#   'ath': 64.7,
#   'ath_change_percentage': -89.67412,
#   'ath_date': '2025-05-14T08:10:39.605Z',
#   'atl': 6.39,
#   'atl_change_percentage': 4.54546,
#   'atl_date': '2026-02-06T00:25:22.515Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.146Z'},
#  {'id': 'loaded-lions',
#   'symbol': 'lion',
#   'name': 'Loaded Lions',
#   'image': 'https://coin-images.coingecko.com/coins/images/54686/large/_LION_Token_Artwork.png?1741015702',
#   'current_price': 0.345695,
#   'market_cap': 10593001445,
#   'market_cap_rank': 240,
#   'fully_diluted_valuation': 34569476759,
#   'total_volume': 67213972,
#   'high_24h': 0.361671,
#   'low_24h': 0.344893,
#   'price_change_24h': -0.014369777369258707,
#   'price_change_percentage_24h': -3.99089,
#   'market_cap_change_24h': -415716424.3311863,
#   'market_cap_change_percentage_24h': -3.77625,
#   'circulating_supply': 30642643274.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 2.77,
#   'ath_change_percentage': -87.53916,
#   'ath_date': '2025-08-28T02:22:49.420Z',
#   'atl': 0.193689,
#   'atl_change_percentage': 78.07133,
#   'atl_date': '2025-03-04T09:34:06.201Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.079Z'},
#  {'id': 'bitmart-token',
#   'symbol': 'bmx',
#   'name': 'BitMart',
#   'image': 'https://coin-images.coingecko.com/coins/images/5236/large/bitmart-token.png?1696505741',
#   'current_price': 30.81,
#   'market_cap': 10453300681,
#   'market_cap_rank': 241,
#   'fully_diluted_valuation': 19692779329,
#   'total_volume': 451710245,
#   'high_24h': 31.11,
#   'low_24h': 30.75,
#   'price_change_24h': -0.14648019335734475,
#   'price_change_percentage_24h': -0.47318,
#   'market_cap_change_24h': -54408229.06809425,
#   'market_cap_change_percentage_24h': -0.51779,
#   'circulating_supply': 339412030.0,
#   'total_supply': 639412030.0,
#   'max_supply': 881679315.0,
#   'ath': 52.71,
#   'ath_change_percentage': -41.61886,
#   'ath_date': '2025-10-28T16:58:27.513Z',
#   'atl': 0.501523,
#   'atl_change_percentage': 6035.94462,
#   'atl_date': '2020-03-13T02:12:53.990Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.077Z'},
#  {'id': 'cash-4',
#   'symbol': 'cash',
#   'name': 'CASH',
#   'image': 'https://coin-images.coingecko.com/coins/images/69679/large/cash.jpg?1759283906',
#   'current_price': 90.99,
#   'market_cap': 10312413604,
#   'market_cap_rank': 242,
#   'fully_diluted_valuation': 10312413521,
#   'total_volume': 631607186,
#   'high_24h': 91.07,
#   'low_24h': 90.66,
#   'price_change_24h': 0.280324,
#   'price_change_percentage_24h': 0.30904,
#   'market_cap_change_24h': 31221509,
#   'market_cap_change_percentage_24h': 0.30368,
#   'circulating_supply': 113334309.030704,
#   'total_supply': 113334308.114987,
#   'max_supply': None,
#   'ath': 93.86,
#   'ath_change_percentage': -3.05908,
#   'ath_date': '2025-11-15T20:50:58.067Z',
#   'atl': 86.47,
#   'atl_change_percentage': 5.23443,
#   'atl_date': '2025-11-19T06:10:46.512Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.069Z'},
#  {'id': 'frax-usd',
#   'symbol': 'frxusd',
#   'name': 'Frax USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/53963/large/frxUSD.png?1737792154',
#   'current_price': 90.96,
#   'market_cap': 10306220414,
#   'market_cap_rank': 243,
#   'fully_diluted_valuation': 10306227703,
#   'total_volume': 324540304,
#   'high_24h': 90.99,
#   'low_24h': 90.61,
#   'price_change_24h': 0.257351,
#   'price_change_percentage_24h': 0.28372,
#   'market_cap_change_24h': -7622256.787130356,
#   'market_cap_change_percentage_24h': -0.0739,
#   'circulating_supply': 113299988.1259787,
#   'total_supply': 113300068.2525914,
#   'max_supply': None,
#   'ath': 92.17,
#   'ath_change_percentage': -1.32115,
#   'ath_date': '2026-01-28T15:55:49.024Z',
#   'atl': 83.77,
#   'atl_change_percentage': 8.58174,
#   'atl_date': '2025-05-02T06:32:33.156Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.137Z'},
#  {'id': 're-protocol-reusd',
#   'symbol': 'reusd',
#   'name': 'Re Protocol reUSD',
#   'image': 'https://coin-images.coingecko.com/coins/images/66291/large/Points_Program_Group_91.png?1749676055',
#   'current_price': 96.75,
#   'market_cap': 10157458623,
#   'market_cap_rank': 244,
#   'fully_diluted_valuation': 10157458623,
#   'total_volume': 4661847,
#   'high_24h': 96.75,
#   'low_24h': 96.22,
#   'price_change_24h': 0.413312,
#   'price_change_percentage_24h': 0.42905,
#   'market_cap_change_24h': 113717391,
#   'market_cap_change_percentage_24h': 1.13222,
#   'circulating_supply': 104991028.5090223,
#   'total_supply': 104991028.5090223,
#   'max_supply': None,
#   'ath': 98.49,
#   'ath_change_percentage': -1.81862,
#   'ath_date': '2026-01-31T18:55:08.505Z',
#   'atl': 75.07,
#   'atl_change_percentage': 28.8176,
#   'atl_date': '2025-07-17T08:04:08.632Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.077Z'},
#  {'id': 'avant-usd',
#   'symbol': 'avusd',
#   'name': 'Avant USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/53527/large/token-avusd.png?1736579003',
#   'current_price': 90.38,
#   'market_cap': 9976285652,
#   'market_cap_rank': 245,
#   'fully_diluted_valuation': 9976285652,
#   'total_volume': 8430868,
#   'high_24h': 90.99,
#   'low_24h': 90.36,
#   'price_change_24h': -0.11051556458188827,
#   'price_change_percentage_24h': -0.12213,
#   'market_cap_change_24h': -12561050.26197815,
#   'market_cap_change_percentage_24h': -0.12575,
#   'circulating_supply': 110383561.5424455,
#   'total_supply': 110383561.5424455,
#   'max_supply': None,
#   'ath': 93.96,
#   'ath_change_percentage': -3.82842,
#   'ath_date': '2025-10-10T21:48:29.498Z',
#   'atl': 83.81,
#   'atl_change_percentage': 7.81807,
#   'atl_date': '2025-05-02T06:32:03.463Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.098Z'},
#  {'id': 'eigenlayer',
#   'symbol': 'eigen',
#   'name': 'EigenCloud (prev. EigenLayer)',
#   'image': 'https://coin-images.coingecko.com/coins/images/37441/large/eigencloud.jpg?1751003565',
#   'current_price': 16.63,
#   'market_cap': 9931739095,
#   'market_cap_rank': 246,
#   'fully_diluted_valuation': 29939272438,
#   'total_volume': 3633013026,
#   'high_24h': 17.86,
#   'low_24h': 15.48,
#   'price_change_24h': 0.162838,
#   'price_change_percentage_24h': 0.98894,
#   'market_cap_change_24h': 119003480,
#   'market_cap_change_percentage_24h': 1.21275,
#   'circulating_supply': 596583765.388169,
#   'total_supply': 1798404459.966838,
#   'max_supply': None,
#   'ath': 479.53,
#   'ath_change_percentage': -96.52077,
#   'ath_date': '2024-12-17T03:45:30.422Z',
#   'atl': 15.48,
#   'atl_change_percentage': 7.78443,
#   'atl_date': '2026-02-23T02:05:33.374Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.194Z'},
#  {'id': 'livepeer',
#   'symbol': 'lpt',
#   'name': 'Livepeer',
#   'image': 'https://coin-images.coingecko.com/coins/images/7137/large/badge-logo-circuit-green.png?1719357686',
#   'current_price': 199.79,
#   'market_cap': 9927274378,
#   'market_cap_rank': 247,
#   'fully_diluted_valuation': 9927274378,
#   'total_volume': 724186262,
#   'high_24h': 206.57,
#   'low_24h': 196.87,
#   'price_change_24h': -6.229105187952513,
#   'price_change_percentage_24h': -3.02357,
#   'market_cap_change_24h': -312548983.3031807,
#   'market_cap_change_percentage_24h': -3.05229,
#   'circulating_supply': 49688954.55058027,
#   'total_supply': 49688954.55058027,
#   'max_supply': None,
#   'ath': 7340.08,
#   'ath_change_percentage': -97.27507,
#   'ath_date': '2021-11-09T16:58:44.554Z',
#   'atl': 25.08,
#   'atl_change_percentage': 697.46735,
#   'atl_date': '2019-10-26T22:59:09.500Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.269Z'},
#  {'id': 'standx-dusd',
#   'symbol': 'dusd',
#   'name': 'StandX DUSD',
#   'image': 'https://coin-images.coingecko.com/coins/images/55984/large/output-onlinepngtools.png?1747932126',
#   'current_price': 90.89,
#   'market_cap': 9827689135,
#   'market_cap_rank': 248,
#   'fully_diluted_valuation': 9827768486,
#   'total_volume': 67530771,
#   'high_24h': 90.97,
#   'low_24h': 90.59,
#   'price_change_24h': 0.263914,
#   'price_change_percentage_24h': 0.29123,
#   'market_cap_change_24h': 33325402,
#   'market_cap_change_percentage_24h': 0.34025,
#   'circulating_supply': 108127256.163121,
#   'total_supply': 108128129.205731,
#   'max_supply': None,
#   'ath': 92.19,
#   'ath_change_percentage': -1.3896,
#   'ath_date': '2025-11-21T07:46:31.680Z',
#   'atl': 84.63,
#   'atl_change_percentage': 7.41992,
#   'atl_date': '2025-05-26T04:06:25.299Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.116Z'},
#  {'id': 'midas-mf-one',
#   'symbol': 'mf-one',
#   'name': 'Midas mF-ONE',
#   'image': 'https://coin-images.coingecko.com/coins/images/66975/large/mfone-logo.png?1751307469',
#   'current_price': 96.4,
#   'market_cap': 9739146064,
#   'market_cap_rank': 249,
#   'fully_diluted_valuation': 9739146064,
#   'total_volume': None,
#   'high_24h': 96.59,
#   'low_24h': 95.96,
#   'price_change_24h': 0.394619,
#   'price_change_percentage_24h': 0.41104,
#   'market_cap_change_24h': 39166625,
#   'market_cap_change_percentage_24h': 0.40378,
#   'circulating_supply': 101028766.2860154,
#   'total_supply': 101028766.2860154,
#   'max_supply': None,
#   'ath': 97.07,
#   'ath_change_percentage': -0.68357,
#   'ath_date': '2026-01-28T19:05:05.634Z',
#   'atl': 86.94,
#   'atl_change_percentage': 10.88736,
#   'atl_date': '2025-07-21T08:45:11.072Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:25:01.723Z'},
#  {'id': 'seeker',
#   'symbol': 'skr',
#   'name': 'Seeker',
#   'image': 'https://coin-images.coingecko.com/coins/images/70974/large/seeker-logo.jpg?1764922774',
#   'current_price': 1.71,
#   'market_cap': 9719695293,
#   'market_cap_rank': 250,
#   'fully_diluted_valuation': 17052097006,
#   'total_volume': 724003423,
#   'high_24h': 1.82,
#   'low_24h': 1.6,
#   'price_change_24h': 0.00025838,
#   'price_change_percentage_24h': 0.01515,
#   'market_cap_change_24h': -68858.5352344513,
#   'market_cap_change_percentage_24h': -0.00071,
#   'circulating_supply': 5700000000.0,
#   'total_supply': 10000000000.0,
#   'max_supply': None,
#   'ath': 5.11,
#   'ath_change_percentage': -66.63732,
#   'ath_date': '2026-01-22T03:32:20.056Z',
#   'atl': 0.493987,
#   'atl_change_percentage': 244.97828,
#   'atl_date': '2026-01-21T02:11:35.450Z',
#   'roi': None,
#   'last_updated': '2026-02-23T18:28:19.160Z'}]

# %%
print(f"Total Data of Cryptocurrencies: {len(data_crypto)}")
# Out:
# Total Data of Cryptocurrencies: 750

# %%
# following columns for ectracting from collected data
# id, symbol, name, current_price, market_cap, market_cap_rank, total_volume, circulating_supply, total_supply, ath, atl, last_updated(just extract date).

filtered_columns = []

for i in data_crypto:
  filtered_columns.append(dict(
      coin_id = i['id'],
      symbol = i['symbol'],
      coin_name = i['name'],
      current_price = i['current_price'],
      market_cap = i['market_cap'],
      market_cap_rank = i['market_cap_rank'],
      total_volume = i['total_volume'],
      circulating_supply = i['circulating_supply'],
      total_supply = i['total_supply'],
      ath = i['ath'],
      atl = i['atl'],
      last_updated = i['last_updated']
      ))

# %%
filtered_columns
# Out:
# [{'coin_id': 'bitcoin',
#   'symbol': 'btc',
#   'coin_name': 'Bitcoin',
#   'current_price': 5895707,
#   'market_cap': 117892080849959,
#   'market_cap_rank': 1,
#   'total_volume': 4583479474349,
#   'circulating_supply': 19993700.0,
#   'total_supply': 19993731.0,
#   'ath': 11187013,
#   'atl': 3993.42,
#   'last_updated': '2026-02-23T18:28:21.461Z'},
#  {'coin_id': 'ethereum',
#   'symbol': 'eth',
#   'coin_name': 'Ethereum',
#   'current_price': 169178,
#   'market_cap': 20440925651868,
#   'market_cap_rank': 2,
#   'total_volume': 2001022139544,
#   'circulating_supply': 120692355.0689789,
#   'total_supply': 120692355.0689789,
#   'ath': 431946,
#   'atl': 28.13,
#   'last_updated': '2026-02-23T18:28:21.307Z'},
#  {'coin_id': 'tether',
#   'symbol': 'usdt',
#   'coin_name': 'Tether',
#   'current_price': 90.97,
#   'market_cap': 16705159045807,
#   'market_cap_rank': 3,
#   'total_volume': 7545121219116,
#   'circulating_supply': 183624238441.843,
#   'total_supply': 189091175734.4462,
#   'ath': 105.52,
#   'atl': 36.86,
#   'last_updated': '2026-02-23T18:28:18.378Z'},
#  {'coin_id': 'ripple',
#   'symbol': 'xrp',
#   'coin_name': 'XRP',
#   'current_price': 124.14,
#   'market_cap': 7577930067118,
#   'market_cap_rank': 4,
#   'total_volume': 313077098068,
#   'circulating_supply': 61018583977.0,
#   'total_supply': 99985712847.0,
#   'ath': 313.99,
#   'atl': 0.159343,
#   'last_updated': '2026-02-23T18:28:17.907Z'},
#  {'coin_id': 'binancecoin',
#   'symbol': 'bnb',
#   'coin_name': 'BNB',
#   'current_price': 54333,
#   'market_cap': 7415804403755,
#   'market_cap_rank': 5,
#   'total_volume': 132172575655,
#   'circulating_supply': 136359000.53,
#   'total_supply': 136358999.65,
#   'ath': 121422,
#   'atl': 2.58,
#   'last_updated': '2026-02-23T18:28:21.068Z'},
#  {'coin_id': 'usd-coin',
#   'symbol': 'usdc',
#   'coin_name': 'USDC',
#   'current_price': 90.97,
#   'market_cap': 6798842455725,
#   'market_cap_rank': 6,
#   'total_volume': 1174213171678,
#   'circulating_supply': 74743037601.80803,
#   'total_supply': 74751095984.18327,
#   'ath': 1327.87,
#   'atl': 65.31,
#   'last_updated': '2026-02-23T18:28:18.356Z'},
#  {'coin_id': 'solana',
#   'symbol': 'sol',
#   'coin_name': 'Solana',
#   'current_price': 7126.6,
#   'market_cap': 4051450602339,
#   'market_cap_rank': 7,
#   'total_volume': 443170790479,
#   'circulating_supply': 568474098.3567048,
#   'total_supply': 621064043.7705076,
#   'ath': 25396,
#   'atl': 38.03,
#   'last_updated': '2026-02-23T18:28:18.163Z'},
#  {'coin_id': 'tron',
#   'symbol': 'trx',
#   'coin_name': 'TRON',
#   'current_price': 25.65,
#   'market_cap': 2429930340801,
#   'market_cap_rank': 8,
#   'total_volume': 57286417590,
#   'circulating_supply': 94735543888.4447,
#   'total_supply': 94735549340.83319,
#   'ath': 36.53,
#   'atl': 0.117589,
#   'last_updated': '2026-02-23T18:28:18.111Z'},
#  {'coin_id': 'dogecoin',
#   'symbol': 'doge',
#   'coin_name': 'Dogecoin',
#   'current_price': 8.53,
#   'market_cap': 1441016746813,
#   'market_cap_rank': 9,
#   'total_volume': 93180325836,
#   'circulating_supply': 168830643126.5791,
#   'total_supply': 168861953126.579,
#   'ath': 53.62,
#   'atl': 0.00552883,
#   'last_updated': '2026-02-23T18:28:18.103Z'},
#  {'coin_id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'coin_name': 'Figure Heloc',
#   'current_price': 94.17,
#   'market_cap': 1433902804106,
#   'market_cap_rank': 10,
#   'total_volume': 355571838,
#   'circulating_supply': 15224003657.427,
#   'total_supply': 15224003657.427,
#   'ath': 120.96,
#   'atl': 13.78,
#   'last_updated': '2026-02-23T18:28:17.798Z'},
#  {'coin_id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'coin_name': 'Bitcoin Cash',
#   'current_price': 47932,
#   'market_cap': 958722778613,
#   'market_cap_rank': 11,
#   'total_volume': 35019957311,
#   'circulating_supply': 19999131.14665078,
#   'total_supply': 19999134.27165078,
#   'ath': 242198,
#   'atl': 5536.54,
#   'last_updated': '2026-02-23T18:28:18.069Z'},
#  {'coin_id': 'whitebit',
#   'symbol': 'wbt',
#   'coin_name': 'WhiteBIT Coin',
#   'current_price': 4397.99,
#   'market_cap': 939602499188,
#   'market_cap_rank': 12,
#   'total_volume': 6944158536,
#   'circulating_supply': 213606247.0,
#   'total_supply': 320106247.0,
#   'ath': 5758.63,
#   'atl': 245.71,
#   'last_updated': '2026-02-23T18:28:17.817Z'},
#  {'coin_id': 'usds',
#   'symbol': 'usds',
#   'coin_name': 'USDS',
#   'current_price': 90.96,
#   'market_cap': 899649613562,
#   'market_cap_rank': 13,
#   'total_volume': 1315231677,
#   'circulating_supply': 9890911420.053265,
#   'total_supply': 9888643973.312433,
#   'ath': 92.23,
#   'atl': 79.67,
#   'last_updated': '2026-02-23T18:28:17.850Z'},
#  {'coin_id': 'cardano',
#   'symbol': 'ada',
#   'coin_name': 'Cardano',
#   'current_price': 24.01,
#   'market_cap': 884315341107,
#   'market_cap_rank': 14,
#   'total_volume': 41125218958,
#   'circulating_supply': 36813373987.7429,
#   'total_supply': 45000000000.0,
#   'ath': 225.26,
#   'atl': 1.38,
#   'last_updated': '2026-02-23T18:28:18.231Z'},
#  {'coin_id': 'leo-token',
#   'symbol': 'leo',
#   'coin_name': 'LEO Token',
#   'current_price': 735.3,
#   'market_cap': 677433689245,
#   'market_cap_rank': 15,
#   'total_volume': 300014683,
#   'circulating_supply': 921306944.9,
#   'total_supply': 985239504.0,
#   'ath': 888.26,
#   'atl': 56.97,
#   'last_updated': '2026-02-23T18:28:17.871Z'},
#  {'coin_id': 'hyperliquid',
#   'symbol': 'hype',
#   'coin_name': 'Hyperliquid',
#   'current_price': 2372.0,
#   'market_cap': 565477499788,
#   'market_cap_rank': 16,
#   'total_volume': 24114773632,
#   'circulating_supply': 238385315.9541414,
#   'total_supply': 962274028.9541414,
#   'ath': 5213.52,
#   'atl': 321.88,
#   'last_updated': '2026-02-23T18:28:17.684Z'},
#  {'coin_id': 'ethena-usde',
#   'symbol': 'usde',
#   'coin_name': 'Ethena USDe',
#   'current_price': 90.9,
#   'market_cap': 556733473323,
#   'market_cap_rank': 17,
#   'total_volume': 13165780898,
#   'circulating_supply': 6123353022.934256,
#   'total_supply': 6120331186.490956,
#   'ath': 92.91,
#   'atl': 78.05,
#   'last_updated': '2026-02-23T18:28:17.980Z'},
#  {'coin_id': 'canton-network',
#   'symbol': 'cc',
#   'coin_name': 'Canton',
#   'current_price': 14.35,
#   'market_cap': 542881188586,
#   'market_cap_rank': 18,
#   'total_volume': 785177051,
#   'circulating_supply': 37818276872.86908,
#   'total_supply': 37818276872.86908,
#   'ath': 17.72,
#   'atl': 5.31,
#   'last_updated': '2026-02-23T18:28:18.007Z'},
#  {'coin_id': 'chainlink',
#   'symbol': 'link',
#   'coin_name': 'Chainlink',
#   'current_price': 753.69,
#   'market_cap': 533779363471,
#   'market_cap_rank': 19,
#   'total_volume': 33829055614,
#   'circulating_supply': 708099970.4525867,
#   'total_supply': 1000000000.0,
#   'ath': 3862.15,
#   'atl': 9.55,
#   'last_updated': '2026-02-23T18:28:18.475Z'},
#  {'coin_id': 'monero',
#   'symbol': 'xmr',
#   'coin_name': 'Monero',
#   'current_price': 28406,
#   'market_cap': 523569358466,
#   'market_cap_rank': 20,
#   'total_volume': 7728676142,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'ath': 72026,
#   'atl': 13.57,
#   'last_updated': '2026-02-23T18:28:17.888Z'},
#  {'coin_id': 'stellar',
#   'symbol': 'xlm',
#   'coin_name': 'Stellar',
#   'current_price': 13.74,
#   'market_cap': 451703708562,
#   'market_cap_rank': 21,
#   'total_volume': 9089342332,
#   'circulating_supply': 32858660026.50742,
#   'total_supply': 50001786883.65895,
#   'ath': 58.01,
#   'atl': 0.02966141,
#   'last_updated': '2026-02-23T18:28:18.468Z'},
#  {'coin_id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'coin_name': 'USD1',
#   'current_price': 90.92,
#   'market_cap': 437039854624,
#   'market_cap_rank': 22,
#   'total_volume': 423620650528,
#   'circulating_supply': 4806977895.469311,
#   'total_supply': 4806977895.469311,
#   'ath': 92.17,
#   'atl': 83.75,
#   'last_updated': '2026-02-23T18:28:18.973Z'},
#  {'coin_id': 'rain',
#   'symbol': 'rain',
#   'coin_name': 'Rain',
#   'current_price': 0.851547,
#   'market_cap': 406654213443,
#   'market_cap_rank': 23,
#   'total_volume': 2655768986,
#   'circulating_supply': 477913535471.4499,
#   'total_supply': 1149928999761.049,
#   'ath': 0.989197,
#   'atl': 0.196087,
#   'last_updated': '2026-02-23T18:28:18.116Z'},
#  {'coin_id': 'dai',
#   'symbol': 'dai',
#   'coin_name': 'Dai',
#   'current_price': 90.95,
#   'market_cap': 380069397512,
#   'market_cap_rank': 24,
#   'total_volume': 6465339190,
#   'circulating_supply': 4177042792.17075,
#   'total_supply': 4178836061.116609,
#   'ath': 92.29,
#   'atl': 64.85,
#   'last_updated': '2026-02-23T18:28:18.108Z'},
#  {'coin_id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'coin_name': 'Hedera',
#   'current_price': 8.63,
#   'market_cap': 371421703415,
#   'market_cap_rank': 25,
#   'total_volume': 9024274528,
#   'circulating_supply': 43003421569.21756,
#   'total_supply': 50000000000.0,
#   'ath': 41.81,
#   'atl': 0.703644,
#   'last_updated': '2026-02-23T18:28:19.743Z'},
#  {'coin_id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'coin_name': 'PayPal USD',
#   'current_price': 90.95,
#   'market_cap': 370410232363,
#   'market_cap_rank': 26,
#   'total_volume': 10554611591,
#   'circulating_supply': 4072620294.82134,
#   'total_supply': 4072620294.82134,
#   'ath': 92.2,
#   'atl': 80.95,
#   'last_updated': '2026-02-23T18:28:17.976Z'},
#  {'coin_id': 'zcash',
#   'symbol': 'zec',
#   'coin_name': 'Zcash',
#   'current_price': 21906,
#   'market_cap': 363316127964,
#   'market_cap_rank': 27,
#   'total_volume': 31031114800,
#   'circulating_supply': 16567439.2280448,
#   'total_supply': 16568775.1655448,
#   'ath': 211171,
#   'atl': 1342.38,
#   'last_updated': '2026-02-23T18:28:18.681Z'},
#  {'coin_id': 'litecoin',
#   'symbol': 'ltc',
#   'coin_name': 'Litecoin',
#   'current_price': 4685.73,
#   'market_cap': 360313103918,
#   'market_cap_rank': 28,
#   'total_volume': 27011454825,
#   'circulating_supply': 76880701.98347135,
#   'total_supply': 76881795.73347135,
#   'ath': 30082,
#   'atl': 72.12,
#   'last_updated': '2026-02-23T18:28:18.251Z'},
#  {'coin_id': 'avalanche-2',
#   'symbol': 'avax',
#   'coin_name': 'Avalanche',
#   'current_price': 768.15,
#   'market_cap': 331745121885,
#   'market_cap_rank': 29,
#   'total_volume': 26379222433,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'ath': 10772.35,
#   'atl': 204.63,
#   'last_updated': '2026-02-23T18:28:18.273Z'},
#  {'coin_id': 'shiba-inu',
#   'symbol': 'shib',
#   'coin_name': 'Shiba Inu',
#   'current_price': 0.00055021,
#   'market_cap': 324359924842,
#   'market_cap_rank': 30,
#   'total_volume': 10260492080,
#   'circulating_supply': 589243858474311.2,
#   'total_supply': 589500400241439.5,
#   'ath': 0.00645756,
#   'atl': 4.169e-09,
#   'last_updated': '2026-02-23T18:28:18.119Z'},
#  {'coin_id': 'sui',
#   'symbol': 'sui',
#   'coin_name': 'Sui',
#   'current_price': 80.03,
#   'market_cap': 307997365642,
#   'market_cap_rank': 31,
#   'total_volume': 51772379039,
#   'circulating_supply': 3846172527.429665,
#   'total_supply': 10000000000.0,
#   'ath': 458.6,
#   'atl': 30.36,
#   'last_updated': '2026-02-23T18:28:18.330Z'},
#  {'coin_id': 'the-open-network',
#   'symbol': 'ton',
#   'coin_name': 'Toncoin',
#   'current_price': 122.96,
#   'market_cap': 301470569700,
#   'market_cap_rank': 32,
#   'total_volume': 8691334096,
#   'circulating_supply': 2451718045.107024,
#   'total_supply': 5154974628.543455,
#   'ath': 689.6,
#   'atl': 38.25,
#   'last_updated': '2026-02-23T18:28:18.227Z'},
#  {'coin_id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'coin_name': 'World Liberty Financial',
#   'current_price': 10.25,
#   'market_cap': 283596637015,
#   'market_cap_rank': 33,
#   'total_volume': 33133726429,
#   'circulating_supply': 27660694583.0,
#   'total_supply': 100000000000.0,
#   'ath': 29.22,
#   'atl': 8.91,
#   'last_updated': '2026-02-23T18:28:18.837Z'},
#  {'coin_id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'coin_name': 'Cronos',
#   'current_price': 6.73,
#   'market_cap': 276018706650,
#   'market_cap_rank': 34,
#   'total_volume': 1243441445,
#   'circulating_supply': 41053247711.30286,
#   'total_supply': 98419953826.86824,
#   'ath': 72.06,
#   'atl': 0.864137,
#   'last_updated': '2026-02-23T18:28:18.016Z'},
#  {'coin_id': 'tether-gold',
#   'symbol': 'xaut',
#   'coin_name': 'Tether Gold',
#   'current_price': 471716,
#   'market_cap': 245816899003,
#   'market_cap_rank': 35,
#   'total_volume': 43371544915,
#   'circulating_supply': 520825.641697,
#   'total_supply': 712747.089,
#   'ath': 514631,
#   'atl': 108167,
#   'last_updated': '2026-02-23T18:28:18.090Z'},
#  {'coin_id': 'memecore',
#   'symbol': 'm',
#   'coin_name': 'MemeCore',
#   'current_price': 126.26,
#   'market_cap': 219573877677,
#   'market_cap_rank': 36,
#   'total_volume': 1042972764,
#   'circulating_supply': 1739006001.319395,
#   'total_supply': 5339021448.471307,
#   'ath': 260.79,
#   'atl': 4.05,
#   'last_updated': '2026-02-23T18:28:17.972Z'},
#  {'coin_id': 'pax-gold',
#   'symbol': 'paxg',
#   'coin_name': 'PAX Gold',
#   'current_price': 475292,
#   'market_cap': 218479101912,
#   'market_cap_rank': 37,
#   'total_volume': 34244871723,
#   'circulating_supply': 459417.25,
#   'total_supply': 459417.25,
#   'ath': 516779,
#   'atl': 100361,
#   'last_updated': '2026-02-23T18:28:18.050Z'},
#  {'coin_id': 'uniswap',
#   'symbol': 'uni',
#   'coin_name': 'Uniswap',
#   'current_price': 304.66,
#   'market_cap': 193114701256,
#   'market_cap_rank': 38,
#   'total_volume': 21485870804,
#   'circulating_supply': 633684762.0380214,
#   'total_supply': 898646420.0366304,
#   'ath': 3333.06,
#   'atl': 75.81,
#   'last_updated': '2026-02-23T18:28:18.805Z'},
#  {'coin_id': 'polkadot',
#   'symbol': 'dot',
#   'coin_name': 'Polkadot',
#   'current_price': 115.73,
#   'market_cap': 193080644696,
#   'market_cap_rank': 39,
#   'total_volume': 11887667206,
#   'circulating_supply': 1668295422.743435,
#   'total_supply': 1668295422.742343,
#   'ath': 4095.22,
#   'atl': 103.91,
#   'last_updated': '2026-02-23T18:28:18.544Z'},
#  {'coin_id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'coin_name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'current_price': 90.99,
#   'market_cap': 176588295524,
#   'market_cap_rank': 40,
#   'total_volume': None,
#   'circulating_supply': 1940843131.800449,
#   'total_supply': 1940843131.800449,
#   'ath': 92.2,
#   'atl': 83.81,
#   'last_updated': '2026-02-23T18:20:03.501Z'},
#  {'coin_id': 'mantle',
#   'symbol': 'mnt',
#   'coin_name': 'Mantle',
#   'current_price': 52.45,
#   'market_cap': 170697515922,
#   'market_cap_rank': 41,
#   'total_volume': 4261075354,
#   'circulating_supply': 3252944055.63684,
#   'total_supply': 6219316794.889999,
#   'ath': 253.43,
#   'atl': 25.64,
#   'last_updated': '2026-02-23T18:28:18.052Z'},
#  {'coin_id': 'falcon-finance',
#   'symbol': 'usdf',
#   'coin_name': 'Falcon USD',
#   'current_price': 90.73,
#   'market_cap': 159386390474,
#   'market_cap_rank': 42,
#   'total_volume': 406075839,
#   'circulating_supply': 1755749524.542127,
#   'total_supply': 1755749524.542127,
#   'ath': 92.45,
#   'atl': 80.47,
#   'last_updated': '2026-02-23T18:28:16.815Z'},
#  {'coin_id': 'aave',
#   'symbol': 'aave',
#   'coin_name': 'Aave',
#   'current_price': 10458.72,
#   'market_cap': 159011126292,
#   'market_cap_rank': 43,
#   'total_volume': 32212589111,
#   'circulating_supply': 15190704.844337257,
#   'total_supply': 16000000.0,
#   'ath': 48387,
#   'atl': 1933.39,
#   'last_updated': '2026-02-23T18:28:18.428Z'},
#  {'coin_id': 'aster-2',
#   'symbol': 'aster',
#   'coin_name': 'Aster',
#   'current_price': 63.24,
#   'market_cap': 155306450798,
#   'market_cap_rank': 44,
#   'total_volume': 14503192726,
#   'circulating_supply': 2454947754.91,
#   'total_supply': 7822985112.446448,
#   'ath': 213.7,
#   'atl': 8.76,
#   'last_updated': '2026-02-23T18:28:18.089Z'},
#  {'coin_id': 'pepe',
#   'symbol': 'pepe',
#   'coin_name': 'Pepe',
#   'current_price': 0.00036664,
#   'market_cap': 154292062831,
#   'market_cap_rank': 45,
#   'total_volume': 30842135246,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'ath': 0.00237833,
#   'atl': 4.52e-06,
#   'last_updated': '2026-02-23T18:28:18.578Z'},
#  {'coin_id': 'global-dollar',
#   'symbol': 'usdg',
#   'coin_name': 'Global Dollar',
#   'current_price': 90.96,
#   'market_cap': 147999681993,
#   'market_cap_rank': 46,
#   'total_volume': 3223368370,
#   'circulating_supply': 1627147250.164927,
#   'total_supply': 1627147250.164927,
#   'ath': 143.35,
#   'atl': 76.61,
#   'last_updated': '2026-02-23T18:28:18.036Z'},
#  {'coin_id': 'bittensor',
#   'symbol': 'tao',
#   'coin_name': 'Bittensor',
#   'current_price': 15304.09,
#   'market_cap': 147016609346,
#   'market_cap_rank': 47,
#   'total_volume': 7713705780,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'ath': 62722,
#   'atl': 2535.93,
#   'last_updated': '2026-02-23T18:28:18.212Z'},
#  {'coin_id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'coin_name': 'Circle USYC',
#   'current_price': 101.11,
#   'market_cap': 144003304098,
#   'market_cap_rank': 48,
#   'total_volume': 4044.32,
#   'circulating_supply': 1553577376.229146,
#   'total_supply': 1553577376.229146,
#   'ath': 102.4,
#   'atl': 86.89,
#   'last_updated': '2026-02-10T05:42:11.457Z'},
#  {'coin_id': 'bitget-token',
#   'symbol': 'bgb',
#   'coin_name': 'Bitget Token',
#   'current_price': 203.47,
#   'market_cap': 142445212509,
#   'market_cap_rank': 49,
#   'total_volume': 1866229380,
#   'circulating_supply': 699992035.9787906,
#   'total_supply': 916931610.9787906,
#   'ath': 722.65,
#   'atl': 1.081,
#   'last_updated': '2026-02-23T18:28:18.250Z'},
#  {'coin_id': 'okb',
#   'symbol': 'okb',
#   'coin_name': 'OKB',
#   'current_price': 6765.83,
#   'market_cap': 142040061130,
#   'market_cap_rank': 50,
#   'total_volume': 1343312022,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'ath': 22313,
#   'atl': 40.86,
#   'last_updated': '2026-02-23T18:28:18.320Z'},
#  {'coin_id': 'ripple-usd',
#   'symbol': 'rlusd',
#   'coin_name': 'Ripple USD',
#   'current_price': 90.96,
#   'market_cap': 141751060587,
#   'market_cap_rank': 51,
#   'total_volume': 7757259699,
#   'circulating_supply': 1558420717.127497,
#   'total_supply': 1558420717.127497,
#   'ath': 92.15,
#   'atl': 81.72,
#   'last_updated': '2026-02-23T18:28:18.685Z'},
#  {'coin_id': 'htx-dao',
#   'symbol': 'htx',
#   'coin_name': 'HTX DAO',
#   'current_price': 0.00015072,
#   'market_cap': 138141858466,
#   'market_cap_rank': 52,
#   'total_volume': 6867439226,
#   'circulating_supply': 916533066327098.8,
#   'total_supply': 916533066327098.8,
#   'ath': 0.00031771,
#   'atl': 6.739e-05,
#   'last_updated': '2026-02-23T18:28:18.013Z'},
#  {'coin_id': 'pi-network',
#   'symbol': 'pi',
#   'coin_name': 'Pi Network',
#   'current_price': 14.55,
#   'market_cap': 134000531329,
#   'market_cap_rank': 53,
#   'total_volume': 1409478886,
#   'circulating_supply': 9212524148.819681,
#   'total_supply': 14173114075.1072,
#   'ath': 260.4,
#   'atl': 11.91,
#   'last_updated': '2026-02-23T18:28:20.943Z'},
#  {'coin_id': 'sky',
#   'symbol': 'sky',
#   'coin_name': 'Sky',
#   'current_price': 5.72,
#   'market_cap': 131871438139,
#   'market_cap_rank': 54,
#   'total_volume': 1073534269,
#   'circulating_supply': 23039919068.07182,
#   'total_supply': 23462665147.36596,
#   'ath': 8.62,
#   'atl': 3.12,
#   'last_updated': '2026-02-23T18:28:18.343Z'},
#  {'coin_id': 'bfusd',
#   'symbol': 'bfusd',
#   'coin_name': 'BFUSD',
#   'current_price': 90.91,
#   'market_cap': 120019286706,
#   'market_cap_rank': 55,
#   'total_volume': 717217655,
#   'circulating_supply': 1320000000.0,
#   'total_supply': 1320000000.0,
#   'ath': 92.02,
#   'atl': 86.85,
#   'last_updated': '2026-02-23T18:28:18.001Z'},
#  {'coin_id': 'ethereum-classic',
#   'symbol': 'etc',
#   'coin_name': 'Ethereum Classic',
#   'current_price': 767.79,
#   'market_cap': 119526329107,
#   'market_cap_rank': 56,
#   'total_volume': 5045769969,
#   'circulating_supply': 155648590.2195606,
#   'total_supply': 155649117.1955606,
#   'ath': 12296.58,
#   'atl': 41.44,
#   'last_updated': '2026-02-23T18:28:18.104Z'},
#  {'coin_id': 'near',
#   'symbol': 'near',
#   'coin_name': 'NEAR Protocol',
#   'current_price': 89.24,
#   'market_cap': 115007747343,
#   'market_cap_rank': 57,
#   'total_volume': 10078605095,
#   'circulating_supply': 1288546614.0,
#   'total_supply': 1288546593.0,
#   'ath': 1518.16,
#   'atl': 39.17,
#   'last_updated': '2026-02-23T18:28:18.796Z'},
#  {'coin_id': 'ondo-finance',
#   'symbol': 'ondo',
#   'coin_name': 'Ondo',
#   'current_price': 22.75,
#   'market_cap': 110823809384,
#   'market_cap_rank': 58,
#   'total_volume': 4062685932,
#   'circulating_supply': 4869330647.0,
#   'total_supply': 10000000000.0,
#   'ath': 181.52,
#   'atl': 6.83,
#   'last_updated': '2026-02-23T18:28:18.248Z'},
#  {'coin_id': 'superstate-short-duration-us-government-securities-fund-ustb',
#   'symbol': 'ustb',
#   'coin_name': 'Superstate Short Duration U.S. Government Securities Fund (USTB)',
#   'current_price': 1000.59,
#   'market_cap': 108686835820,
#   'market_cap_rank': 59,
#   'total_volume': None,
#   'circulating_supply': 108622547.916425,
#   'total_supply': 108668001.602391,
#   'ath': 1011.63,
#   'atl': 876.83,
#   'last_updated': '2026-02-23T18:25:05.551Z'},
#  {'coin_id': 'polygon-ecosystem-token',
#   'symbol': 'pol',
#   'coin_name': 'POL (ex-MATIC)',
#   'current_price': 9.78,
#   'market_cap': 103667968300,
#   'market_cap_rank': 60,
#   'total_volume': 7996257309,
#   'circulating_supply': 10596983001.07012,
#   'total_supply': 10596983001.07012,
#   'ath': 106.68,
#   'atl': 7.85,
#   'last_updated': '2026-02-23T18:28:18.586Z'},
#  {'coin_id': 'gatechain-token',
#   'symbol': 'gt',
#   'coin_name': 'Gate',
#   'current_price': 625.82,
#   'market_cap': 103919175936,
#   'market_cap_rank': 61,
#   'total_volume': 543070857,
#   'circulating_supply': 115180573.04885802,
#   'total_supply': 115180573.04885802,
#   'ath': 2235.58,
#   'atl': 19.44,
#   'last_updated': '2026-02-23T18:28:18.047Z'},
#  {'coin_id': 'internet-computer',
#   'symbol': 'icp',
#   'coin_name': 'Internet Computer',
#   'current_price': 186.73,
#   'market_cap': 102619391236,
#   'market_cap_rank': 62,
#   'total_volume': 5206084102,
#   'circulating_supply': 549276617.9948642,
#   'total_supply': 549276681.6308945,
#   'ath': 51433,
#   'atl': 184.15,
#   'last_updated': '2026-02-23T18:28:18.265Z'},
#  {'coin_id': 'kucoin-shares',
#   'symbol': 'kcs',
#   'coin_name': 'KuCoin',
#   'current_price': 747.96,
#   'market_cap': 98776844223,
#   'market_cap_rank': 63,
#   'total_volume': 345575175,
#   'circulating_supply': 132155021.7355671,
#   'total_supply': 142155021.7355671,
#   'ath': 2158.41,
#   'atl': 24.48,
#   'last_updated': '2026-02-23T18:28:18.218Z'},
#  {'coin_id': 'pump-fun',
#   'symbol': 'pump',
#   'coin_name': 'Pump.fun',
#   'current_price': 0.167041,
#   'market_cap': 98549553244,
#   'market_cap_rank': 64,
#   'total_volume': 7722329123,
#   'circulating_supply': 590000000000.0,
#   'total_supply': 999989195140.263,
#   'ath': 0.77853,
#   'atl': 0.150889,
#   'last_updated': '2026-02-23T18:28:18.195Z'},
#  {'coin_id': 'worldcoin-wld',
#   'symbol': 'wld',
#   'coin_name': 'Worldcoin',
#   'current_price': 34.04,
#   'market_cap': 97467860344,
#   'market_cap_rank': 65,
#   'total_volume': 7262417593,
#   'circulating_supply': 2864410692.901624,
#   'total_supply': 10000000000.0,
#   'ath': 971.56,
#   'atl': 28.73,
#   'last_updated': '2026-02-23T18:28:18.405Z'},
#  {'coin_id': 'cosmos',
#   'symbol': 'atom',
#   'coin_name': 'Cosmos Hub',
#   'current_price': 194.39,
#   'market_cap': 96125721075,
#   'market_cap_rank': 66,
#   'total_volume': 4594652656,
#   'circulating_supply': 494797471.557071,
#   'total_supply': 494800762.651934,
#   'ath': 3301.61,
#   'atl': 87.61,
#   'last_updated': '2026-02-23T18:28:18.824Z'},
#  {'coin_id': 'hash-2',
#   'symbol': 'hash',
#   'coin_name': 'Provenance Blockchain',
#   'current_price': 1.63,
#   'market_cap': 89653334867,
#   'market_cap_rank': 67,
#   'total_volume': 590040,
#   'circulating_supply': 54953653269.0,
#   'total_supply': 100000000000.0,
#   'ath': 5.31,
#   'atl': 0.877643,
#   'last_updated': '2026-02-23T18:28:18.074Z'},
#  {'coin_id': 'midnight-3',
#   'symbol': 'night',
#   'coin_name': 'Midnight',
#   'current_price': 5.31,
#   'market_cap': 88122220136,
#   'market_cap_rank': 68,
#   'total_volume': 901566602,
#   'circulating_supply': 16607399400.63495,
#   'total_supply': 24000000000.0,
#   'ath': 10.66,
#   'atl': 2.14,
#   'last_updated': '2026-02-23T18:28:18.344Z'},
#  {'coin_id': 'quant-network',
#   'symbol': 'qnt',
#   'coin_name': 'Quant',
#   'current_price': 5668.53,
#   'market_cap': 82445145422,
#   'market_cap_rank': 69,
#   'total_volume': 1082088609,
#   'circulating_supply': 14544176.164081175,
#   'total_supply': 14612493.0,
#   'ath': 31427,
#   'atl': 15.06,
#   'last_updated': '2026-02-23T18:28:18.450Z'},
#  {'coin_id': 'nexo',
#   'symbol': 'nexo',
#   'coin_name': 'NEXO',
#   'current_price': 76.19,
#   'market_cap': 76198781386,
#   'market_cap_rank': 70,
#   'total_volume': 757196573,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 298.99,
#   'atl': 3.25,
#   'last_updated': '2026-02-23T18:28:18.270Z'},
#  {'coin_id': 'usdtb',
#   'symbol': 'usdtb',
#   'coin_name': 'USDtb',
#   'current_price': 91.08,
#   'market_cap': 76047480744,
#   'market_cap_rank': 71,
#   'total_volume': 1191993144,
#   'circulating_supply': 834924105.9761826,
#   'total_supply': 834924105.9761826,
#   'ath': 95.66,
#   'atl': 77.41,
#   'last_updated': '2026-02-23T18:28:18.628Z'},
#  {'coin_id': 'ethena',
#   'symbol': 'ena',
#   'coin_name': 'Ethena',
#   'current_price': 8.97,
#   'market_cap': 73863233601,
#   'market_cap_rank': 72,
#   'total_volume': 9203679702,
#   'circulating_supply': 8225000000.0,
#   'total_supply': 15000000000.0,
#   'ath': 126.48,
#   'atl': 8.71,
#   'last_updated': '2026-02-23T18:28:18.259Z'},
#  {'coin_id': 'kaspa',
#   'symbol': 'kas',
#   'coin_name': 'Kaspa',
#   'current_price': 2.73,
#   'market_cap': 73003022030,
#   'market_cap_rank': 73,
#   'total_volume': 1641130932,
#   'circulating_supply': 26777148610.50726,
#   'total_supply': 27228580942.72774,
#   'ath': 17.36,
#   'atl': 0.01327337,
#   'last_updated': '2026-02-23T18:28:18.637Z'},
#  {'coin_id': 'eutbl',
#   'symbol': 'eutbl',
#   'coin_name': 'Spiko EU T-Bills Money Market Fund',
#   'current_price': 112.42,
#   'market_cap': 72125023668,
#   'market_cap_rank': 74,
#   'total_volume': None,
#   'circulating_supply': 641581721.86248,
#   'total_supply': 641581721.86248,
#   'ath': 115.38,
#   'atl': 84.72,
#   'last_updated': '2026-02-23T18:25:07.083Z'},
#  {'coin_id': 'official-trump',
#   'symbol': 'trump',
#   'coin_name': 'Official Trump',
#   'current_price': 304.87,
#   'market_cap': 70899484443,
#   'market_cap_rank': 75,
#   'total_volume': 12410966547,
#   'circulating_supply': 232498807.465716,
#   'total_supply': 1000000000.0,
#   'ath': 6357.94,
#   'atl': 281.07,
#   'last_updated': '2026-02-23T18:28:18.313Z'},
#  {'coin_id': 'flare-networks',
#   'symbol': 'flr',
#   'coin_name': 'Flare',
#   'current_price': 0.828144,
#   'market_cap': 70230571058,
#   'market_cap_rank': 76,
#   'total_volume': 284908123,
#   'circulating_supply': 84847665817.05566,
#   'total_supply': 105015397455.3796,
#   'ath': 12.35,
#   'atl': 0.687929,
#   'last_updated': '2026-02-23T18:28:18.218Z'},
#  {'coin_id': 'algorand',
#   'symbol': 'algo',
#   'coin_name': 'Algorand',
#   'current_price': 7.63,
#   'market_cap': 67744187991,
#   'market_cap_rank': 77,
#   'total_volume': 2664254632,
#   'circulating_supply': 8880114343.678478,
#   'total_supply': 8884558383.055464,
#   'ath': 247.29,
#   'atl': 7.26,
#   'last_updated': '2026-02-23T18:28:18.403Z'},
#  {'coin_id': 'usdd',
#   'symbol': 'usdd',
#   'coin_name': 'USDD',
#   'current_price': 90.97,
#   'market_cap': 67566037109,
#   'market_cap_rank': 78,
#   'total_volume': 318700828,
#   'circulating_supply': 742668611.26,
#   'total_supply': 742779008.26,
#   'ath': 92.2,
#   'atl': 72.35,
#   'last_updated': '2026-02-23T18:28:18.192Z'},
#  {'coin_id': 'ousg',
#   'symbol': 'ousg',
#   'coin_name': 'OUSG',
#   'current_price': 10405.61,
#   'market_cap': 65925674297,
#   'market_cap_rank': 79,
#   'total_volume': 0.0,
#   'circulating_supply': 6335590.065824495,
#   'total_supply': 6335590.065824495,
#   'ath': 10520.12,
#   'atl': 7844.42,
#   'last_updated': '2026-02-23T18:25:01.772Z'},
#  {'coin_id': 'janus-henderson-anemoy-aaa-clo-fund',
#   'symbol': 'jaaa',
#   'coin_name': 'Janus Henderson Anemoy AAA CLO Fund',
#   'current_price': 93.48,
#   'market_cap': 65765933563,
#   'market_cap_rank': 80,
#   'total_volume': None,
#   'circulating_supply': 703562532.975816,
#   'total_supply': 703562532.975816,
#   'ath': 94.38,
#   'atl': 89.64,
#   'last_updated': '2026-02-23T18:05:04.870Z'},
#  {'coin_id': 'pippin',
#   'symbol': 'pippin',
#   'coin_name': 'pippin',
#   'current_price': 65.62,
#   'market_cap': 65372441412,
#   'market_cap_rank': 81,
#   'total_volume': 5360567211,
#   'circulating_supply': 999937490.733444,
#   'total_supply': 999937490.733444,
#   'ath': 68.76,
#   'atl': 0.473545,
#   'last_updated': '2026-02-23T18:28:18.910Z'},
#  {'coin_id': 'render-token',
#   'symbol': 'render',
#   'coin_name': 'Render',
#   'current_price': 125.27,
#   'market_cap': 64979063810,
#   'market_cap_rank': 82,
#   'total_volume': 4636509832,
#   'circulating_supply': 518714713.0140741,
#   'total_supply': 533474886.2940741,
#   'ath': 1121.89,
#   'atl': 2.79,
#   'last_updated': '2026-02-23T18:28:18.315Z'},
#  {'coin_id': 'ondo-us-dollar-yield',
#   'symbol': 'usdy',
#   'coin_name': 'Ondo US Dollar Yield',
#   'current_price': 101.68,
#   'market_cap': 64406504697,
#   'market_cap_rank': 83,
#   'total_volume': 180718448,
#   'circulating_supply': 633420602.6989516,
#   'total_supply': 1168933304.052243,
#   'ath': 105.8,
#   'atl': 77.42,
#   'last_updated': '2026-02-23T18:28:19.011Z'},
#  {'coin_id': 'filecoin',
#   'symbol': 'fil',
#   'coin_name': 'Filecoin',
#   'current_price': 80.9,
#   'market_cap': 61059100906,
#   'market_cap_rank': 84,
#   'total_volume': 8287666720,
#   'circulating_supply': 753940420.0,
#   'total_supply': 1958239236.0,
#   'ath': 17367.85,
#   'atl': 73.41,
#   'last_updated': '2026-02-23T18:28:18.345Z'},
#  {'coin_id': 'xdce-crowd-sale',
#   'symbol': 'xdc',
#   'coin_name': 'XDC Network',
#   'current_price': 3.05,
#   'market_cap': 60710364315,
#   'market_cap_rank': 85,
#   'total_volume': 2208108074,
#   'circulating_supply': 19933830184.32,
#   'total_supply': 38052851794.8,
#   'ath': 14.32,
#   'atl': 0.02721364,
#   'last_updated': '2026-02-23T18:28:18.797Z'},
#  {'coin_id': 'aptos',
#   'symbol': 'apt',
#   'coin_name': 'Aptos',
#   'current_price': 73.97,
#   'market_cap': 57685470123,
#   'market_cap_rank': 86,
#   'total_volume': 10669745216,
#   'circulating_supply': 779617858.8241673,
#   'total_supply': 1197226541.984117,
#   'ath': 1622.34,
#   'atl': 72.2,
#   'last_updated': '2026-02-23T18:28:18.605Z'},
#  {'coin_id': 'vechain',
#   'symbol': 'vet',
#   'coin_name': 'VeChain',
#   'current_price': 0.660188,
#   'market_cap': 56831333641,
#   'market_cap_rank': 87,
#   'total_volume': 1524289365,
#   'circulating_supply': 85985041177.0,
#   'total_supply': 85985041177.0,
#   'ath': 20.95,
#   'atl': 0.144791,
#   'last_updated': '2026-02-23T18:28:18.348Z'},
#  {'coin_id': 'beldex',
#   'symbol': 'bdx',
#   'coin_name': 'Beldex',
#   'current_price': 7.29,
#   'market_cap': 55447899203,
#   'market_cap_rank': 88,
#   'total_volume': 985911496,
#   'circulating_supply': 7605786488.145544,
#   'total_supply': 9936086363.38976,
#   'ath': 32.42,
#   'atl': 0.01949843,
#   'last_updated': '2026-02-23T18:28:18.393Z'},
#  {'coin_id': 'janus-henderson-anemoy-treasury-fund',
#   'symbol': 'jtrsy',
#   'coin_name': 'Janus Henderson Anemoy Treasury Fund',
#   'current_price': 99.66,
#   'market_cap': 51654622487,
#   'market_cap_rank': 89,
#   'total_volume': None,
#   'circulating_supply': 518328892.305495,
#   'total_supply': 518328892.305495,
#   'ath': 100.75,
#   'atl': 95.98,
#   'last_updated': '2026-02-23T18:25:01.366Z'},
#  {'coin_id': 'usual-usd',
#   'symbol': 'usd0',
#   'coin_name': 'Usual USD',
#   'current_price': 90.97,
#   'market_cap': 51419850732,
#   'market_cap_rank': 91,
#   'total_volume': 198569790,
#   'circulating_supply': 564856373.9693954,
#   'total_supply': 564856373.9693954,
#   'ath': 110.74,
#   'atl': 81.88,
#   'last_updated': '2026-02-23T18:28:18.196Z'},
#  {'coin_id': 'morpho',
#   'symbol': 'morpho',
#   'coin_name': 'Morpho',
#   'current_price': 143.64,
#   'market_cap': 51268707202,
#   'market_cap_rank': 90,
#   'total_volume': 2640340012,
#   'circulating_supply': 356615377.4331003,
#   'total_supply': 1000000000.0,
#   'ath': 361.23,
#   'atl': 60.2,
#   'last_updated': '2026-02-23T18:28:18.988Z'},
#  {'coin_id': 'arbitrum',
#   'symbol': 'arb',
#   'coin_name': 'Arbitrum',
#   'current_price': 8.42,
#   'market_cap': 49060142432,
#   'market_cap_rank': 92,
#   'total_volume': 8107206718,
#   'circulating_supply': 5826785045.0,
#   'total_supply': 10000000000.0,
#   'ath': 198.19,
#   'atl': 8.07,
#   'last_updated': '2026-02-23T18:28:18.626Z'},
#  {'coin_id': 'gho',
#   'symbol': 'gho',
#   'coin_name': 'GHO',
#   'current_price': 90.95,
#   'market_cap': 47968713128,
#   'market_cap_rank': 93,
#   'total_volume': 906155484,
#   'circulating_supply': 527437881.796613,
#   'total_supply': 527437881.796613,
#   'ath': 92.12,
#   'atl': 76.18,
#   'last_updated': '2026-02-23T18:28:18.275Z'},
#  {'coin_id': 'bonk',
#   'symbol': 'bonk',
#   'coin_name': 'Bonk',
#   'current_price': 0.00053523,
#   'market_cap': 47108646289,
#   'market_cap_rank': 94,
#   'total_volume': 4721247142,
#   'circulating_supply': 87995151183818.42,
#   'total_supply': 87995151197094.7,
#   'ath': 0.00491619,
#   'atl': 7.14e-06,
#   'last_updated': '2026-02-23T18:28:18.593Z'},
#  {'coin_id': 'a7a5',
#   'symbol': 'a7a5',
#   'coin_name': 'A7A5',
#   'current_price': 1.18,
#   'market_cap': 46422638941,
#   'market_cap_rank': 95,
#   'total_volume': 99120,
#   'circulating_supply': 39191262224.85074,
#   'total_supply': 39191262224.85074,
#   'ath': 20.14,
#   'atl': 0.00091492,
#   'last_updated': '2026-02-23T18:28:18.402Z'},
#  {'coin_id': 'stable-2',
#   'symbol': 'stable',
#   'coin_name': '\u200b\u200bStable',
#   'current_price': 2.55,
#   'market_cap': 45765335117,
#   'market_cap_rank': 96,
#   'total_volume': 2421961128,
#   'circulating_supply': 18000000000.0,
#   'total_supply': 100000000000.0,
#   'ath': 3.05,
#   'atl': 0.827533,
#   'last_updated': '2026-02-23T18:28:18.259Z'},
#  {'coin_id': 'true-usd',
#   'symbol': 'tusd',
#   'coin_name': 'TrueUSD',
#   'current_price': 90.87,
#   'market_cap': 44942374142,
#   'market_cap_rank': 97,
#   'total_volume': 617453599,
#   'circulating_supply': 494515083.0,
#   'total_supply': 494515083.0,
#   'ath': 112.93,
#   'atl': 64.32,
#   'last_updated': '2026-02-23T18:28:18.406Z'},
#  {'coin_id': 'fasttoken',
#   'symbol': 'ftn',
#   'coin_name': 'Fasttoken',
#   'current_price': 98.67,
#   'market_cap': 42808196520,
#   'market_cap_rank': 98,
#   'total_volume': 108145255,
#   'circulating_supply': 433857414.6,
#   'total_supply': 870742437.0,
#   'ath': 403.42,
#   'atl': 30.21,
#   'last_updated': '2026-02-23T18:28:18.262Z'},
#  {'coin_id': 'jupiter-exchange-solana',
#   'symbol': 'jup',
#   'coin_name': 'Jupiter',
#   'current_price': 13.15,
#   'market_cap': 42642112661,
#   'market_cap_rank': 99,
#   'total_volume': 2198725269,
#   'circulating_supply': 3243891294.88,
#   'total_supply': 6863982741.589805,
#   'ath': 166.05,
#   'atl': 12.3,
#   'last_updated': '2026-02-23T18:28:18.569Z'},
#  {'coin_id': 'usdai',
#   'symbol': 'usdai',
#   'coin_name': 'USDai',
#   'current_price': 90.93,
#   'market_cap': 42378333936,
#   'market_cap_rank': 100,
#   'total_volume': 506140209,
#   'circulating_supply': 465996229.2298472,
#   'total_supply': 465996229.2298472,
#   'ath': 104.92,
#   'atl': 68.25,
#   'last_updated': '2026-02-23T18:28:18.319Z'},
#  {'coin_id': 'euro-coin',
#   'symbol': 'eurc',
#   'coin_name': 'EURC',
#   'current_price': 107.35,
#   'market_cap': 42317870128,
#   'market_cap_rank': 101,
#   'total_volume': 2931403896,
#   'circulating_supply': 394206784.4132711,
#   'total_supply': 394210290.8432711,
#   'ath': 111.47,
#   'atl': 4.35,
#   'last_updated': '2026-02-23T18:28:18.933Z'},
#  {'coin_id': 'sei-network',
#   'symbol': 'sei',
#   'coin_name': 'Sei',
#   'current_price': 6.07,
#   'market_cap': 40844991443,
#   'market_cap_rank': 102,
#   'total_volume': 3797947759,
#   'circulating_supply': 6733333333.0,
#   'total_supply': 10000000000.0,
#   'ath': 94.47,
#   'atl': 6.0,
#   'last_updated': '2026-02-23T18:28:18.840Z'},
#  {'coin_id': 'decred',
#   'symbol': 'dcr',
#   'coin_name': 'Decred',
#   'current_price': 2314.71,
#   'market_cap': 40018561046,
#   'market_cap_rank': 103,
#   'total_volume': 356422169,
#   'circulating_supply': 17290353.61774874,
#   'total_supply': 17290460.66456954,
#   'ath': 18443.33,
#   'atl': 29.25,
#   'last_updated': '2026-02-23T18:28:18.296Z'},
#  {'coin_id': 'kite-2',
#   'symbol': 'kite',
#   'coin_name': 'Kite',
#   'current_price': 22.0,
#   'market_cap': 39634742941,
#   'market_cap_rank': 104,
#   'total_volume': 10809264402,
#   'circulating_supply': 1800000000.0,
#   'total_supply': 10000000000.0,
#   'ath': 26.21,
#   'atl': 5.48,
#   'last_updated': '2026-02-23T18:28:18.492Z'},
#  {'coin_id': 'blockstack',
#   'symbol': 'stx',
#   'coin_name': 'Stacks',
#   'current_price': 21.33,
#   'market_cap': 37937474008,
#   'market_cap_rank': 105,
#   'total_volume': 865159032,
#   'circulating_supply': 1779197820.63924,
#   'total_supply': 1779197820.63924,
#   'ath': 322.23,
#   'atl': 3.44,
#   'last_updated': '2026-02-23T18:28:18.878Z'},
#  {'coin_id': 'pancakeswap-token',
#   'symbol': 'cake',
#   'coin_name': 'PancakeSwap',
#   'current_price': 112.17,
#   'market_cap': 37153757663,
#   'market_cap_rank': 106,
#   'total_volume': 3322813716,
#   'circulating_supply': 330795777.5852192,
#   'total_supply': 344107898.4723421,
#   'ath': 3259.75,
#   'atl': 14.48,
#   'last_updated': '2026-02-23T18:28:18.503Z'},
#  {'coin_id': 'dash',
#   'symbol': 'dash',
#   'coin_name': 'Dash',
#   'current_price': 2942.74,
#   'market_cap': 37109679981,
#   'market_cap_rank': 107,
#   'total_volume': 7554327205,
#   'circulating_supply': 12601041.40999666,
#   'total_supply': 12603402.04138784,
#   'ath': 95552,
#   'atl': 13.82,
#   'last_updated': '2026-02-23T18:28:18.562Z'},
#  {'coin_id': 'pudgy-penguins',
#   'symbol': 'pengu',
#   'coin_name': 'Pudgy Penguins',
#   'current_price': 0.579868,
#   'market_cap': 36446610218,
#   'market_cap_rank': 108,
#   'total_volume': 7263088762,
#   'circulating_supply': 62860396090.0,
#   'total_supply': 79756767591.77896,
#   'ath': 5.81,
#   'atl': 0.320882,
#   'last_updated': '2026-02-23T18:28:18.613Z'},
#  {'coin_id': 'tezos',
#   'symbol': 'xtz',
#   'coin_name': 'Tezos',
#   'current_price': 33.62,
#   'market_cap': 36173926039,
#   'market_cap_rank': 109,
#   'total_volume': 1106420048,
#   'circulating_supply': 1076335851.130665,
#   'total_supply': 1096395162.093095,
#   'ath': 676.89,
#   'atl': 24.73,
#   'last_updated': '2026-02-23T18:28:18.385Z'},
#  {'coin_id': 'just',
#   'symbol': 'jst',
#   'coin_name': 'JUST',
#   'current_price': 4.09,
#   'market_cap': 36081770694,
#   'market_cap_rank': 110,
#   'total_volume': 2628735491,
#   'circulating_supply': 8815108920.581306,
#   'total_supply': 8815108920.581306,
#   'ath': 14.19,
#   'atl': 0.359754,
#   'last_updated': '2026-02-23T18:28:18.600Z'},
#  {'coin_id': 'first-digital-usd',
#   'symbol': 'fdusd',
#   'coin_name': 'First Digital USD',
#   'current_price': 90.87,
#   'market_cap': 35857462982,
#   'market_cap_rank': 111,
#   'total_volume': 13465562060,
#   'circulating_supply': 394590529.224244,
#   'total_supply': 394590529.224244,
#   'ath': 100.07,
#   'atl': 78.29,
#   'last_updated': '2026-02-23T18:28:18.456Z'},
#  {'coin_id': 'kinesis-gold',
#   'symbol': 'kau',
#   'coin_name': 'Kinesis Gold',
#   'current_price': 15018.88,
#   'market_cap': 35838460353,
#   'market_cap_rank': 112,
#   'total_volume': 25638223,
#   'circulating_supply': 2386227.8342,
#   'total_supply': 2386227.8342,
#   'ath': 16494.48,
#   'atl': 3614.27,
#   'last_updated': '2026-02-23T18:28:18.674Z'},
#  {'coin_id': 'virtual-protocol',
#   'symbol': 'virtual',
#   'coin_name': 'Virtuals Protocol',
#   'current_price': 53.71,
#   'market_cap': 35253034118,
#   'market_cap_rank': 113,
#   'total_volume': 4407205150,
#   'circulating_supply': 656282621.3333926,
#   'total_supply': 1000000000.0,
#   'ath': 434.45,
#   'atl': 0.622571,
#   'last_updated': '2026-02-23T18:28:18.986Z'},
#  {'coin_id': 'story-2',
#   'symbol': 'ip',
#   'coin_name': 'Story',
#   'current_price': 92.9,
#   'market_cap': 32590695631,
#   'market_cap_rank': 114,
#   'total_volume': 2895199608,
#   'circulating_supply': 350777227.6,
#   'total_supply': 1024304921.47,
#   'ath': 1302.35,
#   'atl': 87.81,
#   'last_updated': '2026-02-23T18:28:18.364Z'},
#  {'coin_id': 'fetch-ai',
#   'symbol': 'fet',
#   'coin_name': 'Artificial Superintelligence Alliance',
#   'current_price': 14.04,
#   'market_cap': 31872092996,
#   'market_cap_rank': 115,
#   'total_volume': 3612635422,
#   'circulating_supply': 2268993332.6762614,
#   'total_supply': 2714384546.672,
#   'ath': 287.87,
#   'atl': 0.616804,
#   'last_updated': '2026-02-23T18:28:18.539Z'},
#  {'coin_id': 'chiliz',
#   'symbol': 'chz',
#   'coin_name': 'Chiliz',
#   'current_price': 3.08,
#   'market_cap': 31713688793,
#   'market_cap_rank': 116,
#   'total_volume': 5320799687,
#   'circulating_supply': 10292952900.0,
#   'total_supply': 10293032349.0,
#   'ath': 63.87,
#   'atl': 0.290329,
#   'last_updated': '2026-02-23T18:28:19.683Z'},
#  {'coin_id': 'lighter',
#   'symbol': 'lit',
#   'coin_name': 'Lighter',
#   'current_price': 125.72,
#   'market_cap': 31398373741,
#   'market_cap_rank': 117,
#   'total_volume': 3316358480,
#   'circulating_supply': 250000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 705.52,
#   'atl': 120.24,
#   'last_updated': '2026-02-23T18:28:18.421Z'},
#  {'coin_id': 'c8ntinuum',
#   'symbol': 'ctm',
#   'coin_name': 'c8ntinuum',
#   'current_price': 7.18,
#   'market_cap': 31280637503,
#   'market_cap_rank': 118,
#   'total_volume': 54634563,
#   'circulating_supply': 4359542107.432732,
#   'total_supply': 8888888888.0,
#   'ath': 13.05,
#   'atl': 0.709073,
#   'last_updated': '2026-02-23T18:28:18.355Z'},
#  {'coin_id': 'ether-fi',
#   'symbol': 'ethfi',
#   'coin_name': 'Ether.fi',
#   'current_price': 41.68,
#   'market_cap': 31073282979,
#   'market_cap_rank': 120,
#   'total_volume': 3590945041,
#   'circulating_supply': 744064067.0,
#   'total_supply': 998535999.0,
#   'ath': 711.06,
#   'atl': 34.7,
#   'last_updated': '2026-02-23T18:28:18.458Z'},
#  {'coin_id': 'injective-protocol',
#   'symbol': 'inj',
#   'coin_name': 'Injective',
#   'current_price': 310.36,
#   'market_cap': 31046596321,
#   'market_cap_rank': 119,
#   'total_volume': 5148528430,
#   'circulating_supply': 100000000.0,
#   'total_supply': 100000000.0,
#   'ath': 4364.19,
#   'atl': 49.02,
#   'last_updated': '2026-02-23T18:28:19.130Z'},
#  {'coin_id': 'hastra-prime',
#   'symbol': 'prime',
#   'coin_name': 'PRIME',
#   'current_price': 92.82,
#   'market_cap': 30853499046,
#   'market_cap_rank': 121,
#   'total_volume': 46968518,
#   'circulating_supply': 332386264.498513,
#   'total_supply': 332386264.498513,
#   'ath': 94.01,
#   'atl': 89.31,
#   'last_updated': '2026-02-23T18:28:18.427Z'},
#  {'coin_id': 'usx',
#   'symbol': 'usx',
#   'coin_name': 'USX',
#   'current_price': 90.96,
#   'market_cap': 30623289417,
#   'market_cap_rank': 122,
#   'total_volume': 406065530,
#   'circulating_supply': 336653894.511546,
#   'total_supply': 336653894.511546,
#   'ath': 95.56,
#   'atl': 74.4,
#   'last_updated': '2026-02-23T18:28:18.590Z'},
#  {'coin_id': 'apenft',
#   'symbol': 'nft',
#   'coin_name': 'AINFT',
#   'current_price': 3.048e-05,
#   'market_cap': 30181164492,
#   'market_cap_rank': 123,
#   'total_volume': 2043108577,
#   'circulating_supply': 990105667256391.5,
#   'total_supply': 990105667256391.5,
#   'ath': 0.00054965,
#   'atl': 2.463e-05,
#   'last_updated': '2026-02-23T18:28:18.640Z'},
#  {'coin_id': 'bittorrent',
#   'symbol': 'btt',
#   'coin_name': 'BitTorrent',
#   'current_price': 3.035e-05,
#   'market_cap': 29944917249,
#   'market_cap_rank': 124,
#   'total_volume': 1152262443,
#   'circulating_supply': 987037885840674.8,
#   'total_supply': 990000000000000.0,
#   'ath': 0.00025579,
#   'atl': 2.748e-05,
#   'last_updated': '2026-02-23T18:28:18.748Z'},
#  {'coin_id': 'curve-dao-token',
#   'symbol': 'crv',
#   'coin_name': 'Curve DAO',
#   'current_price': 20.21,
#   'market_cap': 29902578615,
#   'market_cap_rank': 125,
#   'total_volume': 4547769479,
#   'circulating_supply': 1479114808.0,
#   'total_supply': 2355346599.768306,
#   'ath': 1150.14,
#   'atl': 15.17,
#   'last_updated': '2026-02-23T18:28:18.753Z'},
#  {'coin_id': 'sun-token',
#   'symbol': 'sun',
#   'coin_name': 'Sun Token',
#   'current_price': 1.51,
#   'market_cap': 28959872348,
#   'market_cap_rank': 126,
#   'total_volume': 2392819772,
#   'circulating_supply': 19213033038.81119,
#   'total_supply': 19900730000.0,
#   'ath': 4880.96,
#   'atl': 0.374246,
#   'last_updated': '2026-02-23T18:28:18.604Z'},
#  {'coin_id': 'kaia',
#   'symbol': 'kaia',
#   'coin_name': 'Kaia',
#   'current_price': 4.89,
#   'market_cap': 28631600121,
#   'market_cap_rank': 127,
#   'total_volume': 760730446,
#   'circulating_supply': 5856641747.106198,
#   'total_supply': 5856641936.044253,
#   'ath': 34.46,
#   'atl': 4.23,
#   'last_updated': '2026-02-23T18:28:18.882Z'},
#  {'coin_id': 'gnosis',
#   'symbol': 'gno',
#   'coin_name': 'Gnosis',
#   'current_price': 10756.46,
#   'market_cap': 28394701586,
#   'market_cap_rank': 128,
#   'total_volume': 296736234,
#   'circulating_supply': 2639589.0,
#   'total_supply': 3000000.0,
#   'ath': 47603,
#   'atl': 519.75,
#   'last_updated': '2026-02-23T18:28:18.690Z'},
#  {'coin_id': 'adi-token',
#   'symbol': 'adi',
#   'coin_name': 'ADI',
#   'current_price': 287.11,
#   'market_cap': 27938862493,
#   'market_cap_rank': 129,
#   'total_volume': 64571624,
#   'circulating_supply': 97364999.92,
#   'total_supply': 999999999.0,
#   'ath': 300.71,
#   'atl': 87.73,
#   'last_updated': '2026-02-23T18:28:18.410Z'},
#  {'coin_id': 'bitcoin-cash-sv',
#   'symbol': 'bsv',
#   'coin_name': 'Bitcoin SV',
#   'current_price': 1384.59,
#   'market_cap': 27690340209,
#   'market_cap_rank': 131,
#   'total_volume': 935373524,
#   'circulating_supply': 19992628.125,
#   'total_supply': 19992634.375,
#   'ath': 36495,
#   'atl': 1043.89,
#   'last_updated': '2026-02-23T18:28:18.663Z'},
#  {'coin_id': 'layerzero',
#   'symbol': 'zro',
#   'coin_name': 'LayerZero',
#   'current_price': 136.36,
#   'market_cap': 27640267397,
#   'market_cap_rank': 130,
#   'total_volume': 6849469354,
#   'circulating_supply': 202629028.12286997,
#   'total_supply': 1000000000.0,
#   'ath': 632.92,
#   'atl': 99.55,
#   'last_updated': '2026-02-23T18:28:19.087Z'},
#  {'coin_id': 'crvusd',
#   'symbol': 'crvusd',
#   'coin_name': 'crvUSD',
#   'current_price': 90.79,
#   'market_cap': 26393744866,
#   'market_cap_rank': 133,
#   'total_volume': 3335776463,
#   'circulating_supply': 290724882.696833,
#   'total_supply': 290725849.076833,
#   'ath': 96.91,
#   'atl': 78.57,
#   'last_updated': '2026-02-23T18:28:18.652Z'},
#  {'coin_id': 'pyth-network',
#   'symbol': 'pyth',
#   'coin_name': 'Pyth Network',
#   'current_price': 4.59,
#   'market_cap': 26387283243,
#   'market_cap_rank': 132,
#   'total_volume': 1346189470,
#   'circulating_supply': 5749982430.365929,
#   'total_supply': 10000000000.0,
#   'ath': 99.17,
#   'atl': 3.36,
#   'last_updated': '2026-02-23T18:28:18.564Z'},
#  {'coin_id': 'iota',
#   'symbol': 'iota',
#   'coin_name': 'IOTA',
#   'current_price': 6.02,
#   'market_cap': 25893287282,
#   'market_cap_rank': 134,
#   'total_volume': 862087070,
#   'circulating_supply': 4305863440.0,
#   'total_supply': 4825420702.0,
#   'ath': 336.22,
#   'atl': 5.75,
#   'last_updated': '2026-02-23T18:28:18.726Z'},
#  {'coin_id': 'jasmycoin',
#   'symbol': 'jasmy',
#   'coin_name': 'JasmyCoin',
#   'current_price': 0.520333,
#   'market_cap': 25752165073,
#   'market_cap_rank': 135,
#   'total_volume': 2179216311,
#   'circulating_supply': 49444999677.59027,
#   'total_supply': 50000000000.0,
#   'ath': 347.8,
#   'atl': 0.227783,
#   'last_updated': '2026-02-23T18:28:18.954Z'},
#  {'coin_id': 'the-graph',
#   'symbol': 'grt',
#   'coin_name': 'The Graph',
#   'current_price': 2.36,
#   'market_cap': 25302750772,
#   'market_cap_rank': 136,
#   'total_volume': 1304232455,
#   'circulating_supply': 10727809534.70197,
#   'total_supply': 10800262816.04821,
#   'ath': 206.81,
#   'atl': 2.12,
#   'last_updated': '2026-02-23T18:28:18.742Z'},
#  {'coin_id': 'humanity',
#   'symbol': 'h',
#   'coin_name': 'Humanity',
#   'current_price': 13.76,
#   'market_cap': 24905369437,
#   'market_cap_rank': 138,
#   'total_volume': 3243447124,
#   'circulating_supply': 1825000000.0,
#   'total_supply': 10000000000.0,
#   'ath': 34.11,
#   'atl': 1.55,
#   'last_updated': '2026-02-23T18:28:18.640Z'},
#  {'coin_id': 'frax',
#   'symbol': 'frax',
#   'coin_name': 'Legacy Frax Dollar',
#   'current_price': 90.21,
#   'market_cap': 24904219702,
#   'market_cap_rank': 137,
#   'total_volume': 267882416,
#   'circulating_supply': 276015184.0102677,
#   'total_supply': 276015184.0102677,
#   'ath': 91.66,
#   'atl': 67.16,
#   'last_updated': '2026-02-23T18:28:18.551Z'},
#  {'coin_id': 'floki',
#   'symbol': 'floki',
#   'coin_name': 'FLOKI',
#   'current_price': 0.00256557,
#   'market_cap': 24784802246,
#   'market_cap_rank': 140,
#   'total_volume': 2982764127,
#   'circulating_supply': 9654894633121.0,
#   'total_supply': 10000000000000.0,
#   'ath': 0.02877055,
#   'atl': 6.26e-06,
#   'last_updated': '2026-02-23T18:28:19.156Z'},
#  {'coin_id': 'aerodrome-finance',
#   'symbol': 'aero',
#   'coin_name': 'Aerodrome Finance',
#   'current_price': 26.95,
#   'market_cap': 24773813870,
#   'market_cap_rank': 139,
#   'total_volume': 1343564626,
#   'circulating_supply': 920182502.9801406,
#   'total_supply': 1844060794.170277,
#   'ath': 196.44,
# ...
#   'symbol': 'usdf',
#   'coin_name': 'Aster USDF',
#   'current_price': 90.81,
#   'market_cap': 13843562147,
#   'market_cap_rank': 204,
#   'total_volume': 22328750,
#   'circulating_supply': 152441653.5729042,
#   'total_supply': 152441653.5729042,
#   'ath': 94.12,
#   'atl': 70.87,
#   'last_updated': '2026-02-23T18:28:18.914Z'},
#  {'coin_id': 'ecash',
#   'symbol': 'xec',
#   'coin_name': 'eCash',
#   'current_price': 0.00068509,
#   'market_cap': 13691373307,
#   'market_cap_rank': 205,
#   'total_volume': 305035604,
#   'circulating_supply': 19992645297580.0,
#   'total_supply': 19992670297580.0,
#   'ath': 0.02773893,
#   'atl': 0.00063402,
#   'last_updated': '2026-02-23T18:28:18.917Z'},
#  {'coin_id': 'gusd',
#   'symbol': 'gusd',
#   'coin_name': 'GUSD',
#   'current_price': 91.05,
#   'market_cap': 13623618287,
#   'market_cap_rank': 206,
#   'total_volume': 124355827,
#   'circulating_supply': 149790000.0,
#   'total_supply': 320000000.0,
#   'ath': 92.35,
#   'atl': 86.82,
#   'last_updated': '2026-02-23T18:28:18.906Z'},
#  {'coin_id': 'theo-short-duration-us-treasury-fund',
#   'symbol': 'thbill',
#   'coin_name': 'Theo Short Duration US Treasury Fund',
#   'current_price': 92.17,
#   'market_cap': 13609745091,
#   'market_cap_rank': 207,
#   'total_volume': 101853373,
#   'circulating_supply': 147650114.654288,
#   'total_supply': 147650114.654288,
#   'ath': 98.66,
#   'atl': 80.46,
#   'last_updated': '2026-02-23T18:28:18.941Z'},
#  {'coin_id': 'fartcoin',
#   'symbol': 'fartcoin',
#   'coin_name': 'Fartcoin',
#   'current_price': 13.48,
#   'market_cap': 13510068552,
#   'market_cap_rank': 208,
#   'total_volume': 7704935342,
#   'circulating_supply': 999979216.93773,
#   'total_supply': 999979216.93773,
#   'ath': 214.63,
#   'atl': 1.68,
#   'last_updated': '2026-02-23T18:28:18.956Z'},
#  {'coin_id': 'sonic-3',
#   'symbol': 's',
#   'coin_name': 'Sonic',
#   'current_price': 3.54,
#   'market_cap': 13401471987,
#   'market_cap_rank': 209,
#   'total_volume': 1502366373,
#   'circulating_supply': 3784775845.0,
#   'total_supply': 3885497663.0,
#   'ath': 88.3,
#   'atl': 3.52,
#   'last_updated': '2026-02-23T18:28:19.016Z'},
#  {'coin_id': 'origintrail',
#   'symbol': 'trac',
#   'coin_name': 'OriginTrail',
#   'current_price': 29.07,
#   'market_cap': 13021300347,
#   'market_cap_rank': 210,
#   'total_volume': 759157945,
#   'circulating_supply': 447274118.0,
#   'total_supply': 500000000.0,
#   'ath': 261.16,
#   'atl': 0.290873,
#   'last_updated': '2026-02-23T18:28:18.940Z'},
#  {'coin_id': 'wemix-token',
#   'symbol': 'wemix',
#   'coin_name': 'WEMIX',
#   'current_price': 28.07,
#   'market_cap': 12970214735,
#   'market_cap_rank': 211,
#   'total_volume': 88781160,
#   'circulating_supply': 462277841.3255647,
#   'total_supply': 552473209.5478008,
#   'ath': 1836.35,
#   'atl': 9.55,
#   'last_updated': '2026-02-23T18:28:18.953Z'},
#  {'coin_id': 'mimblewimblecoin',
#   'symbol': 'mwc',
#   'coin_name': 'MimbleWimbleCoin',
#   'current_price': 1151.81,
#   'market_cap': 12623482780,
#   'market_cap_rank': 212,
#   'total_volume': 4576447,
#   'circulating_supply': 11001411.91778802,
#   'total_supply': 11001438.01778801,
#   'ath': 3360.8,
#   'atl': 21.36,
#   'last_updated': '2026-02-23T18:28:18.932Z'},
#  {'coin_id': 'havven',
#   'symbol': 'snx',
#   'coin_name': 'Synthetix',
#   'current_price': 36.16,
#   'market_cap': 12460530239,
#   'market_cap_rank': 213,
#   'total_volume': 4486532639,
#   'circulating_supply': 344516234.4572882,
#   'total_supply': 344939867.5556631,
#   'ath': 2071.19,
#   'atl': 2.42,
#   'last_updated': '2026-02-23T18:28:19.285Z'},
#  {'coin_id': 'thorchain',
#   'symbol': 'rune',
#   'coin_name': 'THORChain',
#   'current_price': 35.25,
#   'market_cap': 12364978454,
#   'market_cap_rank': 214,
#   'total_volume': 6212998307,
#   'circulating_supply': 350679393.0,
#   'total_supply': 424843285.0,
#   'ath': 1525.95,
#   'atl': 0.601495,
#   'last_updated': '2026-02-23T18:28:19.367Z'},
#  {'coin_id': 'zano',
#   'symbol': 'zano',
#   'coin_name': 'Zano',
#   'current_price': 804.12,
#   'market_cap': 12217217770,
#   'market_cap_rank': 215,
#   'total_volume': 131773584,
#   'circulating_supply': 15170792.37,
#   'total_supply': 15170803.83,
#   'ath': 1562.37,
#   'atl': 10.35,
#   'last_updated': '2026-02-23T18:28:19.052Z'},
#  {'coin_id': 'zero-gravity',
#   'symbol': '0g',
#   'coin_name': '0G',
#   'current_price': 56.88,
#   'market_cap': 12139635291,
#   'market_cap_rank': 216,
#   'total_volume': 1573823757,
#   'circulating_supply': 213199722.0,
#   'total_supply': 1000000000.0,
#   'ath': 623.04,
#   'atl': 41.11,
#   'last_updated': '2026-02-23T18:28:18.996Z'},
#  {'coin_id': 'rollbit-coin',
#   'symbol': 'rlb',
#   'coin_name': 'Rollbit Coin',
#   'current_price': 6.94,
#   'market_cap': 12125364645,
#   'market_cap_rank': 217,
#   'total_volume': 40029386,
#   'circulating_supply': 1747077024.471832,
#   'total_supply': 1747077024.471832,
#   'ath': 22.02,
#   'atl': 0.073824,
#   'last_updated': '2026-02-23T18:28:19.029Z'},
#  {'coin_id': 'immutable-x',
#   'symbol': 'imx',
#   'coin_name': 'Immutable',
#   'current_price': 14.17,
#   'market_cap': 12028096205,
#   'market_cap_rank': 218,
#   'total_volume': 1149068101,
#   'circulating_supply': 849472049.1198142,
#   'total_supply': 2000000000.0,
#   'ath': 709.31,
#   'atl': 12.15,
#   'last_updated': '2026-02-23T18:28:19.076Z'},
#  {'coin_id': 'dexe',
#   'symbol': 'dexe',
#   'coin_name': 'DeXe',
#   'current_price': 257.14,
#   'market_cap': 12016681592,
#   'market_cap_rank': 219,
#   'total_volume': 1456169248,
#   'circulating_supply': 46752636.689831376,
#   'total_supply': 96504599.33609451,
#   'ath': 2374.75,
#   'atl': 49.7,
#   'last_updated': '2026-02-23T18:28:19.302Z'},
#  {'coin_id': 'apollo-diversified-credit-securitize-fund',
#   'symbol': 'acred',
#   'coin_name': 'Apollo Diversified Credit Securitize Fund',
#   'current_price': 99813,
#   'market_cap': 11913094882,
#   'market_cap_rank': 220,
#   'total_volume': None,
#   'circulating_supply': 119353.6193169999,
#   'total_supply': 119353.6193169999,
#   'ath': 101170,
#   'atl': 85668,
#   'last_updated': '2026-02-23T18:20:07.323Z'},
#  {'coin_id': 'gmt-token',
#   'symbol': 'gomining',
#   'coin_name': 'GoMining Token',
#   'current_price': 29.3,
#   'market_cap': 11880756633,
#   'market_cap_rank': 223,
#   'total_volume': 854798786,
#   'circulating_supply': 405555826.3608998,
#   'total_supply': 405555826.3608998,
#   'ath': 48.04,
#   'atl': 5.65,
#   'last_updated': '2026-02-23T18:28:19.050Z'},
#  {'coin_id': 'safepal',
#   'symbol': 'sfp',
#   'coin_name': 'SafePal',
#   'current_price': 23.72,
#   'market_cap': 11868050730,
#   'market_cap_rank': 221,
#   'total_volume': 238156970,
#   'circulating_supply': 500000000.0,
#   'total_supply': 500000000.0,
#   'ath': 305.14,
#   'atl': 21.02,
#   'last_updated': '2026-02-23T18:28:19.047Z'},
#  {'coin_id': 'build-on',
#   'symbol': 'b',
#   'coin_name': 'BUILDon',
#   'current_price': 11.88,
#   'market_cap': 11853210990,
#   'market_cap_rank': 222,
#   'total_volume': 369587429,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 64.51,
#   'atl': 7.36,
#   'last_updated': '2026-02-23T18:28:19.121Z'},
#  {'coin_id': 'comedian',
#   'symbol': 'ban',
#   'coin_name': 'Comedian',
#   'current_price': 11.75,
#   'market_cap': 11739226083,
#   'market_cap_rank': 224,
#   'total_volume': 840200036,
#   'circulating_supply': 999961859.27,
#   'total_supply': 999961859.27,
#   'ath': 31.9,
#   'atl': 0.781169,
#   'last_updated': '2026-02-23T18:28:19.068Z'},
#  {'coin_id': 'vaulta',
#   'symbol': 'a',
#   'coin_name': 'Vaulta',
#   'current_price': 7.19,
#   'market_cap': 11683186332,
#   'market_cap_rank': 225,
#   'total_volume': 1337867257,
#   'circulating_supply': 1624603279.7873,
#   'total_supply': 2100000000.0,
#   'ath': 66.55,
#   'atl': 6.41,
#   'last_updated': '2026-02-23T18:28:19.073Z'},
#  {'coin_id': 'coco-2',
#   'symbol': 'coco',
#   'coin_name': 'coco',
#   'current_price': 11.62,
#   'market_cap': 11609815240,
#   'market_cap_rank': 226,
#   'total_volume': 14075257,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 14.11,
#   'atl': 4.55,
#   'last_updated': '2026-02-23T18:28:19.027Z'},
#  {'coin_id': 'dola-usd',
#   'symbol': 'dola',
#   'coin_name': 'DOLA',
#   'current_price': 90.52,
#   'market_cap': 11524892918,
#   'market_cap_rank': 227,
#   'total_volume': 182642353,
#   'circulating_supply': 127317177.2617751,
#   'total_supply': 183614118.240939,
#   'ath': 139.2,
#   'atl': 7.34,
#   'last_updated': '2026-02-23T18:28:19.066Z'},
#  {'coin_id': 'elrond-erd-2',
#   'symbol': 'egld',
#   'coin_name': 'MultiversX',
#   'current_price': 390.43,
#   'market_cap': 11474679170,
#   'market_cap_rank': 228,
#   'total_volume': 511994530,
#   'circulating_supply': 29390578.0,
#   'total_supply': 29390578.0,
#   'ath': 40604,
#   'atl': 346.17,
#   'last_updated': '2026-02-23T18:28:18.921Z'},
#  {'coin_id': '1inch',
#   'symbol': '1inch',
#   'coin_name': '1INCH',
#   'current_price': 8.03,
#   'market_cap': 11314711993,
#   'market_cap_rank': 229,
#   'total_volume': 1241702429,
#   'circulating_supply': 1408847430.661079,
#   'total_supply': 1499999999.997,
#   'ath': 648.39,
#   'atl': 7.55,
#   'last_updated': '2026-02-23T18:28:19.122Z'},
#  {'coin_id': 'ozone-chain',
#   'symbol': 'ozo',
#   'coin_name': 'Ozone Chain',
#   'current_price': 11.85,
#   'market_cap': 11225806575,
#   'market_cap_rank': 230,
#   'total_volume': 20172401,
#   'circulating_supply': 947649982.0,
#   'total_supply': 1000000000.0,
#   'ath': 40.49,
#   'atl': 4.99,
#   'last_updated': '2026-02-23T18:28:19.083Z'},
#  {'coin_id': 'jito-governance-token',
#   'symbol': 'jto',
#   'coin_name': 'Jito',
#   'current_price': 25.21,
#   'market_cap': 11092131151,
#   'market_cap_rank': 231,
#   'total_volume': 2182428855,
#   'circulating_supply': 439865633.8,
#   'total_supply': 1000000000.0,
#   'ath': 501.19,
#   'atl': 19.7,
#   'last_updated': '2026-02-23T18:28:19.121Z'},
#  {'coin_id': 'cow-protocol',
#   'symbol': 'cow',
#   'coin_name': 'CoW Protocol',
#   'current_price': 19.73,
#   'market_cap': 11086163289,
#   'market_cap_rank': 232,
#   'total_volume': 1833408195,
#   'circulating_supply': 560712016.2229732,
#   'total_supply': 1000000000.0,
#   'ath': 168.89,
#   'atl': 3.24,
#   'last_updated': '2026-02-23T18:28:19.154Z'},
#  {'coin_id': 'amp-token',
#   'symbol': 'amp',
#   'coin_name': 'Amp',
#   'current_price': 0.131302,
#   'market_cap': 11065747195,
#   'market_cap_rank': 233,
#   'total_volume': 757167935,
#   'circulating_supply': 84282148485.5968,
#   'total_supply': 99720008803.0992,
#   'ath': 8.86,
#   'atl': 0.11691,
#   'last_updated': '2026-02-23T18:28:19.513Z'},
#  {'coin_id': 'arweave',
#   'symbol': 'ar',
#   'coin_name': 'Arweave',
#   'current_price': 168.85,
#   'market_cap': 11061104140,
#   'market_cap_rank': 234,
#   'total_volume': 1752434729,
#   'circulating_supply': 65454185.5381511,
#   'total_supply': 65454185.5381511,
#   'ath': 6640.2,
#   'atl': 21.36,
#   'last_updated': '2026-02-23T18:28:19.082Z'},
#  {'coin_id': 'keeta',
#   'symbol': 'kta',
#   'coin_name': 'Keeta',
#   'current_price': 22.46,
#   'market_cap': 11023778360,
#   'market_cap_rank': 235,
#   'total_volume': 342561649,
#   'circulating_supply': 494859128.29340035,
#   'total_supply': 1000000000.0,
#   'ath': 143.99,
#   'atl': 0.594085,
#   'last_updated': '2026-02-23T18:28:19.062Z'},
#  {'coin_id': 'pleasing-usd',
#   'symbol': 'pusd',
#   'coin_name': 'Pleasing USD',
#   'current_price': 91.02,
#   'market_cap': 10922742302,
#   'market_cap_rank': 236,
#   'total_volume': 0.0,
#   'circulating_supply': 120000000.0,
#   'total_supply': 120000000.0,
#   'ath': 95.47,
#   'atl': 87.56,
#   'last_updated': '2026-02-23T18:28:19.025Z'},
#  {'coin_id': 'berachain-bera',
#   'symbol': 'bera',
#   'coin_name': 'Berachain',
#   'current_price': 50.74,
#   'market_cap': 10898870004,
#   'market_cap_rank': 237,
#   'total_volume': 2483016664,
#   'circulating_supply': 214698040.9819136,
#   'total_supply': 533465164.5100173,
#   'ath': 1299.39,
#   'atl': 31.56,
#   'last_updated': '2026-02-23T18:28:19.101Z'},
#  {'coin_id': 'cap-usd',
#   'symbol': 'cusd',
#   'coin_name': 'Cap USD',
#   'current_price': 90.98,
#   'market_cap': 10891367318,
#   'market_cap_rank': 238,
#   'total_volume': 1177219,
#   'circulating_supply': 118370756.016975,
#   'total_supply': 118370756.016975,
#   'ath': 103.87,
#   'atl': 84.14,
#   'last_updated': '2026-02-23T18:28:20.637Z'},
#  {'coin_id': 'walrus-2',
#   'symbol': 'wal',
#   'coin_name': 'Walrus',
#   'current_price': 6.71,
#   'market_cap': 10759552952,
#   'market_cap_rank': 239,
#   'total_volume': 708232067,
#   'circulating_supply': 1609791667.0,
#   'total_supply': 5000000000.0,
#   'ath': 64.7,
#   'atl': 6.39,
#   'last_updated': '2026-02-23T18:28:19.146Z'},
#  {'coin_id': 'loaded-lions',
#   'symbol': 'lion',
#   'coin_name': 'Loaded Lions',
#   'current_price': 0.345695,
#   'market_cap': 10593001445,
#   'market_cap_rank': 240,
#   'total_volume': 67213972,
#   'circulating_supply': 30642643274.0,
#   'total_supply': 100000000000.0,
#   'ath': 2.77,
#   'atl': 0.193689,
#   'last_updated': '2026-02-23T18:28:19.079Z'},
#  {'coin_id': 'bitmart-token',
#   'symbol': 'bmx',
#   'coin_name': 'BitMart',
#   'current_price': 30.81,
#   'market_cap': 10453300681,
#   'market_cap_rank': 241,
#   'total_volume': 451710245,
#   'circulating_supply': 339412030.0,
#   'total_supply': 639412030.0,
#   'ath': 52.71,
#   'atl': 0.501523,
#   'last_updated': '2026-02-23T18:28:19.077Z'},
#  {'coin_id': 'cash-4',
#   'symbol': 'cash',
#   'coin_name': 'CASH',
#   'current_price': 90.99,
#   'market_cap': 10312413604,
#   'market_cap_rank': 242,
#   'total_volume': 631607186,
#   'circulating_supply': 113334309.030704,
#   'total_supply': 113334308.114987,
#   'ath': 93.86,
#   'atl': 86.47,
#   'last_updated': '2026-02-23T18:28:19.069Z'},
#  {'coin_id': 'frax-usd',
#   'symbol': 'frxusd',
#   'coin_name': 'Frax USD',
#   'current_price': 90.96,
#   'market_cap': 10306220414,
#   'market_cap_rank': 243,
#   'total_volume': 324540304,
#   'circulating_supply': 113299988.1259787,
#   'total_supply': 113300068.2525914,
#   'ath': 92.17,
#   'atl': 83.77,
#   'last_updated': '2026-02-23T18:28:19.137Z'},
#  {'coin_id': 're-protocol-reusd',
#   'symbol': 'reusd',
#   'coin_name': 'Re Protocol reUSD',
#   'current_price': 96.75,
#   'market_cap': 10157458623,
#   'market_cap_rank': 244,
#   'total_volume': 4661847,
#   'circulating_supply': 104991028.5090223,
#   'total_supply': 104991028.5090223,
#   'ath': 98.49,
#   'atl': 75.07,
#   'last_updated': '2026-02-23T18:28:19.077Z'},
#  {'coin_id': 'avant-usd',
#   'symbol': 'avusd',
#   'coin_name': 'Avant USD',
#   'current_price': 90.38,
#   'market_cap': 9976285652,
#   'market_cap_rank': 245,
#   'total_volume': 8430868,
#   'circulating_supply': 110383561.5424455,
#   'total_supply': 110383561.5424455,
#   'ath': 93.96,
#   'atl': 83.81,
#   'last_updated': '2026-02-23T18:28:19.098Z'},
#  {'coin_id': 'eigenlayer',
#   'symbol': 'eigen',
#   'coin_name': 'EigenCloud (prev. EigenLayer)',
#   'current_price': 16.63,
#   'market_cap': 9931739095,
#   'market_cap_rank': 246,
#   'total_volume': 3633013026,
#   'circulating_supply': 596583765.388169,
#   'total_supply': 1798404459.966838,
#   'ath': 479.53,
#   'atl': 15.48,
#   'last_updated': '2026-02-23T18:28:19.194Z'},
#  {'coin_id': 'livepeer',
#   'symbol': 'lpt',
#   'coin_name': 'Livepeer',
#   'current_price': 199.79,
#   'market_cap': 9927274378,
#   'market_cap_rank': 247,
#   'total_volume': 724186262,
#   'circulating_supply': 49688954.55058027,
#   'total_supply': 49688954.55058027,
#   'ath': 7340.08,
#   'atl': 25.08,
#   'last_updated': '2026-02-23T18:28:19.269Z'},
#  {'coin_id': 'standx-dusd',
#   'symbol': 'dusd',
#   'coin_name': 'StandX DUSD',
#   'current_price': 90.89,
#   'market_cap': 9827689135,
#   'market_cap_rank': 248,
#   'total_volume': 67530771,
#   'circulating_supply': 108127256.163121,
#   'total_supply': 108128129.205731,
#   'ath': 92.19,
#   'atl': 84.63,
#   'last_updated': '2026-02-23T18:28:19.116Z'},
#  {'coin_id': 'midas-mf-one',
#   'symbol': 'mf-one',
#   'coin_name': 'Midas mF-ONE',
#   'current_price': 96.4,
#   'market_cap': 9739146064,
#   'market_cap_rank': 249,
#   'total_volume': None,
#   'circulating_supply': 101028766.2860154,
#   'total_supply': 101028766.2860154,
#   'ath': 97.07,
#   'atl': 86.94,
#   'last_updated': '2026-02-23T18:25:01.723Z'},
#  {'coin_id': 'seeker',
#   'symbol': 'skr',
#   'coin_name': 'Seeker',
#   'current_price': 1.71,
#   'market_cap': 9719695293,
#   'market_cap_rank': 250,
#   'total_volume': 724003423,
#   'circulating_supply': 5700000000.0,
#   'total_supply': 10000000000.0,
#   'ath': 5.11,
#   'atl': 0.493987,
#   'last_updated': '2026-02-23T18:28:19.160Z'}]

# %%
print(f"Total data for filtered columns: {len(filtered_columns)}")
# Out:
# Total data for filtered columns: 750

# %%
import pandas as pd

crypto_df = pd.DataFrame(filtered_columns) #visualizing data in pandas
crypto_df
# Out:
#           coin_id  symbol                      coin_name  current_price  \
# 0         bitcoin     btc                        Bitcoin     5895707.00
# 1        ethereum     eth                       Ethereum      169178.00
# 2          tether    usdt                         Tether          90.97
# 3          ripple     xrp                            XRP         124.14
# 4     binancecoin     bnb                            BNB       54333.00
# ..            ...     ...                            ...            ...
# 745    eigenlayer   eigen  EigenCloud (prev. EigenLayer)          16.63
# 746      livepeer     lpt                       Livepeer         199.79
# 747   standx-dusd    dusd                    StandX DUSD          90.89
# 748  midas-mf-one  mf-one                   Midas mF-ONE          96.40
# 749        seeker     skr                         Seeker           1.71
#
#           market_cap  market_cap_rank  total_volume  circulating_supply  \
# 0    117892080849959                1  4.583479e+12        1.999370e+07
# 1     20440925651868                2  2.001022e+12        1.206924e+08
# 2     16705159045807                3  7.545121e+12        1.836242e+11
# 3      7577930067118                4  3.130771e+11        6.101858e+10
# 4      7415804403755                5  1.321726e+11        1.363590e+08
# ..               ...              ...           ...                 ...
# 745       9931739095              246  3.633013e+09        5.965838e+08
# 746       9927274378              247  7.241863e+08        4.968895e+07
# 747       9827689135              248  6.753077e+07        1.081273e+08
# 748       9739146064              249           NaN        1.010288e+08
# 749       9719695293              250  7.240034e+08        5.700000e+09
#
#      total_supply          ath          atl              last_updated
# 0    1.999373e+07  11187013.00  3993.420000  2026-02-23T18:28:21.461Z
# 1    1.206924e+08    431946.00    28.130000  2026-02-23T18:28:21.307Z
# 2    1.890912e+11       105.52    36.860000  2026-02-23T18:28:18.378Z
# 3    9.998571e+10       313.99     0.159343  2026-02-23T18:28:17.907Z
# 4    1.363590e+08    121422.00     2.580000  2026-02-23T18:28:21.068Z
# ..            ...          ...          ...                       ...
# 745  1.798404e+09       479.53    15.480000  2026-02-23T18:28:19.194Z
# 746  4.968895e+07      7340.08    25.080000  2026-02-23T18:28:19.269Z
# 747  1.081281e+08        92.19    84.630000  2026-02-23T18:28:19.116Z
# 748  1.010288e+08        97.07    86.940000  2026-02-23T18:25:01.723Z
# 749  1.000000e+10         5.11     0.493987  2026-02-23T18:28:19.160Z
#
# [750 rows x 12 columns]

# %%
# date only extract from last_updated
crypto_df["last_updated"] = pd.to_datetime(crypto_df["last_updated"]).dt.date
crypto_df
# Out:
#           coin_id  symbol                      coin_name  current_price  \
# 0         bitcoin     btc                        Bitcoin     5895707.00
# 1        ethereum     eth                       Ethereum      169178.00
# 2          tether    usdt                         Tether          90.97
# 3          ripple     xrp                            XRP         124.14
# 4     binancecoin     bnb                            BNB       54333.00
# ..            ...     ...                            ...            ...
# 745    eigenlayer   eigen  EigenCloud (prev. EigenLayer)          16.63
# 746      livepeer     lpt                       Livepeer         199.79
# 747   standx-dusd    dusd                    StandX DUSD          90.89
# 748  midas-mf-one  mf-one                   Midas mF-ONE          96.40
# 749        seeker     skr                         Seeker           1.71
#
#           market_cap  market_cap_rank  total_volume  circulating_supply  \
# 0    117892080849959                1  4.583479e+12        1.999370e+07
# 1     20440925651868                2  2.001022e+12        1.206924e+08
# 2     16705159045807                3  7.545121e+12        1.836242e+11
# 3      7577930067118                4  3.130771e+11        6.101858e+10
# 4      7415804403755                5  1.321726e+11        1.363590e+08
# ..               ...              ...           ...                 ...
# 745       9931739095              246  3.633013e+09        5.965838e+08
# 746       9927274378              247  7.241863e+08        4.968895e+07
# 747       9827689135              248  6.753077e+07        1.081273e+08
# 748       9739146064              249           NaN        1.010288e+08
# 749       9719695293              250  7.240034e+08        5.700000e+09
#
#      total_supply          ath          atl last_updated
# 0    1.999373e+07  11187013.00  3993.420000   2026-02-23
# 1    1.206924e+08    431946.00    28.130000   2026-02-23
# 2    1.890912e+11       105.52    36.860000   2026-02-23
# 3    9.998571e+10       313.99     0.159343   2026-02-23
# 4    1.363590e+08    121422.00     2.580000   2026-02-23
# ..            ...          ...          ...          ...
# 745  1.798404e+09       479.53    15.480000   2026-02-23
# 746  4.968895e+07      7340.08    25.080000   2026-02-23
# 747  1.081281e+08        92.19    84.630000   2026-02-23
# 748  1.010288e+08        97.07    86.940000   2026-02-23
# 749  1.000000e+10         5.11     0.493987   2026-02-23
#
# [750 rows x 12 columns]

# %% [markdown]
# # **Top Coins Historical Prices**

# %%
# finding top 5 coins
crypto_df.nsmallest (5, 'market_cap_rank')
# Out:
#       coin_id symbol coin_name  current_price       market_cap  \
# 0     bitcoin    btc   Bitcoin      5895707.0  117892080849959
# 250   bitcoin    btc   Bitcoin      5895707.0  117892080849959
# 500   bitcoin    btc   Bitcoin      5895707.0  117892080849959
# 1    ethereum    eth  Ethereum       169178.0   20440925651868
# 251  ethereum    eth  Ethereum       169178.0   20440925651868
#
#      market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                  1  4.583479e+12        1.999370e+07  1.999373e+07
# 250                1  4.583479e+12        1.999370e+07  1.999373e+07
# 500                1  4.583479e+12        1.999370e+07  1.999373e+07
# 1                  2  2.001022e+12        1.206924e+08  1.206924e+08
# 251                2  2.001022e+12        1.206924e+08  1.206924e+08
#
#             ath      atl last_updated
# 0    11187013.0  3993.42   2026-02-23
# 250  11187013.0  3993.42   2026-02-23
# 500  11187013.0  3993.42   2026-02-23
# 1      431946.0    28.13   2026-02-23
# 251    431946.0    28.13   2026-02-23

# %%
# getting data for top coins
#scrolling through the data from the URL And exracting the coins history for last 365 days from the day of running the code.
import requests
import pandas as pd
import time

all_coins = []

coin_ids = ['bitcoin','ethereum','tether','binancecoin','ripple']

for i in coin_ids:
  url = f"https://api.coingecko.com/api/v3/coins/{i}/market_chart?vs_currency=inr&days=365"
  response=requests.get(url)

  if response.status_code == 200:
    time.sleep(5)
    coins=response.json()
    prices = coins["prices"]#extracting data to table and converting ms to datestamp

    for ts, price in prices:
      all_coins.append({"coin_id": i,"date": pd.to_datetime(ts, unit="ms"),"price": price})

top_coins_df = pd.DataFrame(all_coins)

top_coins_df
# Out:
#       coin_id                date         price
# 0     bitcoin 2025-02-24 00:00:00  8.341958e+06
# 1     bitcoin 2025-02-25 00:00:00  7.922798e+06
# 2     bitcoin 2025-02-26 00:00:00  7.729282e+06
# 3     bitcoin 2025-02-27 00:00:00  7.314307e+06
# 4     bitcoin 2025-02-28 00:00:00  7.397417e+06
# ..        ...                 ...           ...
# 727  ethereum 2026-02-20 00:00:00  1.772492e+05
# 728  ethereum 2026-02-21 00:00:00  1.785334e+05
# 729  ethereum 2026-02-22 00:00:00  1.790643e+05
# 730  ethereum 2026-02-23 00:00:00  1.773051e+05
# 731  ethereum 2026-02-23 18:30:05  1.691703e+05
#
# [732 rows x 3 columns]

# %%
# date only extract from datestamp
top_coins_df["date"] = pd.to_datetime(top_coins_df["date"]).dt.date
top_coins_df
# Out:
#       coin_id        date         price
# 0     bitcoin  2025-02-24  8.341958e+06
# 1     bitcoin  2025-02-25  7.922798e+06
# 2     bitcoin  2025-02-26  7.729282e+06
# 3     bitcoin  2025-02-27  7.314307e+06
# 4     bitcoin  2025-02-28  7.397417e+06
# ..        ...         ...           ...
# 727  ethereum  2026-02-20  1.772492e+05
# 728  ethereum  2026-02-21  1.785334e+05
# 729  ethereum  2026-02-22  1.790643e+05
# 730  ethereum  2026-02-23  1.773051e+05
# 731  ethereum  2026-02-23  1.691703e+05
#
# [732 rows x 3 columns]

# %% [markdown]
# # **Oil Prices(WTI Crude)**

# %%
# data collection from github link
import pandas as pd

oil_df = pd.read_csv("https://raw.githubusercontent.com/datasets/oil-prices/main/data/wti-daily.csv")
oil_df
# Out:
#              Date  Price
# 0      1986-01-02  25.56
# 1      1986-01-03  26.00
# 2      1986-01-06  26.53
# 3      1986-01-07  25.85
# 4      1986-01-08  25.87
# ...           ...    ...
# 10095  2026-02-10  64.20
# 10096  2026-02-11  64.80
# 10097  2026-02-12  63.08
# 10098  2026-02-13  63.05
# 10099  2026-02-17  62.53
#
# [10100 rows x 2 columns]

# %%
# extracting data from Jan 2020 - Feb 2026 ==> mentioned in project file

oil_df['Date'] = pd.to_datetime(oil_df['Date'])
start_date = pd.to_datetime('2020-01-01')
end_date   = pd.to_datetime('2026-02-23')

oil_df = oil_df[(oil_df['Date'] >= start_date) & (oil_df['Date'] <= end_date)]

oil_df
# Out:
#             Date  Price
# 8569  2020-01-02  61.17
# 8570  2020-01-03  63.00
# 8571  2020-01-06  63.27
# 8572  2020-01-07  62.70
# 8573  2020-01-08  59.65
# ...          ...    ...
# 10095 2026-02-10  64.20
# 10096 2026-02-11  64.80
# 10097 2026-02-12  63.08
# 10098 2026-02-13  63.05
# 10099 2026-02-17  62.53
#
# [1531 rows x 2 columns]

# %%
# saving file as csv file
oil_df.to_csv("oil_prices.csv",index = False)
oil_df
# Out:
#             Date  Price
# 8569  2020-01-02  61.17
# 8570  2020-01-03  63.00
# 8571  2020-01-06  63.27
# 8572  2020-01-07  62.70
# 8573  2020-01-08  59.65
# ...          ...    ...
# 10095 2026-02-10  64.20
# 10096 2026-02-11  64.80
# 10097 2026-02-12  63.08
# 10098 2026-02-13  63.05
# 10099 2026-02-17  62.53
#
# [1531 rows x 2 columns]

# %%
# Jan 2020 - Feb 2026 extracted from all prices and read file
oil_df = pd.read_csv("/content/oil_prices.csv")
oil_df
# Out:
#             Date  Price
# 0     2020-01-02  61.17
# 1     2020-01-03  63.00
# 2     2020-01-06  63.27
# 3     2020-01-07  62.70
# 4     2020-01-08  59.65
# ...          ...    ...
# 1526  2026-02-10  64.20
# 1527  2026-02-11  64.80
# 1528  2026-02-12  63.08
# 1529  2026-02-13  63.05
# 1530  2026-02-17  62.53
#
# [1531 rows x 2 columns]

# %% [markdown]
# # **Stock Prices (Yahoo Finance API)**

# %%
# collect following stocks data from Yahoo Finance API

# %%
import yfinance as YF
import pandas as pd

tickers = ["^GSPC", "^IXIC", "^NSEI"]
start_date = "2020-01-01"
end_date = "2026-02-23"

stocks_df = YF.download(tickers, start=start_date, end=end_date, group_by="ticker")
stocks_df.head()
# Out:
# /tmp/ipython-input-1748226739.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks_df = YF.download(tickers, start=start_date, end=end_date, group_by="ticker")
# [*********************100%***********************]  3 of 3 completed
# Ticker            ^IXIC                                                       \
# Price              Open         High          Low        Close        Volume
# Date
# 2020-01-01          NaN          NaN          NaN          NaN           NaN
# 2020-01-02  9039.459961  9093.429688  9010.889648  9092.190430  2.862700e+09
# 2020-01-03  8976.429688  9065.759766  8976.429688  9020.769531  2.586520e+09
# 2020-01-06  8943.500000  9072.410156  8943.500000  9071.469727  2.810450e+09
# 2020-01-07  9076.639648  9091.929688  9042.549805  9068.580078  2.381740e+09
#
# Ticker            ^GSPC                                                       \
# Price              Open         High          Low        Close        Volume
# Date
# 2020-01-01          NaN          NaN          NaN          NaN           NaN
# 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098  3.459930e+09
# 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098  3.484700e+09
# 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029  3.702460e+09
# 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932  3.435910e+09
#
# Ticker             ^NSEI
# Price               Open          High           Low         Close    Volume
# Date
# 2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000  304100.0
# 2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195  407700.0
# 2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391  428800.0
# 2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805  396500.0
# 2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195  447800.0

# %%
# colleting data separately for easy undersating
# "^NSEI"
stocks1_df = stocks_df["^NSEI"].reset_index()
stocks1_df
# Out:
# Price       Date          Open          High           Low         Close  \
# 0     2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000
# 1     2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195
# 2     2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391
# 3     2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805
# 4     2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195
# ...          ...           ...           ...           ...           ...
# 1588  2026-02-16  25423.599609  25697.000000  25372.699219  25682.750000
# 1589  2026-02-17  25637.949219  25764.400391  25570.300781  25725.400391
# 1590  2026-02-18  25752.650391  25828.050781  25645.150391  25819.349609
# 1591  2026-02-19  25873.349609  25885.300781  25388.750000  25454.349609
# 1592  2026-02-20  25406.550781  25663.550781  25379.750000  25571.250000
#
# Price    Volume
# 0      304100.0
# 1      407700.0
# 2      428800.0
# 3      396500.0
# 4      447800.0
# ...         ...
# 1588   275800.0
# 1589   344100.0
# 1590   310200.0
# 1591   298200.0
# 1592   296600.0
#
# [1593 rows x 6 columns]

# %%
# adding column ==> "tickers"
stocks1_df.insert(1, "Ticker", "^NSEI")
stocks1_df
# Out:
# Price       Date Ticker          Open          High           Low  \
# 0     2020-01-01  ^NSEI  12202.150391  12222.200195  12165.299805
# 1     2020-01-02  ^NSEI  12198.549805  12289.900391  12195.250000
# 2     2020-01-03  ^NSEI  12261.099609  12265.599609  12191.349609
# 3     2020-01-06  ^NSEI  12170.599609  12179.099609  11974.200195
# 4     2020-01-07  ^NSEI  12079.099609  12152.150391  12005.349609
# ...          ...    ...           ...           ...           ...
# 1588  2026-02-16  ^NSEI  25423.599609  25697.000000  25372.699219
# 1589  2026-02-17  ^NSEI  25637.949219  25764.400391  25570.300781
# 1590  2026-02-18  ^NSEI  25752.650391  25828.050781  25645.150391
# 1591  2026-02-19  ^NSEI  25873.349609  25885.300781  25388.750000
# 1592  2026-02-20  ^NSEI  25406.550781  25663.550781  25379.750000
#
# Price         Close    Volume
# 0      12182.500000  304100.0
# 1      12282.200195  407700.0
# 2      12226.650391  428800.0
# 3      11993.049805  396500.0
# 4      12052.950195  447800.0
# ...             ...       ...
# 1588   25682.750000  275800.0
# 1589   25725.400391  344100.0
# 1590   25819.349609  310200.0
# 1591   25454.349609  298200.0
# 1592   25571.250000  296600.0
#
# [1593 rows x 7 columns]

# %%
# finding nulls from collected data
stocks1_df.isnull().sum()
# Out:
# Price
# Date       0
# Ticker     0
# Open      72
# High      72
# Low       72
# Close     72
# Volume    72
# dtype: int64

# %%
# remove null for clear undersating
stocks1_df = stocks1_df.dropna()
stocks1_df
# Out:
# Price       Date Ticker          Open          High           Low  \
# 0     2020-01-01  ^NSEI  12202.150391  12222.200195  12165.299805
# 1     2020-01-02  ^NSEI  12198.549805  12289.900391  12195.250000
# 2     2020-01-03  ^NSEI  12261.099609  12265.599609  12191.349609
# 3     2020-01-06  ^NSEI  12170.599609  12179.099609  11974.200195
# 4     2020-01-07  ^NSEI  12079.099609  12152.150391  12005.349609
# ...          ...    ...           ...           ...           ...
# 1588  2026-02-16  ^NSEI  25423.599609  25697.000000  25372.699219
# 1589  2026-02-17  ^NSEI  25637.949219  25764.400391  25570.300781
# 1590  2026-02-18  ^NSEI  25752.650391  25828.050781  25645.150391
# 1591  2026-02-19  ^NSEI  25873.349609  25885.300781  25388.750000
# 1592  2026-02-20  ^NSEI  25406.550781  25663.550781  25379.750000
#
# Price         Close    Volume
# 0      12182.500000  304100.0
# 1      12282.200195  407700.0
# 2      12226.650391  428800.0
# 3      11993.049805  396500.0
# 4      12052.950195  447800.0
# ...             ...       ...
# 1588   25682.750000  275800.0
# 1589   25725.400391  344100.0
# 1590   25819.349609  310200.0
# 1591   25454.349609  298200.0
# 1592   25571.250000  296600.0
#
# [1521 rows x 7 columns]

# %%
# data collected  for IXIC and GSPC similarly ====> codes where written in same line

# %%
# "^IXIC"
stocks2_df = stocks_df["^IXIC"].reset_index()

stocks2_df.insert(1, "Ticker", "^IXIC") # inserting column

stocks2_df = stocks2_df.dropna() # removing nulls

stocks2_df
# Out:
# Price       Date Ticker          Open          High           Low  \
# 1     2020-01-02  ^IXIC   9039.459961   9093.429688   9010.889648
# 2     2020-01-03  ^IXIC   8976.429688   9065.759766   8976.429688
# 3     2020-01-06  ^IXIC   8943.500000   9072.410156   8943.500000
# 4     2020-01-07  ^IXIC   9076.639648   9091.929688   9042.549805
# 5     2020-01-08  ^IXIC   9068.030273   9168.889648   9059.379883
# ...          ...    ...           ...           ...           ...
# 1587  2026-02-13  ^IXIC  22561.460938  22742.060547  22402.380859
# 1589  2026-02-17  ^IXIC  22394.759766  22690.830078  22256.759766
# 1590  2026-02-18  ^IXIC  22629.849609  22895.960938  22597.769531
# 1591  2026-02-19  ^IXIC  22639.880859  22768.830078  22583.609375
# 1592  2026-02-20  ^IXIC  22542.279297  22948.869141  22539.050781
#
# Price         Close        Volume
# 1       9092.190430  2.862700e+09
# 2       9020.769531  2.586520e+09
# 3       9071.469727  2.810450e+09
# 4       9068.580078  2.381740e+09
# 5       9129.240234  2.472620e+09
# ...             ...           ...
# 1587   22546.669922  7.964830e+09
# 1589   22578.380859  7.654300e+09
# 1590   22753.630859  7.705590e+09
# 1591   22682.730469  6.984780e+09
# 1592   22886.070312  8.063070e+09
#
# [1542 rows x 7 columns]

# %%
# "^GSPC"
stocks3_df = stocks_df["^GSPC"].reset_index()

stocks3_df.insert(1, "Ticker", "^GSPC") # inserting column

stocks3_df = stocks3_df.dropna() # removing nulls

stocks3_df
# Out:
# Price       Date Ticker         Open         High          Low        Close  \
# 1     2020-01-02  ^GSPC  3244.669922  3258.139893  3235.530029  3257.850098
# 2     2020-01-03  ^GSPC  3226.360107  3246.149902  3222.340088  3234.850098
# 3     2020-01-06  ^GSPC  3217.550049  3246.840088  3214.639893  3246.280029
# 4     2020-01-07  ^GSPC  3241.860107  3244.909912  3232.429932  3237.179932
# 5     2020-01-08  ^GSPC  3238.590088  3267.070068  3236.669922  3253.050049
# ...          ...    ...          ...          ...          ...          ...
# 1587  2026-02-13  ^GSPC  6834.270020  6881.959961  6794.549805  6836.169922
# 1589  2026-02-17  ^GSPC  6819.859863  6866.990234  6775.500000  6843.220215
# 1590  2026-02-18  ^GSPC  6855.479980  6909.120117  6849.660156  6881.310059
# 1591  2026-02-19  ^GSPC  6861.339844  6879.120117  6833.060059  6861.890137
# 1592  2026-02-20  ^GSPC  6843.259766  6915.859863  6836.330078  6909.509766
#
# Price        Volume
# 1      3.459930e+09
# 2      3.484700e+09
# 3      3.702460e+09
# 4      3.435910e+09
# 5      3.726840e+09
# ...             ...
# 1587   5.718360e+09
# 1589   5.418480e+09
# 1590   5.098160e+09
# 1591   5.151690e+09
# 1592   5.432480e+09
#
# [1542 rows x 7 columns]

# %%
# merging all stocks after cleaning nulls and adding column for comparision
stk_df = pd.concat([stocks1_df, stocks2_df, stocks3_df])
stk_df
# Out:
# Price       Date Ticker          Open          High           Low  \
# 0     2020-01-01  ^NSEI  12202.150391  12222.200195  12165.299805
# 1     2020-01-02  ^NSEI  12198.549805  12289.900391  12195.250000
# 2     2020-01-03  ^NSEI  12261.099609  12265.599609  12191.349609
# 3     2020-01-06  ^NSEI  12170.599609  12179.099609  11974.200195
# 4     2020-01-07  ^NSEI  12079.099609  12152.150391  12005.349609
# ...          ...    ...           ...           ...           ...
# 1587  2026-02-13  ^GSPC   6834.270020   6881.959961   6794.549805
# 1589  2026-02-17  ^GSPC   6819.859863   6866.990234   6775.500000
# 1590  2026-02-18  ^GSPC   6855.479980   6909.120117   6849.660156
# 1591  2026-02-19  ^GSPC   6861.339844   6879.120117   6833.060059
# 1592  2026-02-20  ^GSPC   6843.259766   6915.859863   6836.330078
#
# Price         Close        Volume
# 0      12182.500000  3.041000e+05
# 1      12282.200195  4.077000e+05
# 2      12226.650391  4.288000e+05
# 3      11993.049805  3.965000e+05
# 4      12052.950195  4.478000e+05
# ...             ...           ...
# 1587    6836.169922  5.718360e+09
# 1589    6843.220215  5.418480e+09
# 1590    6881.310059  5.098160e+09
# 1591    6861.890137  5.151690e+09
# 1592    6909.509766  5.432480e+09
#
# [4605 rows x 7 columns]

# %% [markdown]
# # **SQL connection**

# %%
# import and creating database
import sqlite3

conn = sqlite3.connect("cross_mtk.db")
cursor = conn.cursor()

# %%
# creating tables for cryptocurrencies

conn.execute("""CREATE TABLE cryptocurrencies
                 (id VARCHAR(50) PRIMARY KEY,
                 symbol VARCHAR(10),
                 name VARCHAR(100),
                 current_price DECIMAL(18, 6),
                 market_cap BIGINT,
                 market_cap_rank INT,
                 total_volume BIGINT,
                 circulating_supply DECIMAL(20, 6),
                 total_supply DECIMAL(20, 6),
                 ath DECIMAL(18, 6),
                 atl DECIMAL(18, 6),
                 date DATE
                 );

                 """)
conn.commit() # apply the changes to the sqlite3

# %%
#creating table for Crypto_prices

conn.execute("""CREATE TABLE top_coins
                 (coin_id VARCHAR(50),
                 date DATE,
                 price DECIMAL(18, 6)
                 );

                 """)
conn.commit()

# %%
#creating table for Oil_prices

conn.execute("""CREATE TABLE oil_prices
                 (date DATE PRIMARY KEY,
                 price_INR DECIMAL(18, 6)
                 );

                 """)
conn.commit()

# %%
#creating table for Stock_prices
conn.execute("""CREATE TABLE stk_prices
                 (date DATE,
                 open DECIMAL(18, 6),
                 high DECIMAL(18, 6),
                 low DECIMAL(18, 6),
                 close DECIMAL(18, 6),
                 volume BIGINT,
                 ticker VARCHAR(20)
                 );

                 """)
conn.commit()

# %% [markdown]
# # **Pushing data frames in to sqlite3**

# %%
import sqlite3

conn = sqlite3.connect ("cross_mtk.db")

crypto_df.to_sql ("cryptocurrencies", conn,if_exists = "replace", index = False) # push crypto_df to sqlite
top_coins_df.to_sql ("top_coins", conn,if_exists = "replace", index = False)
oil_df.to_sql ("oil_prices", conn,if_exists = "replace", index = False)
stk_df.to_sql ("stk_prices", conn,if_exists = "replace", index = False)

conn.commit()

# %%
 # execute SQL query to fetch table names in sqlite_master
tables = conn.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
print (tables)
# Out:
# [('cryptocurrencies',), ('top_coins',), ('oil_prices',), ('stk_prices',)]

# %% [markdown]
# # **Querries where mentioned in project file**

# %% [markdown]
# ## **Cryptocurrencies**

# %%
# show/read cryptocurrencies table
df = pd.read_sql("SELECT * FROM  cryptocurrencies;", conn)
df
# Out:
#           coin_id  symbol                      coin_name  current_price  \
# 0         bitcoin     btc                        Bitcoin     5895707.00
# 1        ethereum     eth                       Ethereum      169178.00
# 2          tether    usdt                         Tether          90.97
# 3          ripple     xrp                            XRP         124.14
# 4     binancecoin     bnb                            BNB       54333.00
# ..            ...     ...                            ...            ...
# 745    eigenlayer   eigen  EigenCloud (prev. EigenLayer)          16.63
# 746      livepeer     lpt                       Livepeer         199.79
# 747   standx-dusd    dusd                    StandX DUSD          90.89
# 748  midas-mf-one  mf-one                   Midas mF-ONE          96.40
# 749        seeker     skr                         Seeker           1.71
#
#           market_cap  market_cap_rank  total_volume  circulating_supply  \
# 0    117892080849959                1  4.583479e+12        1.999370e+07
# 1     20440925651868                2  2.001022e+12        1.206924e+08
# 2     16705159045807                3  7.545121e+12        1.836242e+11
# 3      7577930067118                4  3.130771e+11        6.101858e+10
# 4      7415804403755                5  1.321726e+11        1.363590e+08
# ..               ...              ...           ...                 ...
# 745       9931739095              246  3.633013e+09        5.965838e+08
# 746       9927274378              247  7.241863e+08        4.968895e+07
# 747       9827689135              248  6.753077e+07        1.081273e+08
# 748       9739146064              249           NaN        1.010288e+08
# 749       9719695293              250  7.240034e+08        5.700000e+09
#
#      total_supply          ath          atl last_updated
# 0    1.999373e+07  11187013.00  3993.420000   2026-02-23
# 1    1.206924e+08    431946.00    28.130000   2026-02-23
# 2    1.890912e+11       105.52    36.860000   2026-02-23
# 3    9.998571e+10       313.99     0.159343   2026-02-23
# 4    1.363590e+08    121422.00     2.580000   2026-02-23
# ..            ...          ...          ...          ...
# 745  1.798404e+09       479.53    15.480000   2026-02-23
# 746  4.968895e+07      7340.08    25.080000   2026-02-23
# 747  1.081281e+08        92.19    84.630000   2026-02-23
# 748  1.010288e+08        97.07    86.940000   2026-02-23
# 749  1.000000e+10         5.11     0.493987   2026-02-23
#
# [750 rows x 12 columns]

# %%
# 1. Find the top 3 cryptocurrencies by market cap.
import sqlite3
import pandas as pd

conn = sqlite3.connect ("cross_mtk.db")

df = pd.read_sql ("SELECT * FROM cryptocurrencies ORDER BY market_cap DESC LIMIT 3;", conn)

df
# Out:
#    coin_id symbol coin_name  current_price       market_cap  market_cap_rank  \
# 0  bitcoin    btc   Bitcoin      5895707.0  117892080849959                1
# 1  bitcoin    btc   Bitcoin      5895707.0  117892080849959                1
# 2  bitcoin    btc   Bitcoin      5895707.0  117892080849959                1
#
#    total_volume  circulating_supply  total_supply         ath      atl  \
# 0  4.583479e+12          19993700.0    19993731.0  11187013.0  3993.42
# 1  4.583479e+12          19993700.0    19993731.0  11187013.0  3993.42
# 2  4.583479e+12          19993700.0    19993731.0  11187013.0  3993.42
#
#   last_updated
# 0   2026-02-23
# 1   2026-02-23
# 2   2026-02-23

# %%
# 2. List all coins where circulating supply exceeds 90% of total supply.

df = pd.read_sql ("SELECT * FROM cryptocurrencies WHERE circulating_supply > (total_supply * 0.9);", conn)

df
# Out:
#                coin_id  symbol          coin_name  current_price  \
# 0              bitcoin     btc            Bitcoin     5895707.00
# 1             ethereum     eth           Ethereum      169178.00
# 2               tether    usdt             Tether          90.97
# 3          binancecoin     bnb                BNB       54333.00
# 4             usd-coin    usdc               USDC          90.97
# ..                 ...     ...                ...            ...
# 424  re-protocol-reusd   reusd  Re Protocol reUSD          96.75
# 425          avant-usd   avusd          Avant USD          90.38
# 426           livepeer     lpt           Livepeer         199.79
# 427        standx-dusd    dusd        StandX DUSD          90.89
# 428       midas-mf-one  mf-one       Midas mF-ONE          96.40
#
#           market_cap  market_cap_rank  total_volume  circulating_supply  \
# 0    117892080849959                1  4.583479e+12        1.999370e+07
# 1     20440925651868                2  2.001022e+12        1.206924e+08
# 2     16705159045807                3  7.545121e+12        1.836242e+11
# 3      7415804403755                5  1.321726e+11        1.363590e+08
# 4      6798842455725                6  1.174213e+12        7.474304e+10
# ..               ...              ...           ...                 ...
# 424      10157458623              244  4.661847e+06        1.049910e+08
# 425       9976285652              245  8.430868e+06        1.103836e+08
# 426       9927274378              247  7.241863e+08        4.968895e+07
# 427       9827689135              248  6.753077e+07        1.081273e+08
# 428       9739146064              249           NaN        1.010288e+08
#
#      total_supply          ath      atl last_updated
# 0    1.999373e+07  11187013.00  3993.42   2026-02-23
# 1    1.206924e+08    431946.00    28.13   2026-02-23
# 2    1.890912e+11       105.52    36.86   2026-02-23
# 3    1.363590e+08    121422.00     2.58   2026-02-23
# 4    7.475110e+10      1327.87    65.31   2026-02-23
# ..            ...          ...      ...          ...
# 424  1.049910e+08        98.49    75.07   2026-02-23
# 425  1.103836e+08        93.96    83.81   2026-02-23
# 426  4.968895e+07      7340.08    25.08   2026-02-23
# 427  1.081281e+08        92.19    84.63   2026-02-23
# 428  1.010288e+08        97.07    86.94   2026-02-23
#
# [429 rows x 12 columns]

# %%
# 3. Get coins that are within 10% of their all-time-high (ATH).

df = pd.read_sql ("SELECT * FROM cryptocurrencies WHERE current_price >= 0.9 * Ath;", conn)

df
# Out:
#                coin_id  symbol          coin_name  current_price  \
# 0                 usds    usds               USDS          90.96
# 1          ethena-usde    usde        Ethena USDe          90.90
# 2            usd1-wlfi    usd1               USD1          90.92
# 3                  dai     dai                Dai          90.95
# 4           paypal-usd   pyusd         PayPal USD          90.95
# ..                 ...     ...                ...            ...
# 139           frax-usd  frxusd           Frax USD          90.96
# 140  re-protocol-reusd   reusd  Re Protocol reUSD          96.75
# 141          avant-usd   avusd          Avant USD          90.38
# 142        standx-dusd    dusd        StandX DUSD          90.89
# 143       midas-mf-one  mf-one       Midas mF-ONE          96.40
#
#        market_cap  market_cap_rank  total_volume  circulating_supply  \
# 0    899649613562               13  1.315232e+09        9.890911e+09
# 1    556733473323               17  1.316578e+10        6.123353e+09
# 2    437039854624               22  4.236207e+11        4.806978e+09
# 3    380069397512               24  6.465339e+09        4.177043e+09
# 4    370410232363               26  1.055461e+10        4.072620e+09
# ..            ...              ...           ...                 ...
# 139   10306220414              243  3.245403e+08        1.133000e+08
# 140   10157458623              244  4.661847e+06        1.049910e+08
# 141    9976285652              245  8.430868e+06        1.103836e+08
# 142    9827689135              248  6.753077e+07        1.081273e+08
# 143    9739146064              249           NaN        1.010288e+08
#
#      total_supply    ath    atl last_updated
# 0    9.888644e+09  92.23  79.67   2026-02-23
# 1    6.120331e+09  92.91  78.05   2026-02-23
# 2    4.806978e+09  92.17  83.75   2026-02-23
# 3    4.178836e+09  92.29  64.85   2026-02-23
# 4    4.072620e+09  92.20  80.95   2026-02-23
# ..            ...    ...    ...          ...
# 139  1.133001e+08  92.17  83.77   2026-02-23
# 140  1.049910e+08  98.49  75.07   2026-02-23
# 141  1.103836e+08  93.96  83.81   2026-02-23
# 142  1.081281e+08  92.19  84.63   2026-02-23
# 143  1.010288e+08  97.07  86.94   2026-02-23
#
# [144 rows x 12 columns]

# %%
# 4. Find the average market cap rank of coins with volume above $1B.

df = pd.read_sql ("SELECT AVG(market_cap_rank) FROM cryptocurrencies WHERE total_volume > 1000000000;", conn)

df
# Out:
#    AVG(market_cap_rank)
# 0            101.736111

# %%
# 5. Get the most recently updated coin.

df = pd.read_sql ("SELECT * FROM cryptocurrencies ORDER BY last_updated DESC LIMIT 1;", conn)

df
# Out:
#    coin_id symbol coin_name  current_price       market_cap  market_cap_rank  \
# 0  bitcoin    btc   Bitcoin      5895707.0  117892080849959                1
#
#    total_volume  circulating_supply  total_supply         ath      atl  \
# 0  4.583479e+12          19993700.0    19993731.0  11187013.0  3993.42
#
#   last_updated
# 0   2026-02-23

# %% [markdown]
# ## **Crypto_Prices (Daily Prices of Top Coins)**

# %%
df = pd.read_sql("SELECT * FROM  top_coins;", conn)
df
# Out:
#       coin_id        date         price
# 0     bitcoin  2025-02-24  8.341958e+06
# 1     bitcoin  2025-02-25  7.922798e+06
# 2     bitcoin  2025-02-26  7.729282e+06
# 3     bitcoin  2025-02-27  7.314307e+06
# 4     bitcoin  2025-02-28  7.397417e+06
# ..        ...         ...           ...
# 727  ethereum  2026-02-20  1.772492e+05
# 728  ethereum  2026-02-21  1.785334e+05
# 729  ethereum  2026-02-22  1.790643e+05
# 730  ethereum  2026-02-23  1.773051e+05
# 731  ethereum  2026-02-23  1.691703e+05
#
# [732 rows x 3 columns]

# %%
# 1. Find the highest daily price of Bitcoin in the last 365 days.

df = pd.read_sql ("SELECT * FROM top_coins WHERE coin_id = 'bitcoin' AND date >= date('now', '-365 days') ORDER BY Date DESC LIMIT 1;", conn)

df
# Out:
#    coin_id        date         price
# 0  bitcoin  2026-02-23  6.132044e+06

# %%
# 2. Calculate the average daily price of Ethereum in the past 1 year.

df = pd.read_sql ("SELECT AVG(price) FROM top_coins WHERE coin_id = 'ethereum' AND date >= date('now', '-1 year');", conn)

df
# Out:
#       AVG(price)
# 0  263784.088188

# %%
# 3. Show the daily price trend of Bitcoin in January 2025. (or change the month and year according you your data)

df = pd.read_sql("SELECT * FROM top_coins WHERE coin_id = 'bitcoin' AND Date BETWEEN '2025-02-01' AND '2026-02-28' ORDER BY Date;", conn)

df
# Out:
#      coin_id        date         price
# 0    bitcoin  2025-02-24  8.341958e+06
# 1    bitcoin  2025-02-25  7.922798e+06
# 2    bitcoin  2025-02-26  7.729282e+06
# 3    bitcoin  2025-02-27  7.314307e+06
# 4    bitcoin  2025-02-28  7.397417e+06
# ..       ...         ...           ...
# 361  bitcoin  2026-02-20  6.092367e+06
# 362  bitcoin  2026-02-21  6.166731e+06
# 363  bitcoin  2026-02-22  6.167422e+06
# 364  bitcoin  2026-02-23  6.132044e+06
# 365  bitcoin  2026-02-23  5.895648e+06
#
# [366 rows x 3 columns]

# %%
# 4. Find the coin with the highest average price over 1 year.

df = pd.read_sql ("SELECT coin_id, AVG(price) AS avg_price FROM top_coins GROUP BY coin_id ORDER BY avg_price DESC LIMIT 1;", conn)

df
# Out:
#    coin_id     avg_price
# 0  bitcoin  8.685722e+06

# %%
# 5. Get the % change in Bitcoin’s price between Feb 2025 and Feb 2026.

df = pd.read_sql ("""SELECT
(SELECT price FROM top_coins WHERE coin_id = 'bitcoin' AND date = '2025-02-24') /
(SELECT price FROM top_coins WHERE coin_id = 'bitcoin' AND date = '2026-02-22') * 100 AS percent_change;""", conn)

df
# Out:
#    percent_change
# 0      135.258442

# %% [markdown]
# ## **Oil_Price**

# %%
df - pd.read_sql ("SELECT * FROM  oil_prices;", conn)
df
# Out:
#    percent_change
# 0      135.258442

# %%
# 1. Find the highest oil price in the last 5 years.

df = pd.read_sql("""SELECT MAX(Price) AS highest_price FROM oil_prices WHERE Date >= ( SELECT substr
(MAX (date), 1, 4) - 5 || '-01-01' FROM oil_prices);""", conn)

df
# Out:
#    highest_price
# 0         123.64

# %%
# 2. Get the average oil price per year.

df = pd.read_sql ("SELECT substr(date, 1, 4) AS year, AVG(price) AS avg_price_per_year FROM oil_prices GROUP BY strftime('%Y', Date);", conn)

df
# Out:
#    year  avg_price_per_year
# 0  2020           39.160437
# 1  2021           68.135100
# 2  2022           94.902869
# 3  2023           77.576532
# 4  2024           76.632240
# 5  2025           65.388105
# 6  2026           61.238065

# %%
# 3. Show oil prices during COVID crash (March–April 2020).

df = pd.read_sql ("SELECT * FROM oil_prices WHERE date BETWEEN '2020-03-01' AND '2020-04-31' ORDER BY date;", conn)

df
# Out:
#           Date  Price
# 0   2020-03-02  46.78
# 1   2020-03-03  47.27
# 2   2020-03-04  46.78
# 3   2020-03-05  45.90
# 4   2020-03-06  41.14
# 5   2020-03-09  31.05
# 6   2020-03-10  34.47
# 7   2020-03-11  33.13
# 8   2020-03-12  31.56
# 9   2020-03-13  31.72
# 10  2020-03-16  28.96
# 11  2020-03-17  26.96
# 12  2020-03-18  20.48
# 13  2020-03-19  25.09
# 14  2020-03-20  19.48
# 15  2020-03-23  23.33
# 16  2020-03-24  21.03
# 17  2020-03-25  20.75
# 18  2020-03-26  16.60
# 19  2020-03-27  15.48
# 20  2020-03-30  14.10
# 21  2020-03-31  20.51
# 22  2020-04-01  20.28
# 23  2020-04-02  25.18
# 24  2020-04-03  28.36
# 25  2020-04-06  26.21
# 26  2020-04-07  23.54
# 27  2020-04-08  24.97
# 28  2020-04-09  22.90
# 29  2020-04-13  22.36
# 30  2020-04-14  20.15
# 31  2020-04-15  19.96
# 32  2020-04-16  19.82
# 33  2020-04-17  18.31
# 34  2020-04-20 -36.98
# 35  2020-04-21   8.91
# 36  2020-04-22  13.64
# 37  2020-04-23  15.06
# 38  2020-04-24  15.99
# 39  2020-04-27  12.17
# 40  2020-04-28  12.40
# 41  2020-04-29  15.04
# 42  2020-04-30  19.23

# %%
# 4. Find the lowest price of oil in the last 10 years.

df = pd.read_sql ("SELECT MIN(price) AS lowest_price FROM oil_prices WHERE date >= (SELECT date('now', '-10 years'));", conn)

df
# Out:
#    lowest_price
# 0        -36.98

# %%
# 5. Calculate the volatility of oil prices (max-min difference per year).

df = pd.read_sql("SELECT substr(date, 1, 4) AS year, MAX(price) - MIN(price) AS volatility FROM oil_prices GROUP BY strftime('%Y', Date);", conn)

df
# Out:
#    year  volatility
# 0  2020      100.25
# 1  2021       38.17
# 2  2022       52.59
# 3  2023       27.06
# 4  2024       20.96
# 5  2025       25.29
# 6  2026        8.79

# %% [markdown]
# ## **Stock_Prices**

# %%
df = pd.read_sql("SELECT * FROM  stk_prices;", conn)
df
# Out:
#                      Date Ticker          Open          High           Low  \
# 0     2020-01-01 00:00:00  ^NSEI  12202.150391  12222.200195  12165.299805
# 1     2020-01-02 00:00:00  ^NSEI  12198.549805  12289.900391  12195.250000
# 2     2020-01-03 00:00:00  ^NSEI  12261.099609  12265.599609  12191.349609
# 3     2020-01-06 00:00:00  ^NSEI  12170.599609  12179.099609  11974.200195
# 4     2020-01-07 00:00:00  ^NSEI  12079.099609  12152.150391  12005.349609
# ...                   ...    ...           ...           ...           ...
# 4600  2026-02-13 00:00:00  ^GSPC   6834.270020   6881.959961   6794.549805
# 4601  2026-02-17 00:00:00  ^GSPC   6819.859863   6866.990234   6775.500000
# 4602  2026-02-18 00:00:00  ^GSPC   6855.479980   6909.120117   6849.660156
# 4603  2026-02-19 00:00:00  ^GSPC   6861.339844   6879.120117   6833.060059
# 4604  2026-02-20 00:00:00  ^GSPC   6843.259766   6915.859863   6836.330078
#
#              Close        Volume
# 0     12182.500000  3.041000e+05
# 1     12282.200195  4.077000e+05
# 2     12226.650391  4.288000e+05
# 3     11993.049805  3.965000e+05
# 4     12052.950195  4.478000e+05
# ...            ...           ...
# 4600   6836.169922  5.718360e+09
# 4601   6843.220215  5.418480e+09
# 4602   6881.310059  5.098160e+09
# 4603   6861.890137  5.151690e+09
# 4604   6909.509766  5.432480e+09
#
# [4605 rows x 7 columns]

# %%
# 1. Get all stock prices for a given ticker

df = pd.read_sql ("SELECT * FROM stk_prices WHERE Ticker = '^IXIC' or Ticker = '^NSEI' or Ticker = '^GSPC' GROUP by Ticker ORDER BY Date;", conn)

df
# Out:
#                   Date Ticker          Open          High           Low  \
# 0  2020-01-01 00:00:00  ^NSEI  12202.150391  12222.200195  12165.299805
# 1  2020-01-02 00:00:00  ^GSPC   3244.669922   3258.139893   3235.530029
# 2  2020-01-02 00:00:00  ^IXIC   9039.459961   9093.429688   9010.889648
#
#           Close        Volume
# 0  12182.500000  3.041000e+05
# 1   3257.850098  3.459930e+09
# 2   9092.190430  2.862700e+09

# %%
# 2. Find the highest closing price for NASDAQ (^IXIC)

df = pd.read_sql ("SELECT MAX(close) AS highest_closing_price FROM stk_prices WHERE ticker = '^IXIC';", conn)

df
# Out:
#    highest_closing_price
# 0           23958.470703

# %%
# 3. List top 5 days with highest price difference (high - low) for S&P 500 (^GSPC)

df = pd.read_sql ("SELECT date, high - low AS price_difference FROM stk_prices WHERE ticker = '^GSPC' ORDER BY price_difference DESC LIMIT 5;", conn)

df
# Out:
#                   Date  price_difference
# 0  2025-04-09 00:00:00        532.909668
# 1  2025-04-07 00:00:00        411.529785
# 2  2025-04-08 00:00:00        357.050293
# 3  2025-04-10 00:00:00        237.879883
# 4  2025-11-20 00:00:00        236.300293

# %%
# 4. Get monthly average closing price for each ticker

df = pd.read_sql ("SELECT ticker, strftime('%Y-%m', date) AS month, AVG(close) AS avg_closing_price FROM stk_prices GROUP BY ticker, month ORDER BY ticker, month;", conn)

df
# Out:
#     Ticker    month  avg_closing_price
# 0    ^GSPC  2020-01        3278.202858
# 1    ^GSPC  2020-02        3277.314183
# 2    ^GSPC  2020-03        2652.393632
# 3    ^GSPC  2020-04        2761.975226
# 4    ^GSPC  2020-05        2919.608484
# ..     ...      ...                ...
# 217  ^NSEI  2025-10       25494.083519
# 218  ^NSEI  2025-11       25894.834396
# 219  ^NSEI  2025-12       25997.738725
# 220  ^NSEI  2026-01       25652.962695
# 221  ^NSEI  2026-02       25681.076693
#
# [222 rows x 3 columns]

# %% [markdown]
# # **Joint Querries**

# %%
# 1. Compare Bitcoin vs Oil average price in 2025.

df = pd.read_sql ("""SELECT 'bitcoin' AS asset,
AVG(price) AS avg_price
FROM top_coins
WHERE coin_id = 'bitcoin'
AND strftime('%Y', date) = '2025'

UNION ALL

SELECT 'OIL' AS asset,
AVG(price) AS avg_price
FROM oil_prices
WHERE strftime('%Y', date) = '2025';

""",conn)

df
# Out:
#      asset     avg_price
# 0  bitcoin  8.912678e+06
# 1      OIL  6.538810e+01

# %%
# 2. Check if Bitcoin moves with S&P 500 (correlation idea).

df=pd.read_sql("""SELECT
    date(t.date) AS date,
    t.price AS btc_close,
    s.close AS stk_close
FROM top_coins t
LEFT JOIN stk_prices s
    ON date(t.date) = date(s.date)
   AND s.ticker = '^GSPC'
WHERE t.coin_id = 'bitcoin'
ORDER BY date;
""",conn)
df
# Out:
#            date     btc_close    stk_close
# 0    2025-02-24  8.341958e+06  5983.250000
# 1    2025-02-25  7.922798e+06  5955.250000
# 2    2025-02-26  7.729282e+06  5956.060059
# 3    2025-02-27  7.314307e+06  5861.569824
# 4    2025-02-28  7.397417e+06  5954.500000
# ..          ...           ...          ...
# 361  2026-02-20  6.092367e+06  6909.509766
# 362  2026-02-21  6.166731e+06          NaN
# 363  2026-02-22  6.167422e+06          NaN
# 364  2026-02-23  6.132044e+06          NaN
# 365  2026-02-23  5.895648e+06          NaN
#
# [366 rows x 3 columns]

# %%
# 3. Compare Ethereum and NASDAQ daily prices for 2025.

df = pd.read_sql("""
SELECT
    date(t.date) AS date,
    t.price AS eth_price,
    s.close AS nasdaq_close
FROM top_coins t
JOIN stk_prices s
    ON date(t.date) = date(s.date)
WHERE t.coin_id = 'ethereum'
  AND s.ticker = '^IXIC'
  AND strftime('%Y', t.date) = '2025'
ORDER BY date;
""", conn)

df
# Out:
#            date      eth_price  nasdaq_close
# 0    2025-02-24  244834.169775  19286.929688
# 1    2025-02-25  216983.409814  19026.390625
# 2    2025-02-26  217304.159337  19075.259766
# 3    2025-02-27  202765.038710  18544.419922
# 4    2025-02-28  201317.512520  18847.279297
# ..          ...            ...           ...
# 211  2025-12-24  265308.330577  23613.310547
# 212  2025-12-26  261698.838882  23593.099609
# 213  2025-12-29  264760.550466  23474.349609
# 214  2025-12-30  263786.422730  23419.080078
# 215  2025-12-31  266620.867155  23241.990234
#
# [216 rows x 3 columns]

# %%
# 4. Find days when oil price spiked and compare with Bitcoin price change.

df = pd.read_sql ("""
SELECT
    date(o.Date) AS date,
    o.Price AS oil_price,
    t.price AS btc_price
FROM oil_prices o
JOIN top_coins t
    ON date(o.Date) = date(t.Date)
WHERE t.coin_id = 'bitcoin'
ORDER BY date;
""", conn)

df
# Out:
#            date  oil_price     btc_price
# 0    2025-02-24      71.06  8.341958e+06
# 1    2025-02-25      69.15  7.922798e+06
# 2    2025-02-26      68.87  7.729282e+06
# 3    2025-02-27      70.62  7.314307e+06
# 4    2025-02-28      69.97  7.397417e+06
# ..          ...        ...           ...
# 240  2026-02-10      64.20  6.363124e+06
# 241  2026-02-11      64.80  6.230645e+06
# 242  2026-02-12      63.08  6.073657e+06
# 243  2026-02-13      63.05  5.993963e+06
# 244  2026-02-17      62.53  6.255750e+06
#
# [245 rows x 3 columns]

# %%
# 5. Compare top 3 coins daily price trend vs Nifty (^NSEI).

df = pd.read_sql ("""
SELECT
    date(c.Date) AS date,
    c.coin_id AS coins,
    c.price AS coin_prices,
    n.Close AS nifty_close
FROM top_coins c
JOIN stk_prices n
    ON date(c.Date) = date(n.Date)
WHERE c.coin_id IN ('bitcoin', 'ethereum', 'binancecoin')
  AND n.Ticker = '^NSEI'
ORDER BY date;
""", conn)

df
# Out:
#            date     coins   coin_prices   nifty_close
# 0    2025-02-24   bitcoin  8.341958e+06  22553.349609
# 1    2025-02-24  ethereum  2.448342e+05  22553.349609
# 2    2025-02-25   bitcoin  7.922798e+06  22547.550781
# 3    2025-02-25  ethereum  2.169834e+05  22547.550781
# 4    2025-02-27   bitcoin  7.314307e+06  22545.050781
# ..          ...       ...           ...           ...
# 485  2026-02-18  ethereum  1.805283e+05  25819.349609
# 486  2026-02-19   bitcoin  6.033802e+06  25454.349609
# 487  2026-02-19  ethereum  1.774785e+05  25454.349609
# 488  2026-02-20   bitcoin  6.092367e+06  25571.250000
# 489  2026-02-20  ethereum  1.772492e+05  25571.250000
#
# [490 rows x 4 columns]

# %%
# 6. Compare stock prices (^GSPC) with crude oil prices on the same dates


df = pd.read_sql("""
SELECT
    date(s.Date) AS date,
    s.Close AS nifty_close,
    o.Price AS oil_price
FROM stk_prices s
JOIN oil_prices o
    ON date(s.Date) = date(o.Date)
WHERE s.Ticker = '^GSPC'
ORDER BY date;
""", conn)

df
# Out:
#             date  nifty_close  oil_price
# 0     2020-01-02  3257.850098      61.17
# 1     2020-01-03  3234.850098      63.00
# 2     2020-01-06  3246.280029      63.27
# 3     2020-01-07  3237.179932      62.70
# 4     2020-01-08  3253.050049      59.65
# ...          ...          ...        ...
# 1526  2026-02-10  6941.810059      64.20
# 1527  2026-02-11  6941.470215      64.80
# 1528  2026-02-12  6832.759766      63.08
# 1529  2026-02-13  6836.169922      63.05
# 1530  2026-02-17  6843.220215      62.53
#
# [1531 rows x 3 columns]

# %%
# 7. Correlate Bitcoin closing price with crude oil closing price (same date)

df = pd.read_sql("""
SELECT
    date(b.Date) AS date,
    b.price AS btc_price,
    o.Price AS oil_price
FROM top_coins b
JOIN oil_prices o
    ON date(b.Date) = date(o.Date)
WHERE b.coin_id = 'bitcoin'
ORDER BY date;
""", conn)

df
# Out:
#            date     btc_price  oil_price
# 0    2025-02-24  8.341958e+06      71.06
# 1    2025-02-25  7.922798e+06      69.15
# 2    2025-02-26  7.729282e+06      68.87
# 3    2025-02-27  7.314307e+06      70.62
# 4    2025-02-28  7.397417e+06      69.97
# ..          ...           ...        ...
# 240  2026-02-10  6.363124e+06      64.20
# 241  2026-02-11  6.230645e+06      64.80
# 242  2026-02-12  6.073657e+06      63.08
# 243  2026-02-13  5.993963e+06      63.05
# 244  2026-02-17  6.255750e+06      62.53
#
# [245 rows x 3 columns]

# %%
# 8. Compare NASDAQ (^IXIC) with Ethereum price trends

df = pd.read_sql("""
SELECT
    date(e.Date) AS date,
    e.price AS eth_price,
    i.Close AS ixic_close
FROM top_coins e
JOIN stk_prices i
    ON date(e.Date) = date(i.Date)
WHERE e.coin_id = 'ethereum'
  AND i.Ticker = '^IXIC'
ORDER BY date;
""", conn)

df
# Out:
#            date      eth_price    ixic_close
# 0    2025-02-24  244834.169775  19286.929688
# 1    2025-02-25  216983.409814  19026.390625
# 2    2025-02-26  217304.159337  19075.259766
# 3    2025-02-27  202765.038710  18544.419922
# 4    2025-02-28  201317.512520  18847.279297
# ..          ...            ...           ...
# 245  2026-02-13  176214.238345  22546.669922
# 246  2026-02-17  181624.154700  22578.380859
# 247  2026-02-18  180528.328343  22753.630859
# 248  2026-02-19  177478.459914  22682.730469
# 249  2026-02-20  177249.247482  22886.070312
#
# [250 rows x 3 columns]

# %%
# 9. Join top 3 crypto coins with stock indices for 2025
df = pd.read_sql("""
SELECT
    date(t.Date) AS date,
    t.coin_id AS crypto,
    t.price AS crypto_price,
    s.Ticker AS index_symbol,
    s.Close AS index_close
FROM top_coins t
JOIN stk_prices s
    ON date(t.Date) = date(s.Date)
WHERE t.coin_id IN ('bitcoin', 'ethereum', 'binancecoin')
  AND s.Ticker IN ('^GSPC', '^IXIC', '^NSEI')
  AND strftime('%Y', t.Date) = '2025'
ORDER BY date;
""", conn)

df
# Out:
#             date    crypto  crypto_price index_symbol   index_close
# 0     2025-02-24   bitcoin  8.341958e+06        ^NSEI  22553.349609
# 1     2025-02-24   bitcoin  8.341958e+06        ^IXIC  19286.929688
# 2     2025-02-24   bitcoin  8.341958e+06        ^GSPC   5983.250000
# 3     2025-02-24  ethereum  2.448342e+05        ^NSEI  22553.349609
# 4     2025-02-24  ethereum  2.448342e+05        ^IXIC  19286.929688
# ...          ...       ...           ...          ...           ...
# 1279  2025-12-31   bitcoin  7.936951e+06        ^IXIC  23241.990234
# 1280  2025-12-31   bitcoin  7.936951e+06        ^GSPC   6845.500000
# 1281  2025-12-31  ethereum  2.666209e+05        ^NSEI  26129.599609
# 1282  2025-12-31  ethereum  2.666209e+05        ^IXIC  23241.990234
# 1283  2025-12-31  ethereum  2.666209e+05        ^GSPC   6845.500000
#
# [1284 rows x 5 columns]

# %%
# 10. Multi-join: stock prices, oil prices, and Bitcoin prices for daily comparison

df = pd.read_sql("""
SELECT
    date(t.Date) AS date,
    t.price AS btc_price,
    s.Close AS stk_close,
    o.Price AS oil_price
FROM top_coins t
JOIN stk_prices s
    ON date(t.Date) = date(s.Date)
JOIN oil_prices o
    ON date(t.Date) = date(o.Date)
WHERE t.coin_id = 'bitcoin'
  AND s.Ticker = '^GSPC'
ORDER BY date;
""", conn)

df
# Out:
#            date     btc_price    stk_close  oil_price
# 0    2025-02-24  8.341958e+06  5983.250000      71.06
# 1    2025-02-25  7.922798e+06  5955.250000      69.15
# 2    2025-02-26  7.729282e+06  5956.060059      68.87
# 3    2025-02-27  7.314307e+06  5861.569824      70.62
# 4    2025-02-28  7.397417e+06  5954.500000      69.97
# ..          ...           ...          ...        ...
# 240  2026-02-10  6.363124e+06  6941.810059      64.20
# 241  2026-02-11  6.230645e+06  6941.470215      64.80
# 242  2026-02-12  6.073657e+06  6832.759766      63.08
# 243  2026-02-13  5.993963e+06  6836.169922      63.05
# 244  2026-02-17  6.255750e+06  6843.220215      62.53
#
# [245 rows x 4 columns]
